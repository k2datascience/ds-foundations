# %%
import requests

url = 'https://jobs.github.com/positions.json'
search_term = 'data science'

params = {'description': search_term}
response = requests.get(url, params=params)

print(response.status_code)
# Out:
# 200

# %%
json_response = response.json()

print('There are {n} results for the term "{term}".'
      .format(n=len(json_response), term=search_term))
# Out:
# There are 27 results for the term "data science".

# %%
import json
print(json_response == json.loads(response.text))
# Out:
# True

# %%
print(json.dumps(json_response, sort_keys=True, indent=4))
# Out:
# [
#     {
#         "company": "Network Merchants, LLC",
#         "company_logo": "http://github-jobs.s3.amazonaws.com/a1b8f9ec-bbed-11e6-960a-b1034c4cd71b.png",
#         "company_url": "http://nmi.com",
#         "created_at": "Tue Dec 06 19:54:25 UTC 2016",
#         "description": "<p><strong>Summary</strong> </p>\n\n<ul>\n<li>The engineering team at NMI is a small, agile group that works closely together but requires independent thinking and motivation. Engineers have direct influence over the design and implementation of systems, and infrastructure. Expertise should include fluency in Linux and security, strong troubleshooting and analytical skills, good communication skills and a genuine passion for solving problems related to scalability, performance, security and redundancy.</li>\n</ul>\n\n<p><strong>Essential Functions</strong> </p>\n\n<ul>\n<li>Communicate with staff or clients to understand specific system requirements.</li>\n<li>Provide advice on project costs, design concepts, or design changes.</li>\n<li>Document design specifications, installation instructions, and other system-related information.</li>\n<li>Verify stability, interoperability, portability, security, or scalability of system architecture.</li>\n<li>Collaborate with engineers or software developers to select appropriate design solutions or ensure the compatibility of system components.</li>\n<li>Provide technical guidance or support for the development or troubleshooting of systems.</li>\n<li>Identify system data, hardware, or software components required to meet user needs.</li>\n<li>Monitor system operation to detect protential problems.</li>\n<li>Perform all other related duties, as assigned.</li>\n</ul>\n\n<p><strong>Qualifications and Education Requirements</strong> </p>\n\n<ul>\n<li>Bachelor of Science degree in a related field and/or commensurate experience.</li>\n<li>5+ years working with enterprise level Linux servers, monitoring and storage</li>\n</ul>\n\n<p><strong>Knowledge, skills, abilities and other characteristics</strong> </p>\n\n<ul>\n<li>Familiarity with networking equipment such as switches, firewalls and load balancers from Cisco, - Juniper and F5 Working knowledge of PHP and Perl</li>\n<li>Expertise with Linux Servers particularly Redhat or CentOS</li>\n<li>Expertise with Apache, MySQL, Bash Scripting, Security and\nMonitoring Tools</li>\n<li>Expertise with Puppet configuration and maintenance</li>\n<li>Being cognizant of Systems Security</li>\n<li>Fluent written communication and verbal agility</li>\n<li>Working knowledge of PCI-DSS is a plus</li>\n<li>Strong troubleshooting and analytical skills</li>\n<li>Good communication skills</li>\n<li>Genuine passion for solving problems related to scalability, performance, security and redundancy.</li>\n<li>Working knowledge of source control repositories like GIT</li>\n</ul>\n\n<p><strong>Physical requirements and environment</strong> </p>\n\n<ul>\n<li>The ability to see details at close range (within a few feet of the observer).</li>\n<li>General office conditions.</li>\n<li>Regular attendance and reliability is mandatory.</li>\n</ul>\n\n<p><strong>Tools used</strong> </p>\n\n<ul>\n<li>Enterprise hardware (Rack servers, SAN, load balancers, networking equipment)</li>\n<li>Linux based servers and services \u2013 Web, Application, FTP, SMTP, Puppet</li>\n<li>Linux based monitoring systems</li>\n<li>Jira and Confluence for task and project management</li>\n<li>Computer</li>\n<li>Printer</li>\n<li>Fax Machine</li>\n<li>Scanner</li>\n</ul>\n",
#         "how_to_apply": "<p>Please E-mail your resume to <a href=\"mailto:hr@nmi.com\">hr@nmi.com</a></p>\n",
#         "id": "beb74684-bbed-11e6-8197-64e617b51adf",
#         "location": "Roselle, IL",
#         "title": "Linux Systems Engineer",
#         "type": "Full Time",
#         "url": "http://jobs.github.com/positions/beb74684-bbed-11e6-8197-64e617b51adf"
#     },
#     {
#         "company": "Stevens Capital Management LP",
#         "company_logo": "http://github-jobs.s3.amazonaws.com/5df90c6a-baf8-11e6-8a38-492033c01d86.png",
#         "company_url": "http://www.scm-lp.com",
#         "created_at": "Mon Dec 05 14:38:11 UTC 2016",
#         "description": "<p>Stevens Capital Management LP (\u201cSCM\u201d) is a registered investment adviser that manages a multi-billion dollar hedge fund that has been in business for 25+ years.\nSCM specializes in the rigorous development and disciplined implementation of empirically based quantitative trading strategies. Our highly productive team works in a fast-paced collegial environment, utilizing extensive data sets, technology and the scientific method to devise and employ trading strategies throughout the world\u2019s most liquid financial markets.</p>\n\n<p>Implementation Developer</p>\n\n<p>We&#39;re seeking highly driven, production-oriented developers who possess strong technical skills and the ability to work in a fast-paced collaborative environment.  </p>\n\n<p>Primary Responsibilities</p>\n\n<ul>\n<li>Develop and support multi-threaded applications with a strong emphasis on high performance.</li>\n<li>Optimize our trading strategy implementation and performance analysis platform using network and systems programming.</li>\n<li>Create tools to process, store and analyze quote, order and financial data.</li>\n<li>Work closely with our quantitative research analysts, engineers and other groups to provide software solutions.</li>\n</ul>\n\n<p>Requirements</p>\n\n<ul>\n<li>Professional-level C++ programming experience in a Linux environment. </li>\n<li>A Computer Science or Mathematics degree.</li>\n<li>Outstanding problem solving skills.</li>\n<li>Knowledge of shell scripts and other languages including Perl, Bash or CSH is a plus.</li>\n<li>Experience with relational databases including Sybase, SQL Server and Oracle is a plus.</li>\n<li>Experience with GUI design is a plus.</li>\n</ul>\n",
#         "how_to_apply": "<p>Please submit your resume to: <a href=\"mailto:recruiting@scm-lp.com\">recruiting@scm-lp.com</a></p>\n\n<p>Website: <a href=\"http://www.scm-lp.com\">www.scm-lp.com</a></p>\n",
#         "id": "61433012-baf8-11e6-8d18-1baa36e6dbf5",
#         "location": "Radnor, PA. USA",
#         "title": "Implementation Developer",
#         "type": "Full Time",
#         "url": "http://jobs.github.com/positions/61433012-baf8-11e6-8d18-1baa36e6dbf5"
#     },
#     {
#         "company": "GenePeeks, Inc",
#         "company_logo": "http://github-jobs.s3.amazonaws.com/67ea79ea-b8c6-11e6-81ec-ba6eeed777c6.jpg",
#         "company_url": "http://www.genepeeks.com",
#         "created_at": "Fri Dec 02 19:36:23 UTC 2016",
#         "description": "<p>Job description</p>\n\n<p>GenePeeks is a data-driven genetics start-up pushing the boundaries of reproductive health care and computational genetics. As a result, we are looking for an engineer who is passionate in helping us shape how we, as humans, consume and interpret genetic information.  The right candidate has proven experience designing and growing cloud-based architectures and infrastructures. You should never have to manually perform a task more than once, since you have a passion for automation and wrote a deploy script to do it for you on day one. You will have built solutions that scaled rapidly to meet global needs, and have the battle scars to prove that not everything goes according to plan, but you\u2019ve learned and are better for it. Lastly, you pride yourself on elegant solutions which are built for the future and your fellow engineers,  all while not losing sight of the bigger picture.</p>\n\n<p>Relevant Experience:</p>\n\n<ul>\n<li>4+ years of relevant industry experience, someone who has \u2018been there\u2019 and \u2018done that\u2019.</li>\n<li>Familiarity with most of the heavy hitters in our stack which are AWS, NGINX, Python, Django, PostgreSQL, MongoDB, and Redis.</li>\n<li>Experience with industry staples in automation like Puppet, Chef, or Ansible. Also uses CI services like CircleCI, TravisCI, or Jenkins.</li>\n<li>Experience developing with containers/virtualized applications in the cloud i.e. Docker with EC2.</li>\n<li>Experience utilizing and contributing to open-source tools and code.</li>\n<li>Utilize data-driven development in monitoring and logging with analytics being second-nature</li>\n</ul>\n\n<p>Nice-to-haves:</p>\n\n<ul>\n<li>B.S. or equivalent in computer science or related field.</li>\n<li>Scripting/programming experience using Bash or Python.</li>\n<li>Experience working with SQL(PostgreSQL), NoSQL(MongoDB), Key-value store(Redis) in a production environment i.e. vertical scaling, replica sets, and sharding.</li>\n<li>Experience with load balancing and stress testing deployment configurations.</li>\n<li>A strong grasp of data structures, algorithms, databases, etc.</li>\n<li>You wear every 9 of uptime as a badge of honor.</li>\n</ul>\n\n<p>Other Benefits:</p>\n\n<ul>\n<li>Competitive Salary</li>\n<li>Stock Options</li>\n<li>Comprehensive Health and Dental benefits.</li>\n<li>Apple equipment</li>\n<li>Your coworkers are as passionate about applied genetics as they are about climbing, sailing, biking, and Game of Thrones! (and Harry Potter)</li>\n<li>Our office space is on the Red Line, has tons of natural light, and plenty of brick-and-beam Cambridge character.</li>\n</ul>\n\n<p>Location:\nThis position will be located in the Boston or New York area.\n*GenePeeks will not offer visa sponsorship for this position</p>\n",
#         "how_to_apply": "<p><a href=\"http://careers.genepeeks.com/o/software-engineer-devops=GitHub\">http://careers.genepeeks.com/o/software-engineer-devops=GitHub</a></p>\n",
#         "id": "6d409aaa-b8c6-11e6-8408-7debc09d256f",
#         "location": "Cambridge, MA",
#         "title": "Software Engineer, DevOps",
#         "type": "Full Time",
#         "url": "http://jobs.github.com/positions/6d409aaa-b8c6-11e6-8408-7debc09d256f"
#     },
#     {
#         "company": "Intel Corporation",
#         "company_logo": "http://github-jobs.s3.amazonaws.com/0590279e-b7eb-11e6-92e0-095053d3f49d.png",
#         "company_url": "http://jobs.intel.com",
#         "created_at": "Fri Dec 02 11:49:17 UTC 2016",
#         "description": "<p>Employees of the Internet of Things Solutions Group (IOTG) have an exciting opportunity before them: To grow Intel&#39;s leadership position in the rapidly evolving IoT market by delivering the best silicon, software and services that meet a wide range of customer requirements - from Intel\u00ae Xeon\u00ae to Intel\u00ae Quark\u00ae. The group, a fresh, dynamic collaboration between Intel&#39;s Intelligent Solutions Group and Wind River Systems, utilizes assets from across all of Intel in such areas as industrial automation, retail, automobiles and aerospace.\nThe IOTG team is dedicated to helping Intel drive the next major growth inflection through productivity and new business models that are emerging as a result of IoT. Intel&#39;s Transportation Solutions Division is at the forefront of bringing highly and fully automated vehicles to market with our partners from the automotive industry.  </p>\n\n<p>Come join a dynamic and fast paced environment where the possibilities are limited only by your imagination.  </p>\n\n<p>We are looking for the Software Engineer on the Automated Driving team who will design and develop software for next generation automated driving systems. The position will include design and implementation of embedded software.  </p>\n\n<p>In the role you will be responsible for supporting research and developmental efforts in automated vehicle technologies ranging from Advanced Driver Assistance Systems (ADAS) to semi- and fully-autonomous driving capabilities.\nAs an Automated Driving Software Development Engineer, your responsibilities will include but are not be limited to:</p>\n\n<ul>\n<li>Design and develop state-of-the-art computing platforms for next generation automated driving systems</li>\n<li>System Modelling of complete AD systems and subsystems</li>\n<li>Development of middleware components for highly efficient embedded systems font size\nRequirements:</li>\n<li>Qualifications: Bachelor degree in Computer Science, Electrical Engineering, or related field plus 6 years of work experience, Master&#39;s degree in Computer Science, Electrical Engineering, or related field plus 4 years of related work experience, or PhD in Computer Science, Electrical Engineering, or related field plus 2 years of related work experience.</li>\n<li>Excellent skills in C++ and standard libraries (e.g. STL, OpenCL, Boost)Experience developing software for Linux</li>\n<li>Advanced English communication skills, both written \u00a0verbal\nYou will have some of the following:</li>\n<li>Master\u2019s degree or PhD in Electrical or Computer Engineering or similar field of study \u2022 Familiarity with ADAS or AD</li>\n<li>Experience with Functional Safety</li>\n<li>Experience with embedded RTOS</li>\n<li>Experiences with machine learning systems</li>\n<li>Experience in image processing, computer vision, OpenCV</li>\n<li>Experiences with Robot Operating System (ROS)</li>\n<li>Software/firmware development in one or more languages/platforms/libraries (C/C++, VHDL/Verilog, MATLAB, CUDA, OpenCL)</li>\n<li>Familiarity with sensor modalities used in robotics and automated driving applications (Camera/Vision, RADAR, LIDAR, INS/IMU)</li>\n<li>Familiarity with commonly used approaches for autonomous systems (sensor data processing, data fusion, scene analytics, scene interpretation, behavior prediction, trajectory planning, et.)</li>\n<li>Working Knowledge of Linux in embedded applications</li>\n<li>Experiences in system modelling (UML, SysML) and automated code generation \u2022 Experiences with Eclipse and Yocto</li>\n<li>Experiences with ADTF and ROS<br></li>\n</ul>\n\n<p>\u2028Qualifications\u2028<br>\nInside this Business Group\u2028<br>\nEmployees of the Internet of Things Solutions Group (IOTG) have an exciting opportunity before them: To grow Intel&#39;s leadership position in the rapidly evolving IoT market by delivering the best silicon, software and services that meet a wide range of customer requ ...
#         "how_to_apply": "<p>Apply on company website: <a href=\"http://career.intel.com/TpLVa\">http://career.intel.com/TpLVa</a></p>\n",
#         "id": "47b78b5e-b7ef-11e6-86f0-a00baabc0c92",
#         "location": "Karlsruhe, Germany",
#         "title": "Automated Driving SW Development Engineer",
#         "type": "Full Time",
#         "url": "http://jobs.github.com/positions/47b78b5e-b7ef-11e6-86f0-a00baabc0c92"
#     },
#     {
#         "company": "Intel Corporation",
#         "company_logo": "http://github-jobs.s3.amazonaws.com/8fe64a66-b7ed-11e6-9afe-3b4e9182fd07.png",
#         "company_url": "http://jobs.intel.com",
#         "created_at": "Fri Dec 02 11:49:15 UTC 2016",
#         "description": "<p>Duties are focused on development open-source LLVM/GCC toolchain for Intel Architecture in Linux and Android target environments.  </p>\n\n<p><strong>Responsibilities include:</strong> \nDesign modules and software systems for compiler toolchain, including enabling new IA technology or improving performance and quality of existing functionality. Research fundamental problems and implement algorithm solutions with primary focus on backend compiler optimizations.  </p>\n\n<p><strong>What do we offer:</strong><br>\n\u2028On top of that we at Intel provide you with bonuses, trainings, conferences, private medical plan, life insurance, lunch coupons and a chance to participate in Intel Great Place to Work programs supporting diverse activities/hobbies (e.g. running, cycling, squash, tennis, cross fit, photography).  </p>\n\n<p><strong>\u2028Qualifications\u2028\u2028</strong><br>\n<strong>Must have:</strong>\u00a0 \n\u2028- B.S or M.S in Computer Science, or Electrical Engineering, or Computer Engineering or equivalent<br>\n\u2028- Excellent knowledge of C and C++ programming language\u00a0 \n\u2028- Familiarity with source control systems such as git/svn/cvs\u00a0 \n\u2028- Knowledge of Unix-based operating systems and development environment, tools such as shell/make/etc.\u00a0\u2028 </p>\n\n<ul>\n<li>Excellent understanding of algorithms design and data structures\u00a0 \n\u2028- Good experience of debugging issues with gdb/lldb/idb.\u00a0\u2028 </li>\n<li>Familiarity with x86 Intel Architecture Positive team work experience Fluent English\u00a0\u2028\u2028Highly<br></li>\n</ul>\n\n<p><strong>Recommended:</strong>\u00a0\u2028 </p>\n\n<ul>\n<li>Experience of development and knowledge of internals of LLVM/GCC is a great advantage for any candidate.\u00a0 \n\u2028- Experience of work with Open Source communities. Understanding the principles of open source contributions.</li>\n</ul>\n\n<p><strong>Inside this Business Group</strong>\u2028\nThe Intel Software and Services Group (SSG) connects Intel to the worldwide software community. SSG strives to bring competitive advantage to Intel platforms by helping independent software vendors, operating system developers, OEMs, channel members and systems integrators deliver exceptional customer value and achieve differentiation on Intel\u00ae processor technologies. SSG provides global leadership to the software community through its technical expertise, industry enabling activities, and developer products and programs.</p>\n",
#         "how_to_apply": "<p>Apply on company website: <a href=\"http://career.intel.com/TpHFE\">http://career.intel.com/TpHFE</a></p>\n",
#         "id": "88d7a11e-b7ef-11e6-8839-4baedb4f1c00",
#         "location": "Gdansk, Poland ",
#         "title": "Software Development Engineer C, C++",
#         "type": "Full Time",
#         "url": "http://jobs.github.com/positions/88d7a11e-b7ef-11e6-8839-4baedb4f1c00"
#     },
#     {
#         "company": "PDT Partners",
#         "company_logo": "http://github-jobs.s3.amazonaws.com/1dee7540-b7f8-11e6-8780-56e37987ae3b.png",
#         "company_url": "http://www.pdtpartners.com",
#         "created_at": "Thu Dec 01 18:59:13 UTC 2016",
#         "description": "<p><strong>C++/Python Engineers</strong></p>\n\n<p>We\u2019re looking for a select few uniquely excellent C++/Python engineers to join our world-class team. PDTers are creative, energetic, friendly, entrepreneurial, and collaborative. If you could walk around our office, you\u2019d see that we\u2019re a focused, intent, and nimble company with none of the attitude and bureaucracy a stereotypical Wall Street trading firm. Our engineers love to work on challenging and complicated problems, and in return, they have a chance to make a direct impact on our bottom line. For the right talent, there is fantastic growth potential. </p>\n\n<p>Our standards for code quality are high, and our bar for the software engineers who write it is stratospheric.  The most successful engineers at PDT move fluidly between roles over time. Engineering jobs at PDT have some different flavors with a mix of C++ and Python focuses:</p>\n\n<p><strong>Trading Infrastructure Technology (C++ Focus)</strong></p>\n\n<p>Every action we take in the market is conceived, executed, verified, processed, and reported using software we wrote expressly for the purpose.  Our business depends on automated trading platforms that are fast, stable, resilient, and innovative.</p>\n\n<ul>\n<li>Create, support, and improve our fast real-time global trading engine \u2013 the automated platform on which all of our trading strategies run</li>\n<li>Manage the codebase that runs order routing and execution, exchange connectivity, and market data</li>\n<li>Be a partner to our research strategies, systems engineers, and business operations teams to ensure success</li>\n</ul>\n\n<p><strong>Trading Business Technology (Python Focus)</strong> </p>\n\n<p>Running our business responsibly means keeping close track of our fund positions, risks, compliance, and the value of every single asset we hold at any given time. Designing and engineering our next generation platform for routing and managing all of our post-trade data is an exceptional challenge and a top business priority.</p>\n\n<ul>\n<li>Redesign, build, and evolve our post-trade technology stack for finance, fund operations, analytics, risk, and compliance.</li>\n<li>Own the selection, vetting, and integration of open-source and third-party platforms.</li>\n<li>Be a business partner to our CFO, COO, and operations teams</li>\n</ul>\n\n<p><strong>Software Infrastructure (C++ and Python Focus)</strong></p>\n\n<p>Although we write plenty of our software completely from scratch, we also create an ever-expanding set of powerful tools, services, and common frameworks our developers can use used as building blocks. If you\u2019re the kind of developer who loves writing ingenious code that helps other people write more ingenious code, you\u2019ll love this job.</p>\n\n<ul>\n<li>Write, manage, and evolve the core software DNA of libraries and services that our engineers use to write all of the code that runs our business: logging and discovery, orchestration, tooling, services, etc.</li>\n<li>Innovate in and improve the quality of our development environment, from source control to compilers and beyond</li>\n<li>Work closely with Systems Infrastructure engineers to ensure that the software development lifecycle is woven into the fabric of our environment</li>\n<li>Play a transformative role in increasing the effectiveness of our software engineers and the quality of our codebase</li>\n</ul>\n\n<p><strong>Research Infrastructure (C++ and Python Focus)</strong></p>\n\n<p>In order to work their magic, our research scientists and software engineers rely on a suite of bespoke tools, libraries, and applications, running in a fast and stable research grid environment.  It\u2019s this technical foundation that makes our innovative research possible, so we devote significant time and attention to getting it right.</p>\n\n<ul>\n<li>Build and manage libraries and APIs, as well as the container, distributed algorithm, grid-abstr ...
#         "how_to_apply": "<p><a href=\"http://grnh.se/h8l4dk1\">http://grnh.se/h8l4dk1</a></p>\n",
#         "id": "24d6d212-b7f8-11e6-9bc0-4c468fa010c5",
#         "location": "New York",
#         "title": "C++/Python Developer",
#         "type": "Full Time",
#         "url": "http://jobs.github.com/positions/24d6d212-b7f8-11e6-9bc0-4c468fa010c5"
#     },
#     {
#         "company": "CrowdFlower",
#         "company_logo": null,
#         "company_url": null,
#         "created_at": "Tue Nov 29 23:27:00 UTC 2016",
#         "description": "<p><h2><strong>About CrowdFlower...</strong></h2><p>CrowdFlower is the essential human-in-the-loop platform for data science teams. CrowdFlower helps customers generate high quality customized training data for their machine learning initiatives and to automate business processes with easy-to-deploy ML models and integrated human-in-the-loop workflows. The CrowdFlower platform supports a wide range of use cases including self-driving cars, intelligent personal assistants, medical image labeling, content categorization, customer support ticket classification, social data insight, CRM data enrichment, product categorization, and search relevance.\u00a0</p><p>Headquartered in San Francisco and backed by Canvas Venture Fund, Trinity Ventures, and Microsoft Ventures, CrowdFlower serves data science teams at Fortune 500 and fast-growing data-driven organizations across a wide variety of industries. For more information, visit <a href=\"http://www.crowdflower.com\">www.crowdflower.com</a>.</p><p>We are looking for smart, innovative people to help us build scalable, resilient and responsive systems, working with our team based in either San Francisco\u2019s Mission District or Sacramento California.\u00a0</p><h2><strong>The Ideal Candidate</strong></h2><p>You are an experienced application developer who knows how to design and implement scalable, resilient, secure and responsive systems. You like to work with different technologies and are passionate about learning new things. You take pride in designing elegant, simple solutions to challenging problems, whether updating legacy systems or creating new micro-services. You can help to ensure we continue to evolve and keep our edge as a world\u00ac-class development team building great products. You are looking to join a team where you can make a difference while also being challenged to improve your own skills.</p><h3>Responsibilities:</h3><ul><li>Participate in designing and developing robust, scalable systems with modern design patterns in a services oriented architecture.</li><li>Take the initiative to share your skills &amp; knowledge with other members of the team and learn from them in return. Collaboration is key.</li><li>Demonstrate ownership and pride in your work and encourage others to do the same.</li><li>Analyze and improve existing systems and offer go-forward suggestions to enhance scalability, resiliency and performance.</li><li>Promote best practices for writing maintainable, well\u00ac-tested code within a scrum based agile process.</li></ul><h3>Skills &amp; Experience:</h3><ul><li>Bachelor&#39;s degree or higher in Computer Science, or equivalent work experience.</li><li>Strong expertise with Ruby and Rails is a must. Experience with other programming languages such as Node.js or Java are a definite asset.</li><li>Experience with a range of data stores, including relational (SQL), column\u00ac-oriented and key\u00acvalue stores (ideally Postgres, Memcache, Redis, RedShift).</li><li>Knowledge of professional software engineering best practices for the full software development life cycle, including coding standards, code reviews, source control management, agile development, build processes, testing, and operations.</li><li>Experience with the AWS platform and its many components (S3, API Gateway, Lambda etc) is a plus.</li><li>Experience creating RESTful API\u2019s is a plus.</li><li>Experience with Docker containerization is a plus.</li></ul><p>CrowdFlower offers an attractive total compensation package including outstanding benefits and stock options.</p> <img src=\"https://www.applytracking.com/track.aspx/7IJjT\"/></p>\n",
#         "how_to_apply": "<p><a href=\"https://www.applytracking.com/track.aspx/7IJjd\">https://www.applytracking.com/track.aspx/7IJjd</a></p>\n",
#         "id": "53eb1432-b68b-11e6-805c-42ae75f605e1",
#         "location": "San Francisco, CA, US",
#         "title": "Ruby/Rails BackEnd Developer",
#         "type": "Full Time",
#         "url": "http://jobs.github.com/positions/53eb1432-b68b-11e6-805c-42ae75f605e1"
#     },
#     {
#         "company": "Carbon Black, Inc.",
#         "company_logo": "http://github-jobs.s3.amazonaws.com/309b531e-b679-11e6-8bed-4a8a3761e6da.jpg",
#         "company_url": "https://www.carbonblack.com/",
#         "created_at": "Tue Nov 29 21:23:04 UTC 2016",
#         "description": "<p><strong>Why Carbon Black?</strong></p>\n\n<p>At Carbon Black, you\u2019ll have the opportunity to make a huge impact while working alongside a global community of passionate people who are leading the way in cutting-edge technology. Our valued employees across the world have made Carbon Black a Top Place to Work, as named by the Boston Globe for two consecutive years.</p>\n\n<p>Our Engineering team is moving at lightning speed on the breaking edge of technology. You\u2019ll be pulling things apart and tinkering, building new platforms, or playing in the cloud. Here, the engineering opportunities are endless. With this fast-paced, synergetic group, you\u2019ll be working together and across the organization to ensure customer success all while continuing to build a product that protects their dearest assets.</p>\n\n<p><strong>Why You Matter:</strong></p>\n\n<p>There\u2019s incredible excitement and urgency around cyber security software right now.  Protecting the world\u2019s Intellectual Property is an imperative and Carbon Black is at the forefront of this market, providing solutions that protect industry and thought leaders in the Commercial, Retail, Finance, Energy and Government sectors.</p>\n\n<p>We\u2019re looking for a Senior Software Engineer to join our Collective Defense Cloud Engineering Team building solutions that will help us enrich, analyze and deliver our industry leading Threat Intelligence data to our customers. You\u2019ll join a talented team of developers using a wide variety of cool technologies to solve big problems.  You\u2019ll partner with some impressive threat researchers who are on the bleeding edge of malware analysis. You\u2019ll build solutions that our customers are clamoring for, that will help our customers prevent the next front page security breach. You\u2019ll make a difference and help us win a huge market.  Sound good?  </p>\n\n<p><strong>What You\u2019ll Do:</strong></p>\n\n<ul>\n<li>Lead the development of new features while also maintaining and enhancing existing features within our Cb Collective Defense Cloud</li>\n<li>Design and implement RESTful web services (using python, Java, etc.) for an AWS cloud deployment, leveraging many AWS service offerings and technologies</li>\n<li>Participate in the design and implementation of a Big Data analytics platform (NoSQL, Hadoop, Spark, EMR, etc.)</li>\n<li>Deliver high quality, secure and scalable solutions alongside the rest of the dev team as part of an Agile SDLC</li>\n<li>Analyze performance of services and optimize / refactor as needed</li>\n<li>Investigate functional problems, finding and fixing defects as needed</li>\n<li>Independently schedule and manage work items (defects, user stories, features, etc.)</li>\n<li>Design proof of concepts or working prototypes for software services</li>\n<li>Ensure that software designs follow best-practices and architectural guidelines</li>\n</ul>\n\n<p><strong>What You\u2019ll Bring:</strong></p>\n\n<p>To perform this job successfully, an individual must be able to perform each essential duty satisfactorily.  Other duties may be assigned to meet business needs.  Reasonable accommodations may be made to enable individuals with disabilities to perform the essential functions.</p>\n\n<ul>\n<li>B.S. in Computer Science or equivalent experience</li>\n<li>Five+ years\u2019 experience in designing and delivering commercial software products</li>\n<li>High level of expertise programming in python, Java or equivalent programming languages on Linux</li>\n<li>Solid RDBMS experience and fundamentals</li>\n<li>Demonstrated aptitude in quickly mastering new languages and technologies</li>\n<li>Excellent communication and interpersonal skills</li>\n<li>Excellent problem solving and troubleshooting skills</li>\n<li>Amazon AWS experience a big plus</li>\n<li>Security Experience a big plus</li>\n<li>NoSQL experience a plus</li>\n</ul>\n\n<p><strong>Who We Are:</strong></p>\n\n<p>Carbon Bla ...
#         "how_to_apply": "<p><a href=\"https://lifeatcb.carbonblack.com/job-postings/?p=job/oMPL3fw9&amp;__jvst=JobBoard&amp;__jvsd=Github&amp;nl=1\">Click here to apply.</a></p>\n",
#         "id": "f2dff876-b679-11e6-896e-3954f140fe85",
#         "location": "Waltham, MA or Telecommute",
#         "title": "Senior Software Engineer - Cloud",
#         "type": "Full Time",
#         "url": "http://jobs.github.com/positions/f2dff876-b679-11e6-896e-3954f140fe85"
#     },
#     {
#         "company": "SmarterTravel",
#         "company_logo": "http://github-jobs.s3.amazonaws.com/d4a4f27e-b667-11e6-9318-ad870fa045f5.png",
#         "company_url": "http://www.wearesmartertravel.com",
#         "created_at": "Tue Nov 29 19:14:14 UTC 2016",
#         "description": "<p>SmarterTravel, a TripAdvisor Company, offers travelers a portfolio of travel sites to help them find the right trip at the right price.  We are a team of passionate professionals who push and drive and innovate like a start-up, but we also have a track record of success and we benefit from being a part of a large, public company.</p>\n\n<p>Oyster.com is one of the sites in the SmarterTravel portfolio, delivers unbiased, expert information about hotels. Oyster sends trained reviewers to visit, comprehensively photograph, and critique each hotel reviewed on Oyster. Oyster.com has been featured by numerous media outlets, including The Today Show, 20/20, The Wall Street Journal, and The New York Times, we are looking for an experienced technology leader to help us grow.</p>\n\n<p>If you\u2019ve got that exceptional ability to grasp the big picture from a business perspective and figure out how to deliver on that vision with exceptional teams of software engineers; if you are willing to dive in and code to deliver on projects; and if you truly know how to inspire, motivate, and grow teams, then let\u2019s talk!</p>\n\n<p>Some of the Software Engineering Manager responsibilities include:</p>\n\n<ul>\n<li>Be both a highly technical, hands-on coder and effective people manager</li>\n<li>Acting as the liaison between Development and other disciplines within the business</li>\n<li>Driving the adoption of industry best-practices</li>\n<li>Staffing, assessing needs and attracting and retaining top talent</li>\n<li>Technology research, staying on top of and making recommendations for the adoption of new technologies</li>\n<li>Guiding and reviewing major architectural efforts</li>\n<li>Coaching others to challenge the status quo, consider alternatives and make hard choices</li>\n</ul>\n\n<p>Strong candidates will have the following:</p>\n\n<ul>\n<li>12+ years of relevant work experience, including hands-on technical management</li>\n<li>Strong, full-stack technical skills built up while successfully delivering web-based products</li>\n<li>Prior experience building and/or leading development of high-traffic, consumer-facing web products is strongly preferred (eCommerce, online media, etc.)</li>\n<li>Experience with, and knowledge of several programming languages, database technologies, and development methodologies</li>\n<li>Strong communication, interpersonal, and leadership skills</li>\n<li>Exceptional problem solving skills</li>\n<li>Bachelor degree in Computer Science, Statistics, or Mathematics preferred</li>\n<li>Must be able to perform customary physical duties and meet appropriate social expectations of a professional office environment</li>\n</ul>\n\n<p>At SmarterTravel, we have built an open &amp; collaborative environment and we hire the people we want to work with (not just the ones with the right qualifications), but who also think different to us and challenge the status quo. We empower people, giving the support and autonomy needed to succeed. We embrace data to make decisions and overcome obstacles. We choose speed over perfection, but not at the expense of quality. We do what we do well, but we\u2019re always looking to make it better. Let us know if you\u2019d like to help.</p>\n\n<p>SmarterTravel is an equal opportunity employer and evaluates applicants regardless of an individual\u2019s age, race, color, gender, religion, national origin, sexual orientation, disability, veteran status, or musical preferences. We think a diverse team builds a better product.</p>\n\n<p>*** This employer participates in E-Verify. The employer will provide the Social Security Administration (SSA) and, if necessary, the Department of Homeland Security (DHS) with information from each new employee&#39;s I-9 to confirm work authorization. ***</p>\n",
#         "how_to_apply": "<p>Please apply online at <a href=\"http://grnh.se/ta5py11\">http://grnh.se/ta5py11</a> or email your resume to <a href=\"mailto:careers@smartertravel.com\">careers@smartertravel.com</a></p>\n",
#         "id": "b3d3c3fe-b65d-11e6-9da9-6e5efb70d328",
#         "location": "New York, NY",
#         "title": "Software Engineering Manager, Oyster.com",
#         "type": "Full Time",
#         "url": "http://jobs.github.com/positions/b3d3c3fe-b65d-11e6-9da9-6e5efb70d328"
#     },
#     {
#         "company": "Teleopti",
#         "company_logo": "http://github-jobs.s3.amazonaws.com/9d62e428-b57d-11e6-85ba-b1fdde6cc6ee.jpg",
#         "company_url": "http://www.teleopti.com/index.aspx",
#         "created_at": "Mon Nov 28 15:17:34 UTC 2016",
#         "description": "<p>If you are a team player who appreciates freedom with responsibility and working in an international and creative environment, this is the job for you! As an experienced Front-end Lead Developer at Teleopti you will maintain the balance between creativity and functionality for Teleopti\u2019s web applications. Teleopti is continuously growing and they are currently looking for an experienced Front-end Lead Developer.</p>\n\n<p><b>ABOUT THE ROLE</b></p>\n\n<p>As a Front-end Lead Developer at Teleopti you will be one of the key players as Teleopti take the step from Windows applications to web applications in the cloud. This is a highly autonomous role, with the freedom to develop and implement your ideas as part of an innovative and collaborative team. At Teleopti you come face to face with world class agile development and you will get to work with colleagues, teams and customers from the whole world. They work with the latest front-end technologies such as AngularJS 1, HTML5, CSS3, SASS, Grunt and Karma/Jasmine.</p>\n\n<p>You will be part of the R&amp;D department at the Teleopti HQ in Stockholm City with additional R&amp;D offices in Str\u00e4ngn\u00e4s and Shenzhen. This position will be placed in Stockholm, but you will have the opportunity to visit the office in China. There are six teams in Stockholm and each team typically consist of three Back-end Developers, one Front-end Developer and one Tester. You will be the Lead of the Front-end Developers.</p>\n\n<p>This recruitment process is conducted by Academic Work and the request from Teleopti is that all questions regarding the position is handled by <a href=\"mailto:sn03@academicwork.se\">Academic Work</a>.</p>\n\n<p>Academic Work is responsible for the recruitment process but the candidate that proceed will be employed directly by Teleopti.</p>\n\n<p><b>JOB DUTIES</b></p>\n\n<p>As an experienced Front-end Lead Developer, your main task will be the development of new Teleopti web applications for strategic workforce management. To succeed in your role you should be familiar with next-generation technologies, as well as being web and cloud-focused. You will work closely with product owners and customers to meet their requirements of ideas and design to create exceptionally user friendly web applications.</p>\n\n<p>For example, you will:</p>\n\n<p>Coach the development teams to build the best user experience possible</p>\n\n<p>Improve the usability and performance of web applications</p>\n\n<p>Ensure maintainability and quality of the front-end code</p>\n\n<p>Drive and take initiatives to always improve Teleopti\u00b4s products and processes</p>\n\n<p>This position suits you who want to join a company who successfully uses Kanban as a method. You will contribute with your specialities within the team to reach your goals. If you want to work in an international and creative environment, an environment where choices that were made in the past are not necessary rules to be followed, then this will fit you.</p>\n\n<p><b>WE ARE LOOKING FOR</b></p>\n\n<ul>\n<li><p>At least three to five years of test-driven front-end development experience</p></li>\n<li><p>Experience from building complex web applications</p></li>\n<li><p>Solid knowledge of JavaScript, HTML and CSS</p></li>\n<li><p>University degree within computer science or similar</p></li>\n<li><p>It will be considered an additional qualification if you have knowledge of AngularJS</p></li>\n</ul>\n\n<p>As a person, you are flexible, independent, resourceful and responsible. You are a team player who appreciates freedom with responsibility while working. You are easy to work with and can cooperate with your colleagues in an effective way. You should have a strong ability to plan and structure your work and you are not afraid to take the lead and come up with new ideas.</p>\n\n<p><b>START:</b> As soon as possible</p>\n\n<p><b>WORK EXTENT:</b> Fulltime</p>\n\n<p><b>LOCATION:</b> Stockholm</p>\n\n<p>We ...
#         "how_to_apply": "<p>Do you meet the requirements? Click on the link below:\n<a href=\"https://www.academicwork.se/annons/front-end-lead-developer-to-teleopti/14979312?preview=1\">https://www.academicwork.se/annons/front-end-lead-developer-to-teleopti/14979312?preview=1</a></p>\n\n<p>and submit your application as soon as possible as our selection process is continuous. Don\u2019t forget to include a link to your Github profile!</p>\n\n<p>We only handle applications through our website but if you have questions about the position you are welcome to email us <a href=\"mailto:stn03@academicwork.se\">stn03@academicwork.se</a> and we will answer during office hours. Please write the advert title in the subject and paste the advert link in the mail.</p>\n",
#         "id": "ada0319c-b57d-11e6-9c3c-d13afadb65a8",
#         "location": "Stockholm",
#         "title": "Front-End Lead Developer to Teleopti ",
#         "type": "Full Time",
#         "url": "http://jobs.github.com/positions/ada0319c-b57d-11e6-9c3c-d13afadb65a8"
#     },
#     {
#         "company": "Booking.com",
#         "company_logo": "http://github-jobs.s3.amazonaws.com/c9146712-b308-11e6-875e-1fa7ba6a7f42.jpeg",
#         "company_url": "http://www.workingatbooking.com",
#         "created_at": "Fri Nov 25 12:15:59 UTC 2016",
#         "description": "<p>Would you like to translate terabytes of data into unforgettable holidays for millions of people around the globe? Booking.com, the world\u2019s largest accommodation booking website, is looking for rock star Data Scientists to add to join our highly successful Personalization Team within the Front End department.</p>\n\n<p>This product development team crunches endless amounts of data to provide our customers with the best possible experience. They focus on anything from understanding and predicting market data, to ranking all properties on our website, and providing our customers with the most relevant personalized recommendations.</p>\n\n<p>As a Data Scientist you\u2019ll work side by side with Developers, Designers and Product Owners, and take full ownership of your work \u2013 from the initial idea-generation phase to the implementation of the final product on our website. Our ideal candidate is result-focused, innovative and has solid quantitative background and a good business understanding.</p>\n\n<p>B.responsible</p>\n\n<p>Work in a multi-disciplined team where you\u2019ll take full ownership of turning discoveries and ideas into machine learning models. You\u2019ll use the model\u2019s output to create and improve products for our customers, preferably in short development cycles\nResearch &amp; Development on how to improve customers\u2019 experience, by using our vast amount of data\nActively contribute to taking Data Science at Booking.com to the next level\nB.skilled</p>\n\n<p>Minimum two years of relevant work experience\nMasters, PhD, or equivalent experience in a quantitative field (Computer Science, Mathematics, Engineering, Artificial Intelligence, etc.)\nExcellent English communication skills; the ability to convey your message to team members and other stakeholders\nPrior experience with a few of the following models: Logistic Regression, Support Vector Machines, (Deep) Neural Networks, Hidden Markov Models, Conditional Random Fields, Game Theory, Mechanism Design and/or Latent Dirichlet Allocation\nRequired</p>\n\n<p>Experience with at least one scripting language, e.g. R, Octave, and one programming language, e.g. Python, Perl, C/C++, Java\nExposure to SQL and relational databases\nPreferred</p>\n\n<p>Experience implementing a real-world Recommender or Ranking system\nWorked with the Hadoop Ecosystem\nImplemented multi-core/distributed software, preferably in a Linux environment\nB.offered</p>\n\n<p>We are a performance-based company that offers career advancement and lucrative compensation, including bonuses and stock potential.  We also offer what we call the \u201cBooking Deal\u201d with other competitive perks and benefits.  IT has monthly hackathons, trainings and attends/speaks at global conferences.</p>\n\n<p>This position is open to worldwide candidates and in the case of relocation, we will assist you with a generous relocation package, ensuring a smooth transition to working and living in Amsterdam.  We have successfully relocated 200+ IT professionals to Amsterdam in the last year!</p>\n\n<p>The hiring company Booking.com BV is the company behind Booking.com\u2122, the market leading online accommodation reservation service in the world. Booking.com BV is looking for a Data Scientist - Machine Learning in Amsterdam, the Netherlands. All references to \u201cBooking.com&quot; refer to Booking.com BV.</p>\n",
#         "how_to_apply": "<p>Apply: <a href=\"http://grnh.se/62yip51\">http://grnh.se/62yip51</a></p>\n",
#         "id": "cf34f21a-b308-11e6-9192-6f14e27e77e8",
#         "location": "Amsterdam",
#         "title": "Data Scientist \u2013 Machine Learning",
#         "type": "Full Time",
#         "url": "http://jobs.github.com/positions/cf34f21a-b308-11e6-9192-6f14e27e77e8"
#     },
#     {
#         "company": "Booking.com",
#         "company_logo": "http://github-jobs.s3.amazonaws.com/4732bf50-b308-11e6-8f4f-d6abae6872df.jpeg",
#         "company_url": "http://www.workingatbooking.com",
#         "created_at": "Fri Nov 25 12:12:50 UTC 2016",
# ...
#         "company_logo": "http://github-jobs.s3.amazonaws.com/c8d2ddfe-a5cc-11e6-9efa-20771e165637.png",
#         "company_url": "https://www.textnow.com/",
#         "created_at": "Tue Nov 08 16:44:37 UTC 2016",
#         "description": "<p>The telecom industry has far too long been dominated by the big, the bureaucratic and the unimaginative. Now is the time for someone to take this industry on with something better.</p>\n\n<p>We are changing the industry by providing what others cannot - a better user experience, better customer service, continual innovation, and most importantly \u2013 transparent pricing.</p>\n\n<p>We are looking for well-rounded iOS developers to join our development team and help us in our mission of building a product that disrupts the wireless industry. You will play a pivotal role on our team, from building beautiful user interfaces to improving the performance and stability of our app to ensuring that every phone call for each and every customer is crystal clear. Most importantly, the work you do everyday will impact and change the way people communicate on a day-to-day basis.</p>\n\n<p>Join us to make a BIG impact as part of the disrupting force that&#39;s changing telecommunications forever.</p>\n\n<p>What you&#39;ll do:</p>\n\n<ul>\n<li>Write clean, maintainable iOS applications in Objective-C using the latest iOS programming techniques</li>\n<li>Take full ownership of projects from design to deployment</li>\n<li>Collaborate closely with other engineers and designers</li>\n<li>Deploy your features to millions of users - your work will have an immediate impact</li>\n<li>Become an important member of an autonomous, cross-functional team</li>\n</ul>\n\n<p><strong>Requirements</strong></p>\n\n<p>Who you are:</p>\n\n<ul>\n<li>You have a bachelor&#39;s degree in Computer Science, Computer Engineering, Software Engineering, or equivalent practical experience</li>\n<li>You have strong fundamentals - you know your data structures, algorithms, and OO design</li>\n<li>You have excellent problem solving, critical thinking and communication skills</li>\n<li>You have a deep understanding of iOS and Cocoa design patterns</li>\n<li>You are experienced with a variety of iOS frameworks</li>\n<li>You have experience writing unit tests and testable code</li>\n<li>You value the success of your team and their mission</li>\n</ul>\n\n<p><strong>Benefits</strong></p>\n\n<ul>\n<li>Impactful work</li>\n<li>TextNow-powered smartphone</li>\n<li>Competitive total compensation package</li>\n<li>Catered breakfast and lunch</li>\n<li>Professional development</li>\n<li>Fitness center on site, games room</li>\n<li>Multiple social events (milestones celebrations, escape rooms, rock climbing)</li>\n</ul>\n\n<p><em>TextNow embraces and promotes diversity, inclusion and acceptance in our workplace. We are proud to be an equal opportunity employer and we select applicants on the basis of their qualifications. We encourage applications from all qualified individuals and will reasonably accommodate individuals with accessibility needs. Candidates requiring accommodation during the recruitment process are asked to contact the Human Resources team at <a href=\"mailto:Recruitment@textnow.com\">Recruitment@textnow.com</a></em></p>\n",
#         "how_to_apply": "<p>To apply visit our career page at <a href=\"http://about.textnow.com/careers/#openings-iOS-Developer\">http://about.textnow.com/careers/#openings-iOS-Developer</a></p>\n",
#         "id": "42e14a90-a5d2-11e6-9bad-c0590158de94",
#         "location": "Waterloo, Canada",
#         "title": "Sr. iOS Developer",
#         "type": "Full Time",
#         "url": "http://jobs.github.com/positions/42e14a90-a5d2-11e6-9bad-c0590158de94"
#     },
#     {
#         "company": "Booking.com",
#         "company_logo": "http://github-jobs.s3.amazonaws.com/b89761ee-526b-11e6-8d0c-3ec5ffda0b49.png",
#         "company_url": "http://Booking.com",
#         "created_at": "Tue Nov 08 10:41:10 UTC 2016",
#         "description": "<p>Would you like to translate terabytes of data into unforgettable holidays for millions of people around the globe? Booking.com, the world\u2019s largest accommodation booking website, is looking for rock star Data Scientists to add to join our highly successful Personalization Team within the Front End department.</p>\n\n<p>This product development team crunches endless amounts of data to provide our customers with the best possible experience. They focus on anything from understanding and predicting market data, to ranking all properties on our website, and providing our customers with the most relevant personalized recommendations.</p>\n\n<p>As a Data Scientist you\u2019ll work side by side with Developers, Designers and Product Owners, and take full ownership of your work \u2013 from the initial idea-generation phase to the implementation of the final product on our website. Our ideal candidate is result-focused, innovative and has solid quantitative background and a good business understanding.</p>\n\n<p>B.responsible</p>\n\n<ul>\n<li>Work in a multi-disciplined team where you\u2019ll take full ownership of turning discoveries and ideas into machine learning models. You\u2019ll use the model\u2019s output to create and improve products for our customers, preferably in short development cycles</li>\n<li>Research &amp; Development on how to improve customers\u2019 experience, by using our vast amount of data</li>\n<li>Actively contribute to taking Data Science at Booking.com to the next level</li>\n</ul>\n\n<p>B.skilled</p>\n\n<ul>\n<li>Minimum two years of relevant work experience</li>\n<li>Masters, PhD, or equivalent experience in a quantitative field (Computer Science, Mathematics, Engineering, Artificial Intelligence, etc.)</li>\n<li>Excellent English communication skills; the ability to convey your message to team members and other stakeholders</li>\n<li>Prior experience with a few of the following models: Logistic Regression, Support Vector Machines, (Deep) Neural Networks, Hidden Markov Models, Conditional Random Fields, Game Theory, Mechanism Design and/or Latent Dirichlet Allocation</li>\n</ul>\n\n<p>Required</p>\n\n<ul>\n<li>Experience with at least one scripting language, e.g. R, Octave, and one programming language, e.g. Python, Perl, C/C++, Java</li>\n<li>Exposure to SQL and relational databases</li>\n</ul>\n\n<p>Preferred</p>\n\n<ul>\n<li>Experience implementing a real-world Recommender or Ranking system</li>\n<li>Worked with the Hadoop Ecosystem</li>\n<li>Implemented multi-core/distributed software, preferably in a Linux environment</li>\n</ul>\n\n<p>B.offered</p>\n\n<p>We are a performance-based company that offers career advancement and lucrative compensation, including bonuses and stock potential.  We also offer what we call the \u201cBooking Deal\u201d with other competitive perks and benefits.  IT has monthly hackathons, trainings and attends/speaks at global conferences.</p>\n\n<p>This position is open to worldwide candidates and in the case of relocation, we will assist you with a generous relocation package, ensuring a smooth transition to working and living in Amsterdam.  We have successfully relocated 200+ IT professionals to Amsterdam in the last year!</p>\n\n<p>The hiring company Booking.com BV is the company behind Booking.com\u2122, the market leading online accommodation reservation service in the world. Booking.com BV is looking for a Data Scientist - Machine Learning in Amsterdam, the Netherlands. All references to \u201cBooking.com&quot; refer to Booking.com BV.</p>\n",
#         "how_to_apply": "<p>Apply via this link:</p>\n\n<p><a href=\"http://grnh.se/rmwec5\">http://grnh.se/rmwec5</a></p>\n",
#         "id": "9862547e-526b-11e6-9c98-836c3746873d",
#         "location": "Amsterdam",
#         "title": "Data Scientist \u2013 Machine Learning",
#         "type": "Full Time",
#         "url": "http://jobs.github.com/positions/9862547e-526b-11e6-9c98-836c3746873d"
#     },
#     {
#         "company": "Booking.com",
#         "company_logo": "http://github-jobs.s3.amazonaws.com/71ef5eaa-526a-11e6-8cf8-ea0718d97cbe.png",
#         "company_url": "http://Booking.com",
#         "created_at": "Tue Nov 08 10:40:20 UTC 2016",
#         "description": "<p>Booking.com is looking for data savvy professionals to join our team of data scientists. You will be working with stakeholders throughout the company to generate understanding, strategy and suggest actions based on data. If you consider yourself to be that unique hybrid of data hacker, business analyst, communicator and mentor that maintains a strong customer focus and values pragmatism over perfection, then we\u2019d like to hear from you.</p>\n\n<p>There are several data science teams within Booking.com each consisting of 3-8 people. All of these teams have their own scope within the business; we have Data Scientists focusing on the front end of our website, content of the pages, demands of our products, customer satisfaction and loyalty. Every team takes full responsibility for all data analysis within their area; however there is also considerable collaboration amongst teams. We often align on business goals, learn from each other and socialize after work almost every Friday.</p>\n\n<p>B.responsible</p>\n\n<ul>\n<li>Transform large, complex datasets into pragmatic, actionable insights.<br></li>\n<li>Leverage data to identify, quantify and influence tangible business gain.</li>\n<li>Ability to see beyond the numbers, be the voice of data when communicating to decision makers, product owners and team leaders.</li>\n<li>Have the capacity to thrive in our fast-paced environment, adapt quickly and take ownership of your work.</li>\n<li>Challenge ideas and methods while working together with talented, highly skilled team members.</li>\n</ul>\n\n<p>B.skilled</p>\n\n<ul>\n<li>Minimum 3 years of experience in a relevant role</li>\n<li>Experience solving real problems using data mining techniques and with statistical rigor</li>\n<li>Masters, PhD, or equivalent experience in a quantitative field (computer science, physics, mathematics, engineering, bioinformatics, etc.)</li>\n<li>Strong technical skills regarding data analysis, machine learning and programming. Strong working knowledge of, Python, Hadoop, SQL, R and/or Excel.</li>\n<li>Excellent communication skills; the ability to convey complex analysis results clearly and with conviction to all levels of stakeholders</li>\n</ul>\n\n<p>B.offered</p>\n\n<p>We are a performance-based company that offers career advancement and lucrative compensation, including bonuses and stock potential.  We also offer what we call the \u201cBooking Deal\u201d with other competitive perks and benefits.  IT also has monthly hackathons, training and attends/speaks at global conferences.</p>\n\n<p>This position is open to worldwide candidates and in the case of relocation, we will assist you with a generous relocation package, ensuring a smooth transition to working and living in Amsterdam.  We have successfully relocated 200+ IT professionals to Amsterdam in the last year!</p>\n\n<p>The hiring company Booking.com BV is the company behind Booking.com\u2122, the market leading online accommodation reservation service in the world. Booking.com BV is looking for a Data Scientist - Analytics in Amsterdam, the Netherlands. All references to \u201cBooking.com&quot; refer to Booking.com BV.</p>\n",
#         "how_to_apply": "<p>Apply via this link:</p>\n\n<p><a href=\"http://grnh.se/g1tl6m\">http://grnh.se/g1tl6m</a></p>\n",
#         "id": "bc0bbfa6-526a-11e6-8092-d5f4dbf20b0f",
#         "location": "Amsterdam",
#         "title": "Data Scientist \u2013 Analytics",
#         "type": "Full Time",
#         "url": "http://jobs.github.com/positions/bc0bbfa6-526a-11e6-8092-d5f4dbf20b0f"
#     },
#     {
#         "company": "Kaggle",
#         "company_logo": "http://github-jobs.s3.amazonaws.com/8b90dd46-39df-11e6-9583-738af4d1e73c.png",
#         "company_url": "http://www.kaggle.com",
#         "created_at": "Mon Nov 07 08:42:27 UTC 2016",
#         "description": "<p>Come help us create the future of Kaggle and in doing so, help shape the future of data science.</p>\n\n<p>As background, Kaggle is best known for running machine learning competitions. We have a community of over 700K data scientists who come to Kaggle to learn, compete, and collaborate on the cutting edge of machine learning to solve business and research problems for organizations like Facebook, NASA, and GE.</p>\n\n<p>In our next chapter, Kaggle is expanding to become the place where data scientists share code and analysis in a reproducible way. We&#39;re building this platform for data science collaboration (the closest analogy is Github for data science) around our thriving community. As part of our small team, you&#39;ll be a part of designing and building this platform in its early stages. We don&#39;t expect you to know everything coming in, so we&#39;ll pair you with mentors who will help you grow and develop your skills.</p>\n\n<p>We like working remotely: a lot of our team is distributed. We prefer US-based timezones but will hire the right candidate anywhere in the world. If you\u2019re in the San Francisco Bay Area or interested in relocating here, you\u2019ll enjoy our easy-going office culture and all the beauty the Bay Area has to offer.</p>\n\n<p><strong>What you&#39;ll do</strong></p>\n\n<ul>\n<li>Architect and create new site features, ranging from discussing wireframes to creating the data model and deploying the end result.</li>\n<li>Implement local tooling to facilitate users transferring their analytics between local environments and Kaggle&#39;s infrastructure.</li>\n<li>Build features in our current web stack (C#, ASP.NET MVC,  TypeScript, React, SQL Server, and Azure).</li>\n<li>Create and build on our services layer (which includes Linux,  Docker, and Python for running user code).</li>\n<li>Measure, optimize, and scale Kaggle\u2019s infrastructure.</li>\n<li>Ship every day.</li>\n</ul>\n\n<p><strong>What we&#39;re looking for</strong></p>\n\n<ul>\n<li>You have solid programming skills from regularly shipping code.</li>\n<li>You have  exposure to web programming and  modern practices.</li>\n<li>You&#39;re experienced with a stack based on C#, ASP.NET MVC, TypeScript, React, SQL Server, and Azure (or are excited to pick it up).</li>\n<li>You\u2019re motivated, self-directed, a good communicator and have strong telecommuting skills (our engineering team is spread around the world).</li>\n</ul>\n\n<p><strong>What will set you apart</strong></p>\n\n<ul>\n<li>You have a history of open source contributions and helping the broader software engineering community (through Github, StackOverflow, a blog, or the like).</li>\n<li>You are excited about data and curious to learn more about machine learning.</li>\n</ul>\n\n<p><strong>What we offer</strong></p>\n\n<ul>\n<li>A low ego environment where you can give and receive direct feedback.</li>\n<li>Transparent leadership that openly shares the thinking behind company direction and strategy.</li>\n<li>A flat organization where you are encouraged to contribute to company direction and strategy.</li>\n<li>The opportunity to help shape the future of data science and machine learning.</li>\n<li>A flexible work environment: work from where you&#39;re most productive.</li>\n<li>Stock in a company that has the potential to transform the way data science is done.</li>\n</ul>\n",
#         "how_to_apply": "<p>Apply here:\n<a href=\"https://kaggle.applytojob.com/apply/GjSjOi/Fullstack-Engineer?source=Github\">https://kaggle.applytojob.com/apply/GjSjOi/Fullstack-Engineer?source=Github</a></p>\n",
#         "id": "a0389ac2-39df-11e6-9bb0-7b3faa3729cc",
#         "location": "San Francisco or Remote",
#         "title": "Full-Stack Engineer (C#, ASP.NET MVC and React)",
#         "type": "Full Time",
#         "url": "http://jobs.github.com/positions/a0389ac2-39df-11e6-9bb0-7b3faa3729cc"
#     }
# ]

# %%
first_job = json_response.pop()
first_job.keys()
# Out:
# dict_keys(['id', 'how_to_apply', 'description', 'location', 'company_url', 'title', 'company_logo', 'type', 'url', 'created_at', 'company'])

# %%
from IPython.display import Image
image_url = first_job['company_logo']
Image(url=image_url)
# Out:
# <img src="http://github-jobs.s3.amazonaws.com/8b90dd46-39df-11e6-9583-738af4d1e73c.png"/>

# %%
print(first_job['type'], 
      first_job['company'], 
      first_job['company_url'],
      first_job['title'],
      first_job['location'],
      first_job['created_at'],
      sep='\n')
# Out:
# Full Time
# Kaggle
# http://www.kaggle.com
# Full-Stack Engineer (C#, ASP.NET MVC and React)
# San Francisco or Remote
# Mon Nov 07 08:42:27 UTC 2016

# %%
from IPython.core.display import display, HTML

display(HTML(first_job['description']))
# Out:
# <p>Come help us create the future of Kaggle and in doing so, help shape the future of data science.</p>
#
# <p>As background, Kaggle is best known for running machine learning competitions. We have a community of over 700K data scientists who come to Kaggle to learn, compete, and collaborate on the cutting edge of machine learning to solve business and research problems for organizations like Facebook, NASA, and GE.</p>
#
# <p>In our next chapter, Kaggle is expanding to become the place where data scientists share code and analysis in a reproducible way. We&#39;re building this platform for data science collaboration (the closest analogy is Github for data science) around our thriving community. As part of our small team, you&#39;ll be a part of designing and building this platform in its early stages. We don&#39;t expect you to know everything coming in, so we&#39;ll pair you with mentors who will help you grow and develop your skills.</p>
#
# <p>We like working remotely: a lot of our team is distributed. We prefer US-based timezones but will hire the right candidate anywhere in the world. If you’re in the San Francisco Bay Area or interested in relocating here, you’ll enjoy our easy-going office culture and all the beauty the Bay Area has to offer.</p>
#
# <p><strong>What you&#39;ll do</strong></p>
#
# <ul>
# <li>Architect and create new site features, ranging from discussing wireframes to creating the data model and deploying the end result.</li>
# <li>Implement local tooling to facilitate users transferring their analytics between local environments and Kaggle&#39;s infrastructure.</li>
# <li>Build features in our current web stack (C#, ASP.NET MVC,  TypeScript, React, SQL Server, and Azure).</li>
# <li>Create and build on our services layer (which includes Linux,  Docker, and Python for running user code).</li>
# <li>Measure, optimize, and scale Kaggle’s infrastructure.</li>
# <li>Ship every day.</li>
# </ul>
#
# <p><strong>What we&#39;re looking for</strong></p>
#
# <ul>
# <li>You have solid programming skills from regularly shipping code.</li>
# <li>You have  exposure to web programming and  modern practices.</li>
# <li>You&#39;re experienced with a stack based on C#, ASP.NET MVC, TypeScript, React, SQL Server, and Azure (or are excited to pick it up).</li>
# <li>You’re motivated, self-directed, a good communicator and have strong telecommuting skills (our engineering team is spread around the world).</li>
# </ul>
#
# <p><strong>What will set you apart</strong></p>
#
# <ul>
# <li>You have a history of open source contributions and helping the broader software engineering community (through Github, StackOverflow, a blog, or the like).</li>
# <li>You are excited about data and curious to learn more about machine learning.</li>
# </ul>
#
# <p><strong>What we offer</strong></p>
#
# <ul>
# <li>A low ego environment where you can give and receive direct feedback.</li>
# <li>Transparent leadership that openly shares the thinking behind company direction and strategy.</li>
# <li>A flat organization where you are encouraged to contribute to company direction and strategy.</li>
# <li>The opportunity to help shape the future of data science and machine learning.</li>
# <li>A flexible work environment: work from where you&#39;re most productive.</li>
# <li>Stock in a company that has the potential to transform the way data science is done.</li>
# </ul>

# %%
display(HTML(first_job['how_to_apply']))
# Out:
# <p>Apply here:
# <a href="https://kaggle.applytojob.com/apply/GjSjOi/Fullstack-Engineer?source=Github">https://kaggle.applytojob.com/apply/GjSjOi/Fullstack-Engineer?source=Github</a></p>

# %%
print(first_job['id'], 
      first_job['url'],
      sep='\n')
# Out:
# a0389ac2-39df-11e6-9bb0-7b3faa3729cc
# http://jobs.github.com/positions/a0389ac2-39df-11e6-9bb0-7b3faa3729cc

# %%
from sqlalchemy import create_engine, MetaData, Table, Column, Integer, String, ForeignKey, DateTime

engine = create_engine('sqlite:///:memory:', echo=True)
metadata = MetaData()

company_table = Table('company', metadata,
                      Column('id', Integer, primary_key=True),
                      Column('name', String, nullable=False),
                      Column('url', String, unique=True),
                      Column('logo_url', String))

job_table = Table('job', metadata,
                  Column('id', Integer, primary_key=True),
                  Column('company_id', None, ForeignKey('company.id'), nullable=False),
                  Column('type_', Integer),
                  Column('title', String, nullable=False),
                  Column('description', String),
                  Column('how_to_apply', String))

location_table = Table('location', metadata,
                      Column('job_id', None, ForeignKey('job.id'), primary_key=True),
                      Column('description', String),
                      Column('remote_ok', Integer))


github_metadata_table = Table('github_metadata', metadata,
                              Column('job_id', None, ForeignKey('job.id'), primary_key=True),
                              Column('github_id', String, unique=True),
                              Column('url', String, nullable=False),
                              Column('created_at', DateTime, nullable=False))

metadata.create_all(engine)
conn = engine.connect()
# Out:
# 2016-12-07 23:32:24,804 INFO sqlalchemy.engine.base.Engine SELECT CAST('test plain returns' AS VARCHAR(60)) AS anon_1
# 2016-12-07 23:32:24,807 INFO sqlalchemy.engine.base.Engine ()
# 2016-12-07 23:32:24,809 INFO sqlalchemy.engine.base.Engine SELECT CAST('test unicode returns' AS VARCHAR(60)) AS anon_1
# 2016-12-07 23:32:24,811 INFO sqlalchemy.engine.base.Engine ()
# 2016-12-07 23:32:24,813 INFO sqlalchemy.engine.base.Engine PRAGMA table_info("location")
# 2016-12-07 23:32:24,814 INFO sqlalchemy.engine.base.Engine ()
# 2016-12-07 23:32:24,816 INFO sqlalchemy.engine.base.Engine PRAGMA table_info("job")
# 2016-12-07 23:32:24,820 INFO sqlalchemy.engine.base.Engine ()
# 2016-12-07 23:32:24,822 INFO sqlalchemy.engine.base.Engine PRAGMA table_info("github_metadata")
# 2016-12-07 23:32:24,831 INFO sqlalchemy.engine.base.Engine ()
# 2016-12-07 23:32:24,833 INFO sqlalchemy.engine.base.Engine PRAGMA table_info("company")
# 2016-12-07 23:32:24,837 INFO sqlalchemy.engine.base.Engine ()
# 2016-12-07 23:32:24,840 INFO sqlalchemy.engine.base.Engine
# CREATE TABLE company (
# 	id INTEGER NOT NULL,
# 	name VARCHAR NOT NULL,
# 	url VARCHAR,
# 	logo_url VARCHAR,
# 	PRIMARY KEY (id),
# 	UNIQUE (url)
# )
#
#
# 2016-12-07 23:32:24,841 INFO sqlalchemy.engine.base.Engine ()
# 2016-12-07 23:32:24,843 INFO sqlalchemy.engine.base.Engine COMMIT
# 2016-12-07 23:32:24,862 INFO sqlalchemy.engine.base.Engine
# CREATE TABLE job (
# 	id INTEGER NOT NULL,
# 	company_id INTEGER NOT NULL,
# 	type_ INTEGER,
# 	title VARCHAR NOT NULL,
# 	description VARCHAR,
# 	how_to_apply VARCHAR,
# 	PRIMARY KEY (id),
# 	FOREIGN KEY(company_id) REFERENCES company (id)
# )
#
#
# 2016-12-07 23:32:24,868 INFO sqlalchemy.engine.base.Engine ()
# 2016-12-07 23:32:24,870 INFO sqlalchemy.engine.base.Engine COMMIT
# 2016-12-07 23:32:24,871 INFO sqlalchemy.engine.base.Engine
# CREATE TABLE location (
# 	job_id INTEGER NOT NULL,
# 	description VARCHAR,
# 	remote_ok INTEGER,
# 	PRIMARY KEY (job_id),
# 	FOREIGN KEY(job_id) REFERENCES job (id)
# )
#
#
# 2016-12-07 23:32:24,872 INFO sqlalchemy.engine.base.Engine ()
# 2016-12-07 23:32:24,874 INFO sqlalchemy.engine.base.Engine COMMIT
# 2016-12-07 23:32:24,876 INFO sqlalchemy.engine.base.Engine
# CREATE TABLE github_metadata (
# 	job_id INTEGER NOT NULL,
# 	github_id VARCHAR,
# 	url VARCHAR NOT NULL,
# 	created_at DATETIME NOT NULL,
# 	PRIMARY KEY (job_id),
# 	FOREIGN KEY(job_id) REFERENCES job (id),
# 	UNIQUE (github_id)
# )
#
#
# 2016-12-07 23:32:24,878 INFO sqlalchemy.engine.base.Engine ()
# 2016-12-07 23:32:24,880 INFO sqlalchemy.engine.base.Engine COMMIT

# %%
from enum import Enum

class JobType(Enum):
    full_time = 1
    part_time = 2
    
    @staticmethod
    def from_string(string):
        if string.lower() == 'full time' or string.lower() == 'full-time':
            return JobType.full_time
        elif string.lower() == 'part time' or string.lower() == 'part-time':
            return JobType.part_time
        else:
            raise RuntimeError('JobType not supported: {}'.format(string))

# %%
def insert_company(name, url, logo_url, connection=conn):
    """Inserts a new entry in company_table and returns its id."""
    insert = company_table.insert().values(name=name, url=url, logo_url=logo_url)
    result = connection.execute(insert)
    return result.inserted_primary_key[0]

# %%
def insert_location(job_id, description, connection=conn):
    """Inserts a new entry in location_table and returns its job_id."""
    insert = location_table.insert().values(job_id=job_id, description=description, 
                                       remote_ok=int('remote' in description.lower() 
                                                     or 'telecommute' in description.lower())) 
    result = connection.execute(insert)
    return result.inserted_primary_key[0]

# %%
import datetime
created_at_pattern = '%a %b %d %X %Z %Y'

def insert_github_metadata(job_id, github_id, url, created_at_str, connection=conn):
    """Inserts a new entry in github_metadata_table and returns its job_id."""
    insert = github_metadata_table.insert().values(job_id=job_id, github_id=github_id, url=url,
                                       created_at=datetime.datetime.strptime(created_at_str, created_at_pattern))
    result = connection.execute(insert)
    return result.inserted_primary_key[0]

# %%
def insert_job(company_id, type_str, title, description, how_to_apply, connection=conn):
    """Inserts a new entry in job_table and returns its id."""
    insert = job_table.insert().values(company_id=company_id, 
                                       type_=JobType.from_string(type_str).value, 
                                       title=title, description=description, how_to_apply=how_to_apply) 
    result = connection.execute(insert)
    return result.inserted_primary_key[0]
# Out:
# int

# %%
from sqlalchemy.sql import select

def select_or_insert_company(name, url, logo_url, connection=conn):
    """Returns the company id either by selecting from or inserting in company_table"""
    s = select([company_table]).where(company_table.c.url == url)
    result = connection.execute(s).fetchone()
    if (result is not None):
        return result['id']
    else:
        new_id = insert_company(name, url, logo_url, connection)
        return new_id

# %%
def select_or_insert_job(company_name, company_url, company_logo_url, 
                         github_id, github_url, github_created_at_str,
                         type_str, title, description, how_to_apply,
                         location_description):
    """
    Returns the job id either by selecting from or inserting in job_table.
    
    This function might also insert new location, github_metadata and company entries.
    """
    s = select([github_metadata_table]).where(github_metadata_table.c.github_id == github_id)
    result = conn.execute(s).fetchone()
    if (result is not None):
        return result['job_id']
    else:
        with engine.begin() as transaction:
            company_id = select_or_insert_company(company_name, company_url, company_logo_url, transaction)
            job_id = insert_job(company_id, type_str, title, description, how_to_apply, transaction)
            insert_github_metadata(job_id, github_id, github_url, github_created_at_str, transaction)
            insert_location(job_id, location_description, transaction)
            
        return job_id

# %%
for job in json_response:
    select_or_insert_job(
        job['company'],
        job['company_url'],
        job['company_logo'],
        job['id'],
        job['url'],
        job['created_at'],
        job['type'],
        job['title'],
        job['description'],
        job['how_to_apply'],
        job['location']
    )
# Out:
# 2016-12-08 00:02:09,083 INFO sqlalchemy.engine.base.Engine SELECT github_metadata.job_id, github_metadata.github_id, github_metadata.url, github_metadata.created_at
# FROM github_metadata
# WHERE github_metadata.github_id = ?
# 2016-12-08 00:02:09,086 INFO sqlalchemy.engine.base.Engine ('beb74684-bbed-11e6-8197-64e617b51adf',)
# 2016-12-08 00:02:09,088 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2016-12-08 00:02:09,090 INFO sqlalchemy.engine.base.Engine SELECT company.id, company.name, company.url, company.logo_url
# FROM company
# WHERE company.url = ?
# 2016-12-08 00:02:09,091 INFO sqlalchemy.engine.base.Engine ('http://nmi.com',)
# 2016-12-08 00:02:09,092 INFO sqlalchemy.engine.base.Engine INSERT INTO company (name, url, logo_url) VALUES (?, ?, ?)
# 2016-12-08 00:02:09,094 INFO sqlalchemy.engine.base.Engine ('Network Merchants, LLC', 'http://nmi.com', 'http://github-jobs.s3.amazonaws.com/a1b8f9ec-bbed-11e6-960a-b1034c4cd71b.png')
# 2016-12-08 00:02:09,098 INFO sqlalchemy.engine.base.Engine INSERT INTO job (company_id, type_, title, description, how_to_apply) VALUES (?, ?, ?, ?, ?)
# 2016-12-08 00:02:09,099 INFO sqlalchemy.engine.base.Engine (1, 1, 'Linux Systems Engineer', '<p><strong>Summary</strong> </p>\n\n<ul>\n<li>The engineering team at NMI is a small, agile group that works closely together but requires independen ... (2957 characters truncated) ... >\n<li>Jira and Confluence for task and project management</li>\n<li>Computer</li>\n<li>Printer</li>\n<li>Fax Machine</li>\n<li>Scanner</li>\n</ul>\n', '<p>Please E-mail your resume to <a href="mailto:hr@nmi.com">hr@nmi.com</a></p>\n')
# 2016-12-08 00:02:09,106 INFO sqlalchemy.engine.base.Engine INSERT INTO github_metadata (job_id, github_id, url, created_at) VALUES (?, ?, ?, ?)
# 2016-12-08 00:02:09,107 INFO sqlalchemy.engine.base.Engine (1, 'beb74684-bbed-11e6-8197-64e617b51adf', 'http://jobs.github.com/positions/beb74684-bbed-11e6-8197-64e617b51adf', '2016-12-06 19:54:25.000000')
# 2016-12-08 00:02:09,110 INFO sqlalchemy.engine.base.Engine INSERT INTO location (job_id, description, remote_ok) VALUES (?, ?, ?)
# 2016-12-08 00:02:09,111 INFO sqlalchemy.engine.base.Engine (1, 'Roselle, IL', 0)
# 2016-12-08 00:02:09,115 INFO sqlalchemy.engine.base.Engine COMMIT
# 2016-12-08 00:02:09,118 INFO sqlalchemy.engine.base.Engine SELECT github_metadata.job_id, github_metadata.github_id, github_metadata.url, github_metadata.created_at
# FROM github_metadata
# WHERE github_metadata.github_id = ?
# 2016-12-08 00:02:09,119 INFO sqlalchemy.engine.base.Engine ('61433012-baf8-11e6-8d18-1baa36e6dbf5',)
# 2016-12-08 00:02:09,120 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2016-12-08 00:02:09,123 INFO sqlalchemy.engine.base.Engine SELECT company.id, company.name, company.url, company.logo_url
# FROM company
# WHERE company.url = ?
# 2016-12-08 00:02:09,125 INFO sqlalchemy.engine.base.Engine ('http://www.scm-lp.com',)
# 2016-12-08 00:02:09,126 INFO sqlalchemy.engine.base.Engine INSERT INTO company (name, url, logo_url) VALUES (?, ?, ?)
# 2016-12-08 00:02:09,128 INFO sqlalchemy.engine.base.Engine ('Stevens Capital Management LP', 'http://www.scm-lp.com', 'http://github-jobs.s3.amazonaws.com/5df90c6a-baf8-11e6-8a38-492033c01d86.png')
# 2016-12-08 00:02:09,130 INFO sqlalchemy.engine.base.Engine INSERT INTO job (company_id, type_, title, description, how_to_apply) VALUES (?, ?, ?, ?, ?)
# 2016-12-08 00:02:09,132 INFO sqlalchemy.engine.base.Engine (2, 1, 'Implementation Developer', '<p>Stevens Capital Management LP (“SCM”) is a registered investment adviser that manages a multi-billion dollar hedge fund that has been in business  ... (1396 characters truncated) ... Experience with relational databases including Sybase, SQL Server and Oracle is a plus.</li>\n<li>Experience with GUI design is a plus.</li>\n</ul>\n', '<p>Please submit your resume to: <a href="mailto:recruiting@scm-lp.com">recruiting@scm-lp.com</a></p>\n\n<p>Website: <a href="http://www.scm-lp.com">www.scm-lp.com</a></p>\n')
# 2016-12-08 00:02:09,138 INFO sqlalchemy.engine.base.Engine INSERT INTO github_metadata (job_id, github_id, url, created_at) VALUES (?, ?, ?, ?)
# 2016-12-08 00:02:09,139 INFO sqlalchemy.engine.base.Engine (2, '61433012-baf8-11e6-8d18-1baa36e6dbf5', 'http://jobs.github.com/positions/61433012-baf8-11e6-8d18-1baa36e6dbf5', '2016-12-05 14:38:11.000000')
# 2016-12-08 00:02:09,141 INFO sqlalchemy.engine.base.Engine INSERT INTO location (job_id, description, remote_ok) VALUES (?, ?, ?)
# 2016-12-08 00:02:09,142 INFO sqlalchemy.engine.base.Engine (2, 'Radnor, PA. USA', 0)
# 2016-12-08 00:02:09,143 INFO sqlalchemy.engine.base.Engine COMMIT
# 2016-12-08 00:02:09,145 INFO sqlalchemy.engine.base.Engine SELECT github_metadata.job_id, github_metadata.github_id, github_metadata.url, github_metadata.created_at
# FROM github_metadata
# WHERE github_metadata.github_id = ?
# 2016-12-08 00:02:09,147 INFO sqlalchemy.engine.base.Engine ('6d409aaa-b8c6-11e6-8408-7debc09d256f',)
# 2016-12-08 00:02:09,149 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2016-12-08 00:02:09,151 INFO sqlalchemy.engine.base.Engine SELECT company.id, company.name, company.url, company.logo_url
# FROM company
# WHERE company.url = ?
# 2016-12-08 00:02:09,154 INFO sqlalchemy.engine.base.Engine ('http://www.genepeeks.com',)
# 2016-12-08 00:02:09,157 INFO sqlalchemy.engine.base.Engine INSERT INTO company (name, url, logo_url) VALUES (?, ?, ?)
# 2016-12-08 00:02:09,159 INFO sqlalchemy.engine.base.Engine ('GenePeeks, Inc', 'http://www.genepeeks.com', 'http://github-jobs.s3.amazonaws.com/67ea79ea-b8c6-11e6-81ec-ba6eeed777c6.jpg')
# 2016-12-08 00:02:09,164 INFO sqlalchemy.engine.base.Engine INSERT INTO job (company_id, type_, title, description, how_to_apply) VALUES (?, ?, ?, ?, ?)
# 2016-12-08 00:02:09,166 INFO sqlalchemy.engine.base.Engine (3, 1, 'Software Engineer, DevOps', '<p>Job description</p>\n\n<p>GenePeeks is a data-driven genetics start-up pushing the boundaries of reproductive health care and computational geneti ... (2494 characters truncated) ... l>\n\n<p>Location:\nThis position will be located in the Boston or New York area.\n*GenePeeks will not offer visa sponsorship for this position</p>\n', '<p><a href="http://careers.genepeeks.com/o/software-engineer-devops=GitHub">http://careers.genepeeks.com/o/software-engineer-devops=GitHub</a></p>\n')
# 2016-12-08 00:02:09,167 INFO sqlalchemy.engine.base.Engine INSERT INTO github_metadata (job_id, github_id, url, created_at) VALUES (?, ?, ?, ?)
# 2016-12-08 00:02:09,169 INFO sqlalchemy.engine.base.Engine (3, '6d409aaa-b8c6-11e6-8408-7debc09d256f', 'http://jobs.github.com/positions/6d409aaa-b8c6-11e6-8408-7debc09d256f', '2016-12-02 19:36:23.000000')
# 2016-12-08 00:02:09,171 INFO sqlalchemy.engine.base.Engine INSERT INTO location (job_id, description, remote_ok) VALUES (?, ?, ?)
# 2016-12-08 00:02:09,174 INFO sqlalchemy.engine.base.Engine (3, 'Cambridge, MA', 0)
# 2016-12-08 00:02:09,175 INFO sqlalchemy.engine.base.Engine COMMIT
# 2016-12-08 00:02:09,179 INFO sqlalchemy.engine.base.Engine SELECT github_metadata.job_id, github_metadata.github_id, github_metadata.url, github_metadata.created_at
# FROM github_metadata
# WHERE github_metadata.github_id = ?
# 2016-12-08 00:02:09,183 INFO sqlalchemy.engine.base.Engine ('47b78b5e-b7ef-11e6-86f0-a00baabc0c92',)
# 2016-12-08 00:02:09,184 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2016-12-08 00:02:09,186 INFO sqlalchemy.engine.base.Engine SELECT company.id, company.name, company.url, company.logo_url
# FROM company
# WHERE company.url = ?
# 2016-12-08 00:02:09,187 INFO sqlalchemy.engine.base.Engine ('http://jobs.intel.com',)
# 2016-12-08 00:02:09,188 INFO sqlalchemy.engine.base.Engine INSERT INTO company (name, url, logo_url) VALUES (?, ?, ?)
# 2016-12-08 00:02:09,189 INFO sqlalchemy.engine.base.Engine ('Intel Corporation', 'http://jobs.intel.com', 'http://github-jobs.s3.amazonaws.com/0590279e-b7eb-11e6-92e0-095053d3f49d.png')
# 2016-12-08 00:02:09,191 INFO sqlalchemy.engine.base.Engine INSERT INTO job (company_id, type_, title, description, how_to_apply) VALUES (?, ?, ?, ?, ?)
# 2016-12-08 00:02:09,192 INFO sqlalchemy.engine.base.Engine (4, 1, 'Automated Driving SW Development Engineer', '<p>Employees of the Internet of Things Solutions Group (IOTG) have an exciting opportunity before them: To grow Intel&#39;s leadership position in th ... (4089 characters truncated) ... ated to helping Intel drive the next major growth inflection through productivity and new business models that are emerging as a result of IoT.</p>\n', '<p>Apply on company website: <a href="http://career.intel.com/TpLVa">http://career.intel.com/TpLVa</a></p>\n')
# 2016-12-08 00:02:09,194 INFO sqlalchemy.engine.base.Engine INSERT INTO github_metadata (job_id, github_id, url, created_at) VALUES (?, ?, ?, ?)
# 2016-12-08 00:02:09,196 INFO sqlalchemy.engine.base.Engine (4, '47b78b5e-b7ef-11e6-86f0-a00baabc0c92', 'http://jobs.github.com/positions/47b78b5e-b7ef-11e6-86f0-a00baabc0c92', '2016-12-02 11:49:17.000000')
# 2016-12-08 00:02:09,200 INFO sqlalchemy.engine.base.Engine INSERT INTO location (job_id, description, remote_ok) VALUES (?, ?, ?)
# 2016-12-08 00:02:09,202 INFO sqlalchemy.engine.base.Engine (4, 'Karlsruhe, Germany', 0)
# 2016-12-08 00:02:09,204 INFO sqlalchemy.engine.base.Engine COMMIT
# 2016-12-08 00:02:09,206 INFO sqlalchemy.engine.base.Engine SELECT github_metadata.job_id, github_metadata.github_id, github_metadata.url, github_metadata.created_at
# FROM github_metadata
# WHERE github_metadata.github_id = ?
# 2016-12-08 00:02:09,207 INFO sqlalchemy.engine.base.Engine ('88d7a11e-b7ef-11e6-8839-4baedb4f1c00',)
# 2016-12-08 00:02:09,209 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2016-12-08 00:02:09,211 INFO sqlalchemy.engine.base.Engine SELECT company.id, company.name, company.url, company.logo_url
# FROM company
# WHERE company.url = ?
# 2016-12-08 00:02:09,212 INFO sqlalchemy.engine.base.Engine ('http://jobs.intel.com',)
# 2016-12-08 00:02:09,217 INFO sqlalchemy.engine.base.Engine INSERT INTO job (company_id, type_, title, description, how_to_apply) VALUES (?, ?, ?, ?, ?)
# 2016-12-08 00:02:09,218 INFO sqlalchemy.engine.base.Engine (4, 1, 'Software Development Engineer C, C++', '<p>Duties are focused on development open-source LLVM/GCC toolchain for Intel Architecture in Linux and Android target environments.  </p>\n\n<p><str ... (2188 characters truncated) ... global leadership to the software community through its technical expertise, industry enabling activities, and developer products and programs.</p>\n', '<p>Apply on company website: <a href="http://career.intel.com/TpHFE">http://career.intel.com/TpHFE</a></p>\n')
# 2016-12-08 00:02:09,220 INFO sqlalchemy.engine.base.Engine INSERT INTO github_metadata (job_id, github_id, url, created_at) VALUES (?, ?, ?, ?)
# 2016-12-08 00:02:09,221 INFO sqlalchemy.engine.base.Engine (5, '88d7a11e-b7ef-11e6-8839-4baedb4f1c00', 'http://jobs.github.com/positions/88d7a11e-b7ef-11e6-8839-4baedb4f1c00', '2016-12-02 11:49:15.000000')
# 2016-12-08 00:02:09,223 INFO sqlalchemy.engine.base.Engine INSERT INTO location (job_id, description, remote_ok) VALUES (?, ?, ?)
# 2016-12-08 00:02:09,224 INFO sqlalchemy.engine.base.Engine (5, 'Gdansk, Poland ', 0)
# 2016-12-08 00:02:09,225 INFO sqlalchemy.engine.base.Engine COMMIT
# 2016-12-08 00:02:09,227 INFO sqlalchemy.engine.base.Engine SELECT github_metadata.job_id, github_metadata.github_id, github_metadata.url, github_metadata.created_at
# FROM github_metadata
# WHERE github_metadata.github_id = ?
# 2016-12-08 00:02:09,228 INFO sqlalchemy.engine.base.Engine ('24d6d212-b7f8-11e6-9bc0-4c468fa010c5',)
# 2016-12-08 00:02:09,229 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2016-12-08 00:02:09,232 INFO sqlalchemy.engine.base.Engine SELECT company.id, company.name, company.url, company.logo_url
# FROM company
# WHERE company.url = ?
# 2016-12-08 00:02:09,247 INFO sqlalchemy.engine.base.Engine ('http://www.pdtpartners.com',)
# 2016-12-08 00:02:09,270 INFO sqlalchemy.engine.base.Engine INSERT INTO company (name, url, logo_url) VALUES (?, ?, ?)
# 2016-12-08 00:02:09,271 INFO sqlalchemy.engine.base.Engine ('PDT Partners', 'http://www.pdtpartners.com', 'http://github-jobs.s3.amazonaws.com/1dee7540-b7f8-11e6-8780-56e37987ae3b.png')
# 2016-12-08 00:02:09,273 INFO sqlalchemy.engine.base.Engine INSERT INTO job (company_id, type_, title, description, how_to_apply) VALUES (?, ?, ?, ?, ?)
# 2016-12-08 00:02:09,275 INFO sqlalchemy.engine.base.Engine (5, 1, 'C++/Python Developer', '<p><strong>C++/Python Engineers</strong></p>\n\n<p>We’re looking for a select few uniquely excellent C++/Python engineers to join our world-class tea ... (5267 characters truncated) ... ed</li>\n</ul>\n\n<p><strong>Education:</strong></p>\n\n<p>Bachelor’s or master’s degree in computer science from an excellent academic program</p>\n', '<p><a href="http://grnh.se/h8l4dk1">http://grnh.se/h8l4dk1</a></p>\n')
# 2016-12-08 00:02:09,278 INFO sqlalchemy.engine.base.Engine INSERT INTO github_metadata (job_id, github_id, url, created_at) VALUES (?, ?, ?, ?)
# 2016-12-08 00:02:09,280 INFO sqlalchemy.engine.base.Engine (6, '24d6d212-b7f8-11e6-9bc0-4c468fa010c5', 'http://jobs.github.com/positions/24d6d212-b7f8-11e6-9bc0-4c468fa010c5', '2016-12-01 18:59:13.000000')
# 2016-12-08 00:02:09,283 INFO sqlalchemy.engine.base.Engine INSERT INTO location (job_id, description, remote_ok) VALUES (?, ?, ?)
# 2016-12-08 00:02:09,286 INFO sqlalchemy.engine.base.Engine (6, 'New York', 0)
# 2016-12-08 00:02:09,287 INFO sqlalchemy.engine.base.Engine COMMIT
# 2016-12-08 00:02:09,289 INFO sqlalchemy.engine.base.Engine SELECT github_metadata.job_id, github_metadata.github_id, github_metadata.url, github_metadata.created_at
# FROM github_metadata
# WHERE github_metadata.github_id = ?
# 2016-12-08 00:02:09,290 INFO sqlalchemy.engine.base.Engine ('53eb1432-b68b-11e6-805c-42ae75f605e1',)
# 2016-12-08 00:02:09,291 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2016-12-08 00:02:09,292 INFO sqlalchemy.engine.base.Engine SELECT company.id, company.name, company.url, company.logo_url
# FROM company
# WHERE company.url IS NULL
# 2016-12-08 00:02:09,296 INFO sqlalchemy.engine.base.Engine ()
# 2016-12-08 00:02:09,300 INFO sqlalchemy.engine.base.Engine INSERT INTO company (name, url, logo_url) VALUES (?, ?, ?)
# 2016-12-08 00:02:09,302 INFO sqlalchemy.engine.base.Engine ('CrowdFlower', None, None)
# 2016-12-08 00:02:09,304 INFO sqlalchemy.engine.base.Engine INSERT INTO job (company_id, type_, title, description, how_to_apply) VALUES (?, ?, ?, ?, ?)
# 2016-12-08 00:02:09,305 INFO sqlalchemy.engine.base.Engine (6, 1, 'Ruby/Rails BackEnd Developer', '<p><h2><strong>About CrowdFlower...</strong></h2><p>CrowdFlower is the essential human-in-the-loop platform for data science teams. CrowdFlower helps ... (3313 characters truncated) ... ve total compensation package including outstanding benefits and stock options.</p> <img src="https://www.applytracking.com/track.aspx/7IJjT"/></p>\n', '<p><a href="https://www.applytracking.com/track.aspx/7IJjd">https://www.applytracking.com/track.aspx/7IJjd</a></p>\n')
# 2016-12-08 00:02:09,307 INFO sqlalchemy.engine.base.Engine INSERT INTO github_metadata (job_id, github_id, url, created_at) VALUES (?, ?, ?, ?)
# 2016-12-08 00:02:09,308 INFO sqlalchemy.engine.base.Engine (7, '53eb1432-b68b-11e6-805c-42ae75f605e1', 'http://jobs.github.com/positions/53eb1432-b68b-11e6-805c-42ae75f605e1', '2016-11-29 23:27:00.000000')
# 2016-12-08 00:02:09,311 INFO sqlalchemy.engine.base.Engine INSERT INTO location (job_id, description, remote_ok) VALUES (?, ?, ?)
# 2016-12-08 00:02:09,313 INFO sqlalchemy.engine.base.Engine (7, 'San Francisco, CA, US', 0)
# 2016-12-08 00:02:09,366 INFO sqlalchemy.engine.base.Engine COMMIT
# 2016-12-08 00:02:09,369 INFO sqlalchemy.engine.base.Engine SELECT github_metadata.job_id, github_metadata.github_id, github_metadata.url, github_metadata.created_at
# FROM github_metadata
# WHERE github_metadata.github_id = ?
# 2016-12-08 00:02:09,373 INFO sqlalchemy.engine.base.Engine ('f2dff876-b679-11e6-896e-3954f140fe85',)
# 2016-12-08 00:02:09,377 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2016-12-08 00:02:09,380 INFO sqlalchemy.engine.base.Engine SELECT company.id, company.name, company.url, company.logo_url
# FROM company
# WHERE company.url = ?
# 2016-12-08 00:02:09,382 INFO sqlalchemy.engine.base.Engine ('https://www.carbonblack.com/',)
# 2016-12-08 00:02:09,386 INFO sqlalchemy.engine.base.Engine INSERT INTO company (name, url, logo_url) VALUES (?, ?, ?)
# 2016-12-08 00:02:09,387 INFO sqlalchemy.engine.base.Engine ('Carbon Black, Inc.', 'https://www.carbonblack.com/', 'http://github-jobs.s3.amazonaws.com/309b531e-b679-11e6-8bed-4a8a3761e6da.jpg')
# 2016-12-08 00:02:09,390 INFO sqlalchemy.engine.base.Engine INSERT INTO job (company_id, type_, title, description, how_to_apply) VALUES (?, ?, ?, ?, ?)
# 2016-12-08 00:02:09,394 INFO sqlalchemy.engine.base.Engine (7, 1, 'Senior Software Engineer - Cloud', '<p><strong>Why Carbon Black?</strong></p>\n\n<p>At Carbon Black, you’ll have the opportunity to make a huge impact while working alongside a global c ... (4315 characters truncated) ... oint Protection by security professionals in the SANS Institute’s Best of 2015 Awards.</p>\n\n<p>Carbon Black is an Equal Opportunity Employer.</p>\n', '<p><a href="https://lifeatcb.carbonblack.com/job-postings/?p=job/oMPL3fw9&amp;__jvst=JobBoard&amp;__jvsd=Github&amp;nl=1">Click here to apply.</a></p>\n')
# 2016-12-08 00:02:09,400 INFO sqlalchemy.engine.base.Engine INSERT INTO github_metadata (job_id, github_id, url, created_at) VALUES (?, ?, ?, ?)
# 2016-12-08 00:02:09,402 INFO sqlalchemy.engine.base.Engine (8, 'f2dff876-b679-11e6-896e-3954f140fe85', 'http://jobs.github.com/positions/f2dff876-b679-11e6-896e-3954f140fe85', '2016-11-29 21:23:04.000000')
# 2016-12-08 00:02:09,406 INFO sqlalchemy.engine.base.Engine INSERT INTO location (job_id, description, remote_ok) VALUES (?, ?, ?)
# 2016-12-08 00:02:09,407 INFO sqlalchemy.engine.base.Engine (8, 'Waltham, MA or Telecommute', 1)
# 2016-12-08 00:02:09,409 INFO sqlalchemy.engine.base.Engine COMMIT
# 2016-12-08 00:02:09,411 INFO sqlalchemy.engine.base.Engine SELECT github_metadata.job_id, github_metadata.github_id, github_metadata.url, github_metadata.created_at
# FROM github_metadata
# WHERE github_metadata.github_id = ?
# 2016-12-08 00:02:09,413 INFO sqlalchemy.engine.base.Engine ('b3d3c3fe-b65d-11e6-9da9-6e5efb70d328',)
# 2016-12-08 00:02:09,415 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2016-12-08 00:02:09,417 INFO sqlalchemy.engine.base.Engine SELECT company.id, company.name, company.url, company.logo_url
# FROM company
# WHERE company.url = ?
# 2016-12-08 00:02:09,418 INFO sqlalchemy.engine.base.Engine ('http://www.wearesmartertravel.com',)
# 2016-12-08 00:02:09,420 INFO sqlalchemy.engine.base.Engine INSERT INTO company (name, url, logo_url) VALUES (?, ?, ?)
# 2016-12-08 00:02:09,421 INFO sqlalchemy.engine.base.Engine ('SmarterTravel', 'http://www.wearesmartertravel.com', 'http://github-jobs.s3.amazonaws.com/d4a4f27e-b667-11e6-9318-ad870fa045f5.png')
# 2016-12-08 00:02:09,423 INFO sqlalchemy.engine.base.Engine INSERT INTO job (company_id, type_, title, description, how_to_apply) VALUES (?, ?, ?, ?, ?)
# 2016-12-08 00:02:09,424 INFO sqlalchemy.engine.base.Engine (8, 1, 'Software Engineering Manager, Oyster.com', '<p>SmarterTravel, a TripAdvisor Company, offers travelers a portfolio of travel sites to help them find the right trip at the right price.  We are a  ... (3479 characters truncated) ... d, if necessary, the Department of Homeland Security (DHS) with information from each new employee&#39;s I-9 to confirm work authorization. ***</p>\n', '<p>Please apply online at <a href="http://grnh.se/ta5py11">http://grnh.se/ta5py11</a> or email your resume to <a href="mailto:careers@smartertravel.com">careers@smartertravel.com</a></p>\n')
# 2016-12-08 00:02:09,427 INFO sqlalchemy.engine.base.Engine INSERT INTO github_metadata (job_id, github_id, url, created_at) VALUES (?, ?, ?, ?)
# 2016-12-08 00:02:09,428 INFO sqlalchemy.engine.base.Engine (9, 'b3d3c3fe-b65d-11e6-9da9-6e5efb70d328', 'http://jobs.github.com/positions/b3d3c3fe-b65d-11e6-9da9-6e5efb70d328', '2016-11-29 19:14:14.000000')
# 2016-12-08 00:02:09,431 INFO sqlalchemy.engine.base.Engine INSERT INTO location (job_id, description, remote_ok) VALUES (?, ?, ?)
# 2016-12-08 00:02:09,433 INFO sqlalchemy.engine.base.Engine (9, 'New York, NY', 0)
# 2016-12-08 00:02:09,438 INFO sqlalchemy.engine.base.Engine COMMIT
# 2016-12-08 00:02:09,440 INFO sqlalchemy.engine.base.Engine SELECT github_metadata.job_id, github_metadata.github_id, github_metadata.url, github_metadata.created_at
# FROM github_metadata
# WHERE github_metadata.github_id = ?
# 2016-12-08 00:02:09,442 INFO sqlalchemy.engine.base.Engine ('ada0319c-b57d-11e6-9c3c-d13afadb65a8',)
# 2016-12-08 00:02:09,443 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2016-12-08 00:02:09,445 INFO sqlalchemy.engine.base.Engine SELECT company.id, company.name, company.url, company.logo_url
# FROM company
# WHERE company.url = ?
# 2016-12-08 00:02:09,446 INFO sqlalchemy.engine.base.Engine ('http://www.teleopti.com/index.aspx',)
# 2016-12-08 00:02:09,448 INFO sqlalchemy.engine.base.Engine INSERT INTO company (name, url, logo_url) VALUES (?, ?, ?)
# 2016-12-08 00:02:09,448 INFO sqlalchemy.engine.base.Engine ('Teleopti', 'http://www.teleopti.com/index.aspx', 'http://github-jobs.s3.amazonaws.com/9d62e428-b57d-11e6-85ba-b1fdde6cc6ee.jpg')
# 2016-12-08 00:02:09,450 INFO sqlalchemy.engine.base.Engine INSERT INTO job (company_id, type_, title, description, how_to_apply) VALUES (?, ?, ?, ?, ?)
# 2016-12-08 00:02:09,451 INFO sqlalchemy.engine.base.Engine (9, 1, 'Front-End Lead Developer to Teleopti ', '<p>If you are a team player who appreciates freedom with responsibility and working in an international and creative environment, this is the job for ... (5667 characters truncated) ... e third year in a row, Teleopti is ranked by Great Place to Work as one of Sweden´s best workplaces, in the category of medium-sized companies.</p>\n', '<p>Do you meet the requirements? Click on the link below:\n<a href="https://www.academicwork.se/annons/front-end-lead-developer-to-teleopti/14979312? ... (435 characters truncated) ... academicwork.se</a> and we will answer during office hours. Please write the advert title in the subject and paste the advert link in the mail.</p>\n')
# 2016-12-08 00:02:09,455 INFO sqlalchemy.engine.base.Engine INSERT INTO github_metadata (job_id, github_id, url, created_at) VALUES (?, ?, ?, ?)
# 2016-12-08 00:02:09,457 INFO sqlalchemy.engine.base.Engine (10, 'ada0319c-b57d-11e6-9c3c-d13afadb65a8', 'http://jobs.github.com/positions/ada0319c-b57d-11e6-9c3c-d13afadb65a8', '2016-11-28 15:17:34.000000')
# 2016-12-08 00:02:09,458 INFO sqlalchemy.engine.base.Engine INSERT INTO location (job_id, description, remote_ok) VALUES (?, ?, ?)
# 2016-12-08 00:02:09,459 INFO sqlalchemy.engine.base.Engine (10, 'Stockholm', 0)
# 2016-12-08 00:02:09,460 INFO sqlalchemy.engine.base.Engine COMMIT
# 2016-12-08 00:02:09,462 INFO sqlalchemy.engine.base.Engine SELECT github_metadata.job_id, github_metadata.github_id, github_metadata.url, github_metadata.created_at
# FROM github_metadata
# WHERE github_metadata.github_id = ?
# 2016-12-08 00:02:09,463 INFO sqlalchemy.engine.base.Engine ('cf34f21a-b308-11e6-9192-6f14e27e77e8',)
# 2016-12-08 00:02:09,464 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2016-12-08 00:02:09,467 INFO sqlalchemy.engine.base.Engine SELECT company.id, company.name, company.url, company.logo_url
# FROM company
# WHERE company.url = ?
# 2016-12-08 00:02:09,468 INFO sqlalchemy.engine.base.Engine ('http://www.workingatbooking.com',)
# 2016-12-08 00:02:09,471 INFO sqlalchemy.engine.base.Engine INSERT INTO company (name, url, logo_url) VALUES (?, ?, ?)
# 2016-12-08 00:02:09,473 INFO sqlalchemy.engine.base.Engine ('Booking.com', 'http://www.workingatbooking.com', 'http://github-jobs.s3.amazonaws.com/c9146712-b308-11e6-875e-1fa7ba6a7f42.jpeg')
# 2016-12-08 00:02:09,481 INFO sqlalchemy.engine.base.Engine INSERT INTO job (company_id, type_, title, description, how_to_apply) VALUES (?, ?, ?, ?, ?)
# 2016-12-08 00:02:09,484 INFO sqlalchemy.engine.base.Engine (10, 1, 'Data Scientist – Machine Learning', '<p>Would you like to translate terabytes of data into unforgettable holidays for millions of people around the globe? Booking.com, the world’s larges ... (3049 characters truncated) ... is looking for a Data Scientist - Machine Learning in Amsterdam, the Netherlands. All references to “Booking.com&quot; refer to Booking.com BV.</p>\n', '<p>Apply: <a href="http://grnh.se/62yip51">http://grnh.se/62yip51</a></p>\n')
# 2016-12-08 00:02:09,491 INFO sqlalchemy.engine.base.Engine INSERT INTO github_metadata (job_id, github_id, url, created_at) VALUES (?, ?, ?, ?)
# 2016-12-08 00:02:09,503 INFO sqlalchemy.engine.base.Engine (11, 'cf34f21a-b308-11e6-9192-6f14e27e77e8', 'http://jobs.github.com/positions/cf34f21a-b308-11e6-9192-6f14e27e77e8', '2016-11-25 12:15:59.000000')
# 2016-12-08 00:02:09,505 INFO sqlalchemy.engine.base.Engine INSERT INTO location (job_id, description, remote_ok) VALUES (?, ?, ?)
# 2016-12-08 00:02:09,506 INFO sqlalchemy.engine.base.Engine (11, 'Amsterdam', 0)
# 2016-12-08 00:02:09,507 INFO sqlalchemy.engine.base.Engine COMMIT
# 2016-12-08 00:02:09,511 INFO sqlalchemy.engine.base.Engine SELECT github_metadata.job_id, github_metadata.github_id, github_metadata.url, github_metadata.created_at
# FROM github_metadata
# WHERE github_metadata.github_id = ?
# 2016-12-08 00:02:09,523 INFO sqlalchemy.engine.base.Engine ('4e2c3674-b308-11e6-9dbe-b0fc9cbe45b2',)
# 2016-12-08 00:02:09,524 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2016-12-08 00:02:09,525 INFO sqlalchemy.engine.base.Engine SELECT company.id, company.name, company.url, company.logo_url
# FROM company
# WHERE company.url = ?
# 2016-12-08 00:02:09,526 INFO sqlalchemy.engine.base.Engine ('http://www.workingatbooking.com',)
# 2016-12-08 00:02:09,527 INFO sqlalchemy.engine.base.Engine INSERT INTO job (company_id, type_, title, description, how_to_apply) VALUES (?, ?, ?, ?, ?)
# 2016-12-08 00:02:09,528 INFO sqlalchemy.engine.base.Engine (10, 1, 'Data Scientist – Analytics', '<p>Booking.com is looking for data savvy professionals to join our team of data scientists. You will be working with stakeholders throughout the comp ... (2719 characters truncated) ... com BV is looking for a Data Scientist - Analytics in Amsterdam, the Netherlands. All references to “Booking.com&quot; refer to Booking.com BV.</p>\n', '<p>Apply:  <a href="http://grnh.se/62yip51">http://grnh.se/62yip51</a></p>\n')
# 2016-12-08 00:02:09,530 INFO sqlalchemy.engine.base.Engine INSERT INTO github_metadata (job_id, github_id, url, created_at) VALUES (?, ?, ?, ?)
# 2016-12-08 00:02:09,533 INFO sqlalchemy.engine.base.Engine (12, '4e2c3674-b308-11e6-9dbe-b0fc9cbe45b2', 'http://jobs.github.com/positions/4e2c3674-b308-11e6-9dbe-b0fc9cbe45b2', '2016-11-25 12:12:50.000000')
# 2016-12-08 00:02:09,537 INFO sqlalchemy.engine.base.Engine INSERT INTO location (job_id, description, remote_ok) VALUES (?, ?, ?)
# 2016-12-08 00:02:09,538 INFO sqlalchemy.engine.base.Engine (12, 'Amsterdam', 0)
# 2016-12-08 00:02:09,539 INFO sqlalchemy.engine.base.Engine COMMIT
# 2016-12-08 00:02:09,541 INFO sqlalchemy.engine.base.Engine SELECT github_metadata.job_id, github_metadata.github_id, github_metadata.url, github_metadata.created_at
# FROM github_metadata
# WHERE github_metadata.github_id = ?
# 2016-12-08 00:02:09,542 INFO sqlalchemy.engine.base.Engine ('f2648464-b10d-11e6-9bd0-5ecee6c9ffa7',)
# 2016-12-08 00:02:09,544 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2016-12-08 00:02:09,546 INFO sqlalchemy.engine.base.Engine SELECT company.id, company.name, company.url, company.logo_url
# FROM company
# WHERE company.url = ?
# 2016-12-08 00:02:09,547 INFO sqlalchemy.engine.base.Engine ('http://www.livestories.com',)
# 2016-12-08 00:02:09,549 INFO sqlalchemy.engine.base.Engine INSERT INTO company (name, url, logo_url) VALUES (?, ?, ?)
# 2016-12-08 00:02:09,551 INFO sqlalchemy.engine.base.Engine ('LiveStories', 'http://www.livestories.com', 'http://github-jobs.s3.amazonaws.com/a74585a0-b10d-11e6-80d4-bae80c66bb59.png')
# 2016-12-08 00:02:09,565 INFO sqlalchemy.engine.base.Engine INSERT INTO job (company_id, type_, title, description, how_to_apply) VALUES (?, ?, ?, ?, ?)
# 2016-12-08 00:02:09,569 INFO sqlalchemy.engine.base.Engine (11, 1, '(Sr.) Front End Engineer', '<h1>Why LiveStories?</h1>\n\n<p>LiveStories is a venture-backed company building modern tools to help the world’s largest sector be more data-driven, ... (2026 characters truncated) ... ental, and vision benefits </li>\n<li>Flexible vacation policy </li>\n<li>An incredible team of smart, dedicated, and supportive people</li>\n</ul>\n', '<p>Send your resume to <a href="mailto:careers@livestories.com">careers@livestories.com</a></p>\n')
# 2016-12-08 00:02:09,571 INFO sqlalchemy.engine.base.Engine INSERT INTO github_metadata (job_id, github_id, url, created_at) VALUES (?, ?, ?, ?)
# 2016-12-08 00:02:09,572 INFO sqlalchemy.engine.base.Engine (13, 'f2648464-b10d-11e6-9bd0-5ecee6c9ffa7', 'http://jobs.github.com/positions/f2648464-b10d-11e6-9bd0-5ecee6c9ffa7', '2016-11-22 23:48:04.000000')
# 2016-12-08 00:02:09,576 INFO sqlalchemy.engine.base.Engine INSERT INTO location (job_id, description, remote_ok) VALUES (?, ?, ?)
# 2016-12-08 00:02:09,588 INFO sqlalchemy.engine.base.Engine (13, 'Seattle', 0)
# 2016-12-08 00:02:09,591 INFO sqlalchemy.engine.base.Engine COMMIT
# 2016-12-08 00:02:09,594 INFO sqlalchemy.engine.base.Engine SELECT github_metadata.job_id, github_metadata.github_id, github_metadata.url, github_metadata.created_at
# FROM github_metadata
# WHERE github_metadata.github_id = ?
# 2016-12-08 00:02:09,601 INFO sqlalchemy.engine.base.Engine ('048cd71c-adae-11e6-9327-2b710fbf6e21',)
# 2016-12-08 00:02:09,604 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2016-12-08 00:02:09,606 INFO sqlalchemy.engine.base.Engine SELECT company.id, company.name, company.url, company.logo_url
# FROM company
# WHERE company.url = ?
# 2016-12-08 00:02:09,608 INFO sqlalchemy.engine.base.Engine ('http://www.mayfieldrobotics.com/',)
# 2016-12-08 00:02:09,610 INFO sqlalchemy.engine.base.Engine INSERT INTO company (name, url, logo_url) VALUES (?, ?, ?)
# 2016-12-08 00:02:09,611 INFO sqlalchemy.engine.base.Engine ('Mayfield Robotics', 'http://www.mayfieldrobotics.com/', 'http://github-jobs.s3.amazonaws.com/85454f34-adad-11e6-938c-da7ff962d92f.png')
# 2016-12-08 00:02:09,613 INFO sqlalchemy.engine.base.Engine INSERT INTO job (company_id, type_, title, description, how_to_apply) VALUES (?, ?, ?, ?, ?)
# 2016-12-08 00:02:09,618 INFO sqlalchemy.engine.base.Engine (12, 1, 'Software Test Engineer (Python)', '<p>About the Company:</p>\n\n<p>At Mayfield Robotics, we make home robots that are joyful, useful, and inspiring. We move fast, we like and respect e ... (3997 characters truncated) ... es </li>\n<li>Tuition reimbursement </li>\n<li>401K </li>\n<li>Laundry/dry cleaning service </li>\n<li>Happy hours &amp; company events</li>\n</ul>\n', '<p>To apply, send your resume to <a href="mailto:jobs+qa@mayfieldrobotics.com">jobs+qa@mayfieldrobotics.com</a>.</p>\n')
# 2016-12-08 00:02:09,622 INFO sqlalchemy.engine.base.Engine INSERT INTO github_metadata (job_id, github_id, url, created_at) VALUES (?, ?, ?, ?)
# 2016-12-08 00:02:09,622 INFO sqlalchemy.engine.base.Engine (14, '048cd71c-adae-11e6-9327-2b710fbf6e21', 'http://jobs.github.com/positions/048cd71c-adae-11e6-9327-2b710fbf6e21', '2016-11-18 16:43:44.000000')
# 2016-12-08 00:02:09,624 INFO sqlalchemy.engine.base.Engine INSERT INTO location (job_id, description, remote_ok) VALUES (?, ?, ?)
# 2016-12-08 00:02:09,625 INFO sqlalchemy.engine.base.Engine (14, 'Redwood City, CA', 0)
# 2016-12-08 00:02:09,626 INFO sqlalchemy.engine.base.Engine COMMIT
# 2016-12-08 00:02:09,629 INFO sqlalchemy.engine.base.Engine SELECT github_metadata.job_id, github_metadata.github_id, github_metadata.url, github_metadata.created_at
# FROM github_metadata
# WHERE github_metadata.github_id = ?
# 2016-12-08 00:02:09,630 INFO sqlalchemy.engine.base.Engine ('b92c77de-ab62-11e6-9d5d-0f03dd750bd7',)
# 2016-12-08 00:02:09,632 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2016-12-08 00:02:09,644 INFO sqlalchemy.engine.base.Engine SELECT company.id, company.name, company.url, company.logo_url
# FROM company
# WHERE company.url = ?
# 2016-12-08 00:02:09,649 INFO sqlalchemy.engine.base.Engine ('http://www.spreemo.com',)
# 2016-12-08 00:02:09,666 INFO sqlalchemy.engine.base.Engine INSERT INTO company (name, url, logo_url) VALUES (?, ?, ?)
# 2016-12-08 00:02:09,671 INFO sqlalchemy.engine.base.Engine ('Spreemo', 'http://www.spreemo.com', 'http://github-jobs.s3.amazonaws.com/8530b198-ab62-11e6-9227-10b58f5dcfab.png')
# 2016-12-08 00:02:09,673 INFO sqlalchemy.engine.base.Engine INSERT INTO job (company_id, type_, title, description, how_to_apply) VALUES (?, ?, ?, ?, ?)
# 2016-12-08 00:02:09,676 INFO sqlalchemy.engine.base.Engine (13, 1, 'Software Engineer', '<h2><strong>Who are we?</strong></h2>\n\n<p>At Spreemo we believe that advanced data science can prevent serious misdiagnoses and poor outcomes. Usin ... (2839 characters truncated) ... t benefits. Benefits include: medical + dental insurance, FSA, pre-tax commuter benefits, lots of paid time off, and Macbook Pro + XL monitors.</p>\n', '<p>Visit <a href="https://jobs.lever.co/spreemo.com/76c7822a-481a-4629-9a6e-ac6fe811885f">https://jobs.lever.co/spreemo.com/76c7822a-481a-4629-9a6e-ac6fe811885f</a></p>\n')
# 2016-12-08 00:02:09,678 INFO sqlalchemy.engine.base.Engine INSERT INTO github_metadata (job_id, github_id, url, created_at) VALUES (?, ?, ?, ?)
# 2016-12-08 00:02:09,680 INFO sqlalchemy.engine.base.Engine (15, 'b92c77de-ab62-11e6-9d5d-0f03dd750bd7', 'http://jobs.github.com/positions/b92c77de-ab62-11e6-9d5d-0f03dd750bd7', '2016-11-15 18:39:28.000000')
# 2016-12-08 00:02:09,682 INFO sqlalchemy.engine.base.Engine INSERT INTO location (job_id, description, remote_ok) VALUES (?, ?, ?)
# 2016-12-08 00:02:09,684 INFO sqlalchemy.engine.base.Engine (15, 'New York, NY', 0)
# 2016-12-08 00:02:09,686 INFO sqlalchemy.engine.base.Engine COMMIT
# 2016-12-08 00:02:09,687 INFO sqlalchemy.engine.base.Engine SELECT github_metadata.job_id, github_metadata.github_id, github_metadata.url, github_metadata.created_at
# FROM github_metadata
# WHERE github_metadata.github_id = ?
# 2016-12-08 00:02:09,688 INFO sqlalchemy.engine.base.Engine ('d409edb0-ab4a-11e6-8eed-c01232d09e01',)
# 2016-12-08 00:02:09,689 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2016-12-08 00:02:09,690 INFO sqlalchemy.engine.base.Engine SELECT company.id, company.name, company.url, company.logo_url
# FROM company
# WHERE company.url IS NULL
# 2016-12-08 00:02:09,691 INFO sqlalchemy.engine.base.Engine ()
# 2016-12-08 00:02:09,697 INFO sqlalchemy.engine.base.Engine INSERT INTO job (company_id, type_, title, description, how_to_apply) VALUES (?, ?, ?, ?, ?)
# 2016-12-08 00:02:09,699 INFO sqlalchemy.engine.base.Engine (6, 1, 'Software Project Manager', '<p>Summary:</p>\n\n<p>eHealth Africa is focused on improving healthcare by creating effective ways to implement reliable health information managemen ... (3184 characters truncated) ... -paced environment</p>\n\n<p>Ability to work on multiple projects simultaneously and deliver within tight timelines</p>\n\n<p>Fluent in English</p>\n', '<p><a href="https://eHealthAfrica.bamboohr.com/jobs/view.php?id=40">https://eHealthAfrica.bamboohr.com/jobs/view.php?id=40</a></p>\n')
# 2016-12-08 00:02:09,701 INFO sqlalchemy.engine.base.Engine INSERT INTO github_metadata (job_id, github_id, url, created_at) VALUES (?, ?, ?, ?)
# 2016-12-08 00:02:09,702 INFO sqlalchemy.engine.base.Engine (16, 'd409edb0-ab4a-11e6-8eed-c01232d09e01', 'http://jobs.github.com/positions/d409edb0-ab4a-11e6-8eed-c01232d09e01', '2016-11-15 15:49:15.000000')
# 2016-12-08 00:02:09,704 INFO sqlalchemy.engine.base.Engine INSERT INTO location (job_id, description, remote_ok) VALUES (?, ?, ?)
# 2016-12-08 00:02:09,705 INFO sqlalchemy.engine.base.Engine (16, 'Sierra Leone', 0)
# 2016-12-08 00:02:09,706 INFO sqlalchemy.engine.base.Engine COMMIT
# 2016-12-08 00:02:09,709 INFO sqlalchemy.engine.base.Engine SELECT github_metadata.job_id, github_metadata.github_id, github_metadata.url, github_metadata.created_at
# FROM github_metadata
# WHERE github_metadata.github_id = ?
# 2016-12-08 00:02:09,710 INFO sqlalchemy.engine.base.Engine ('2e1b4148-ab49-11e6-8b5d-230703ad0bc9',)
# 2016-12-08 00:02:09,711 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2016-12-08 00:02:09,713 INFO sqlalchemy.engine.base.Engine SELECT company.id, company.name, company.url, company.logo_url
# FROM company
# WHERE company.url IS NULL
# 2016-12-08 00:02:09,720 INFO sqlalchemy.engine.base.Engine ()
# 2016-12-08 00:02:09,730 INFO sqlalchemy.engine.base.Engine INSERT INTO job (company_id, type_, title, description, how_to_apply) VALUES (?, ?, ?, ?, ?)
# 2016-12-08 00:02:09,737 INFO sqlalchemy.engine.base.Engine (6, 1, 'Senior Andriod Developer(Freelance for 6 months)', '<p>Summary:</p>\n\n<p>eHealth Africa is focused on improving healthcare by creating effective ways to implement reliable health information managemen ... (3582 characters truncated) ... our priority as well as rewarding them for their hard work.</p>\n\n<p>Note: The successful candidate will work either from Freetown or  Berlin.</p>\n', '<p><a href="https://eHealthAfrica.bamboohr.com/jobs/view.php?id=38">https://eHealthAfrica.bamboohr.com/jobs/view.php?id=38</a></p>\n')
# 2016-12-08 00:02:09,740 INFO sqlalchemy.engine.base.Engine INSERT INTO github_metadata (job_id, github_id, url, created_at) VALUES (?, ?, ?, ?)
# 2016-12-08 00:02:09,745 INFO sqlalchemy.engine.base.Engine (17, '2e1b4148-ab49-11e6-8b5d-230703ad0bc9', 'http://jobs.github.com/positions/2e1b4148-ab49-11e6-8b5d-230703ad0bc9', '2016-11-15 15:39:44.000000')
# 2016-12-08 00:02:09,748 INFO sqlalchemy.engine.base.Engine INSERT INTO location (job_id, description, remote_ok) VALUES (?, ?, ?)
# 2016-12-08 00:02:09,750 INFO sqlalchemy.engine.base.Engine (17, 'Sierra Leone', 0)
# 2016-12-08 00:02:09,751 INFO sqlalchemy.engine.base.Engine COMMIT
# 2016-12-08 00:02:09,753 INFO sqlalchemy.engine.base.Engine SELECT github_metadata.job_id, github_metadata.github_id, github_metadata.url, github_metadata.created_at
# FROM github_metadata
# WHERE github_metadata.github_id = ?
# 2016-12-08 00:02:09,755 INFO sqlalchemy.engine.base.Engine ('a0e32852-aa9b-11e6-93e6-4146165b3b6f',)
# 2016-12-08 00:02:09,757 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2016-12-08 00:02:09,758 INFO sqlalchemy.engine.base.Engine SELECT company.id, company.name, company.url, company.logo_url
# FROM company
# WHERE company.url = ?
# 2016-12-08 00:02:09,760 INFO sqlalchemy.engine.base.Engine ('http://www.tyco.com/',)
# 2016-12-08 00:02:09,762 INFO sqlalchemy.engine.base.Engine INSERT INTO company (name, url, logo_url) VALUES (?, ?, ?)
# 2016-12-08 00:02:09,763 INFO sqlalchemy.engine.base.Engine ('Johnson Controls', 'http://www.tyco.com/', 'http://github-jobs.s3.amazonaws.com/9c77a9be-aa9b-11e6-9186-3e169096f20b.png')
# 2016-12-08 00:02:09,764 INFO sqlalchemy.engine.base.Engine INSERT INTO job (company_id, type_, title, description, how_to_apply) VALUES (?, ?, ?, ?, ?)
# 2016-12-08 00:02:09,765 INFO sqlalchemy.engine.base.Engine (14, 1, 'Senior Android Engineer', '<p>ANDROID JOB DESCRIPTION\niOS and/or wearable is nice to have. Bluetooth and Embedded Experience also nice to have.</p>\n\n<p>As a Senior Mobile En ... (4111 characters truncated) ... t importantly, (Have a Personality  ) we are a fun crowd and like to work with other fun talented people.</li>\n</ul>\n\n<p>Job Type: Full-Time</p>\n', '<p>Visit:\n<a href="https://jobs.johnsoncontrols.com/job-details/software-engineer-iii-mobile/649849012/">https://jobs.johnsoncontrols.com/job-detail ... (25 characters truncated) ... obile/649849012/</a></p>\n\n<p>or</p>\n\n<p>send resume directly to <a href="mailto:JoPedroza@tycoint.com">JoPedroza@tycoint.com</a> for review</p>\n')
# 2016-12-08 00:02:09,767 INFO sqlalchemy.engine.base.Engine INSERT INTO github_metadata (job_id, github_id, url, created_at) VALUES (?, ?, ?, ?)
# 2016-12-08 00:02:09,768 INFO sqlalchemy.engine.base.Engine (18, 'a0e32852-aa9b-11e6-93e6-4146165b3b6f', 'http://jobs.github.com/positions/a0e32852-aa9b-11e6-93e6-4146165b3b6f', '2016-11-14 18:54:05.000000')
# 2016-12-08 00:02:09,770 INFO sqlalchemy.engine.base.Engine INSERT INTO location (job_id, description, remote_ok) VALUES (?, ?, ?)
# 2016-12-08 00:02:09,771 INFO sqlalchemy.engine.base.Engine (18, 'Irvine, CA', 0)
# 2016-12-08 00:02:09,775 INFO sqlalchemy.engine.base.Engine COMMIT
# 2016-12-08 00:02:09,777 INFO sqlalchemy.engine.base.Engine SELECT github_metadata.job_id, github_metadata.github_id, github_metadata.url, github_metadata.created_at
# FROM github_metadata
# WHERE github_metadata.github_id = ?
# 2016-12-08 00:02:09,778 INFO sqlalchemy.engine.base.Engine ('0e70b42e-aa98-11e6-9dc7-99d5c3a10bc9',)
# 2016-12-08 00:02:09,780 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2016-12-08 00:02:09,784 INFO sqlalchemy.engine.base.Engine SELECT company.id, company.name, company.url, company.logo_url
# FROM company
# WHERE company.url = ?
# 2016-12-08 00:02:09,786 INFO sqlalchemy.engine.base.Engine ('https://jobs.sap.com/search/?q=SAPmachinelearningcareers&locationsearch=&utm_source=github&utm_campaign=sap_machinelearning',)
# 2016-12-08 00:02:09,787 INFO sqlalchemy.engine.base.Engine INSERT INTO company (name, url, logo_url) VALUES (?, ?, ?)
# 2016-12-08 00:02:09,788 INFO sqlalchemy.engine.base.Engine ('SAP', 'https://jobs.sap.com/search/?q=SAPmachinelearningcareers&locationsearch=&utm_source=github&utm_campaign=sap_machinelearning', 'http://github-jobs.s3.amazonaws.com/05fe7560-aa98-11e6-9e8a-0e66c883b7dd.png')
# 2016-12-08 00:02:09,789 INFO sqlalchemy.engine.base.Engine INSERT INTO job (company_id, type_, title, description, how_to_apply) VALUES (?, ?, ?, ?, ?)
# 2016-12-08 00:02:09,790 INFO sqlalchemy.engine.base.Engine (15, 1, 'Developer with ML background for Machine Learning development Job', '<p><a href="https://jobs.sap.com/job/Palo-Alto-Developer-with-ML-background-for-Machine-Learning-development-Job-CA-94301/327259801/?feedId=203001&ut ... (1486 characters truncated) ... arning-development-Job-CA-94301/327259801/?feedId=203001&utm_source=github&utm_campaign=sap_machinelearning">Apply on our career site here.</a></p>\n', '<p><a href="https://jobs.sap.com/job/Palo-Alto-Developer-with-ML-background-for-Machine-Learning-development-Job-CA-94301/327259801/?feedId=203001&utm_source=github&utm_campaign=sap_machinelearning">Apply on our career site here.</a></p>\n')
# 2016-12-08 00:02:09,792 INFO sqlalchemy.engine.base.Engine INSERT INTO github_metadata (job_id, github_id, url, created_at) VALUES (?, ?, ?, ?)
# 2016-12-08 00:02:09,793 INFO sqlalchemy.engine.base.Engine (19, '0e70b42e-aa98-11e6-9dc7-99d5c3a10bc9', 'http://jobs.github.com/positions/0e70b42e-aa98-11e6-9dc7-99d5c3a10bc9', '2016-11-14 18:29:10.000000')
# 2016-12-08 00:02:09,795 INFO sqlalchemy.engine.base.Engine INSERT INTO location (job_id, description, remote_ok) VALUES (?, ?, ?)
# 2016-12-08 00:02:09,799 INFO sqlalchemy.engine.base.Engine (19, 'Palo Alto', 0)
# 2016-12-08 00:02:09,805 INFO sqlalchemy.engine.base.Engine COMMIT
# 2016-12-08 00:02:09,807 INFO sqlalchemy.engine.base.Engine SELECT github_metadata.job_id, github_metadata.github_id, github_metadata.url, github_metadata.created_at
# FROM github_metadata
# WHERE github_metadata.github_id = ?
# 2016-12-08 00:02:09,808 INFO sqlalchemy.engine.base.Engine ('43b8b066-a83e-11e6-9dcf-84f334f5295b',)
# 2016-12-08 00:02:09,809 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2016-12-08 00:02:09,812 INFO sqlalchemy.engine.base.Engine SELECT company.id, company.name, company.url, company.logo_url
# FROM company
# WHERE company.url = ?
# 2016-12-08 00:02:09,818 INFO sqlalchemy.engine.base.Engine ('http://www.leadpages.net/',)
# 2016-12-08 00:02:09,821 INFO sqlalchemy.engine.base.Engine INSERT INTO company (name, url, logo_url) VALUES (?, ?, ?)
# 2016-12-08 00:02:09,823 INFO sqlalchemy.engine.base.Engine ('Leadpages', 'http://www.leadpages.net/', 'http://github-jobs.s3.amazonaws.com/314925f0-a83e-11e6-8350-38442bc0d153.png')
# 2016-12-08 00:02:09,825 INFO sqlalchemy.engine.base.Engine INSERT INTO job (company_id, type_, title, description, how_to_apply) VALUES (?, ?, ?, ?, ?)
# 2016-12-08 00:02:09,827 INFO sqlalchemy.engine.base.Engine (16, 1, 'Site Reliability Engineer', '<p>We promise you haven’t worked with anyone <a href="http://www.leadpages.net/careers">like us</a> before.  We’re a Minneapolis / St. Paul, MN based ... (6317 characters truncated) ... leadpages.net/apply/YN38C7/Site-Reliability-Engineer?source=Github">HERE</a>. Thanks for checking us out - we look forward to hearing from you!</p>\n', '<p><strong>Sound like you?</strong></p>\n\n<p>To apply, please submit your tailored resume, a link to your LinkedIn profile, and a cover letter expla ... (95 characters truncated) ... leadpages.net/apply/YN38C7/Site-Reliability-Engineer?source=Github">HERE</a>. Thanks for checking us out - we look forward to hearing from you!</p>\n')
# 2016-12-08 00:02:09,829 INFO sqlalchemy.engine.base.Engine INSERT INTO github_metadata (job_id, github_id, url, created_at) VALUES (?, ?, ?, ?)
# 2016-12-08 00:02:09,830 INFO sqlalchemy.engine.base.Engine (20, '43b8b066-a83e-11e6-9dcf-84f334f5295b', 'http://jobs.github.com/positions/43b8b066-a83e-11e6-9dcf-84f334f5295b', '2016-11-11 18:41:52.000000')
# 2016-12-08 00:02:09,832 INFO sqlalchemy.engine.base.Engine INSERT INTO location (job_id, description, remote_ok) VALUES (?, ?, ?)
# 2016-12-08 00:02:09,839 INFO sqlalchemy.engine.base.Engine (20, 'Minneapolis, MN', 0)
# 2016-12-08 00:02:09,840 INFO sqlalchemy.engine.base.Engine COMMIT
# 2016-12-08 00:02:09,843 INFO sqlalchemy.engine.base.Engine SELECT github_metadata.job_id, github_metadata.github_id, github_metadata.url, github_metadata.created_at
# FROM github_metadata
# WHERE github_metadata.github_id = ?
# 2016-12-08 00:02:09,845 INFO sqlalchemy.engine.base.Engine ('7978e922-a781-11e6-9907-af5d98bf0bd7',)
# 2016-12-08 00:02:09,846 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2016-12-08 00:02:09,848 INFO sqlalchemy.engine.base.Engine SELECT company.id, company.name, company.url, company.logo_url
# FROM company
# WHERE company.url = ?
# 2016-12-08 00:02:09,850 INFO sqlalchemy.engine.base.Engine ('http://www.fiftythree.com',)
# 2016-12-08 00:02:09,857 INFO sqlalchemy.engine.base.Engine INSERT INTO company (name, url, logo_url) VALUES (?, ?, ?)
# 2016-12-08 00:02:09,859 INFO sqlalchemy.engine.base.Engine ('FiftyThree, Inc.', 'http://www.fiftythree.com', None)
# 2016-12-08 00:02:09,860 INFO sqlalchemy.engine.base.Engine INSERT INTO job (company_id, type_, title, description, how_to_apply) VALUES (?, ?, ?, ?, ?)
# 2016-12-08 00:02:09,862 INFO sqlalchemy.engine.base.Engine (17, 1, 'Software Engineer, Front-End Web', '<p>Job Profile:</p>\n\n<p>Build rich, dynamic, magical web applications. Work hand-in-hand with the design and product teams to implement interfaces  ... (2360 characters truncated) ... >Catered in-office lunches twice weekly and fully stocked pantry </li>\n<li>Flexible Time Off Policy </li>\n<li>Employee Equity Program</li>\n</ul>\n', '<p><a href="http://grnh.se/bdfpi81">http://grnh.se/bdfpi81</a></p>\n')
# 2016-12-08 00:02:09,864 INFO sqlalchemy.engine.base.Engine INSERT INTO github_metadata (job_id, github_id, url, created_at) VALUES (?, ?, ?, ?)
# 2016-12-08 00:02:09,866 INFO sqlalchemy.engine.base.Engine (21, '7978e922-a781-11e6-9907-af5d98bf0bd7', 'http://jobs.github.com/positions/7978e922-a781-11e6-9907-af5d98bf0bd7', '2016-11-10 20:23:11.000000')
# 2016-12-08 00:02:09,868 INFO sqlalchemy.engine.base.Engine INSERT INTO location (job_id, description, remote_ok) VALUES (?, ?, ?)
# 2016-12-08 00:02:09,869 INFO sqlalchemy.engine.base.Engine (21, 'New York, NY', 0)
# 2016-12-08 00:02:09,870 INFO sqlalchemy.engine.base.Engine COMMIT
# 2016-12-08 00:02:09,872 INFO sqlalchemy.engine.base.Engine SELECT github_metadata.job_id, github_metadata.github_id, github_metadata.url, github_metadata.created_at
# FROM github_metadata
# WHERE github_metadata.github_id = ?
# 2016-12-08 00:02:09,874 INFO sqlalchemy.engine.base.Engine ('309a94b6-a615-11e6-8e0d-46596a6e8706',)
# 2016-12-08 00:02:09,875 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2016-12-08 00:02:09,878 INFO sqlalchemy.engine.base.Engine SELECT company.id, company.name, company.url, company.logo_url
# FROM company
# WHERE company.url = ?
# 2016-12-08 00:02:09,879 INFO sqlalchemy.engine.base.Engine ('http://www.advent.com',)
# 2016-12-08 00:02:09,880 INFO sqlalchemy.engine.base.Engine INSERT INTO company (name, url, logo_url) VALUES (?, ?, ?)
# 2016-12-08 00:02:09,882 INFO sqlalchemy.engine.base.Engine ('Advent Software', 'http://www.advent.com', 'http://github-jobs.s3.amazonaws.com/d2a7bac8-a614-11e6-8826-887b1b0177e2.png')
# 2016-12-08 00:02:09,884 INFO sqlalchemy.engine.base.Engine INSERT INTO job (company_id, type_, title, description, how_to_apply) VALUES (?, ?, ?, ?, ?)
# 2016-12-08 00:02:09,885 INFO sqlalchemy.engine.base.Engine (18, 1, 'Senior Software Engineer (Java)', '<p>SS&amp;C Advent, a leading provider of award-winning software and services for the global investment management industry, is seeking a Senior Soft ... (2185 characters truncated) ... achelor in Science/ Engineering preferred</li>\n</ul>\n\n<p>SS&amp;C Advent is an equal opportunity employer, committed to a diverse workforce.</p>\n', '<p><a href="https://app.jobvite.com/j?cj=o86d3fwe&s=GitHub">Click here to apply</a></p>\n')
# 2016-12-08 00:02:09,888 INFO sqlalchemy.engine.base.Engine INSERT INTO github_metadata (job_id, github_id, url, created_at) VALUES (?, ?, ?, ?)
# 2016-12-08 00:02:09,889 INFO sqlalchemy.engine.base.Engine (22, '309a94b6-a615-11e6-8e0d-46596a6e8706', 'http://jobs.github.com/positions/309a94b6-a615-11e6-8e0d-46596a6e8706', '2016-11-09 00:42:36.000000')
# 2016-12-08 00:02:09,891 INFO sqlalchemy.engine.base.Engine INSERT INTO location (job_id, description, remote_ok) VALUES (?, ?, ?)
# 2016-12-08 00:02:09,891 INFO sqlalchemy.engine.base.Engine (22, 'San Francisco, CA', 0)
# 2016-12-08 00:02:09,892 INFO sqlalchemy.engine.base.Engine COMMIT
# 2016-12-08 00:02:09,894 INFO sqlalchemy.engine.base.Engine SELECT github_metadata.job_id, github_metadata.github_id, github_metadata.url, github_metadata.created_at
# FROM github_metadata
# WHERE github_metadata.github_id = ?
# 2016-12-08 00:02:09,895 INFO sqlalchemy.engine.base.Engine ('7e51dc7a-a613-11e6-919f-32ba27ee5a07',)
# 2016-12-08 00:02:09,896 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2016-12-08 00:02:09,897 INFO sqlalchemy.engine.base.Engine SELECT company.id, company.name, company.url, company.logo_url
# FROM company
# WHERE company.url = ?
# 2016-12-08 00:02:09,898 INFO sqlalchemy.engine.base.Engine ('http://www.advent.com/',)
# 2016-12-08 00:02:09,900 INFO sqlalchemy.engine.base.Engine INSERT INTO company (name, url, logo_url) VALUES (?, ?, ?)
# 2016-12-08 00:02:09,901 INFO sqlalchemy.engine.base.Engine ('Advent Software', 'http://www.advent.com/', 'http://github-jobs.s3.amazonaws.com/58e7118a-a613-11e6-8443-a2a8b996310d.png')
# 2016-12-08 00:02:09,903 INFO sqlalchemy.engine.base.Engine INSERT INTO job (company_id, type_, title, description, how_to_apply) VALUES (?, ?, ?, ?, ?)
# 2016-12-08 00:02:09,904 INFO sqlalchemy.engine.base.Engine (19, 1, 'Software Engineer (Java)', '<p>SS&amp;C Advent, a leading provider of award-winning software and services for the global investment management industry, is seeking a Software En ... (1663 characters truncated) ... achelor in Science/ Engineering preferred</li>\n</ul>\n\n<p>SS&amp;C Advent is an equal opportunity employer, committed to a diverse workforce.</p>\n', '<p><a href="https://app.jobvite.com/j?cj=odXy2fwu&s=GitHub">Click here to apply</a></p>\n')
# 2016-12-08 00:02:09,906 INFO sqlalchemy.engine.base.Engine INSERT INTO github_metadata (job_id, github_id, url, created_at) VALUES (?, ?, ?, ?)
# 2016-12-08 00:02:09,907 INFO sqlalchemy.engine.base.Engine (23, '7e51dc7a-a613-11e6-919f-32ba27ee5a07', 'http://jobs.github.com/positions/7e51dc7a-a613-11e6-919f-32ba27ee5a07', '2016-11-09 00:29:16.000000')
# 2016-12-08 00:02:09,908 INFO sqlalchemy.engine.base.Engine INSERT INTO location (job_id, description, remote_ok) VALUES (?, ?, ?)
# 2016-12-08 00:02:09,909 INFO sqlalchemy.engine.base.Engine (23, 'San Francisco, CA', 0)
# 2016-12-08 00:02:09,911 INFO sqlalchemy.engine.base.Engine COMMIT
# 2016-12-08 00:02:09,913 INFO sqlalchemy.engine.base.Engine SELECT github_metadata.job_id, github_metadata.github_id, github_metadata.url, github_metadata.created_at
# FROM github_metadata
# WHERE github_metadata.github_id = ?
# 2016-12-08 00:02:09,915 INFO sqlalchemy.engine.base.Engine ('42e14a90-a5d2-11e6-9bad-c0590158de94',)
# 2016-12-08 00:02:09,923 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2016-12-08 00:02:09,931 INFO sqlalchemy.engine.base.Engine SELECT company.id, company.name, company.url, company.logo_url
# FROM company
# WHERE company.url = ?
# 2016-12-08 00:02:09,938 INFO sqlalchemy.engine.base.Engine ('https://www.textnow.com/',)
# 2016-12-08 00:02:09,941 INFO sqlalchemy.engine.base.Engine INSERT INTO company (name, url, logo_url) VALUES (?, ?, ?)
# 2016-12-08 00:02:09,947 INFO sqlalchemy.engine.base.Engine ('TextNow', 'https://www.textnow.com/', 'http://github-jobs.s3.amazonaws.com/c8d2ddfe-a5cc-11e6-9efa-20771e165637.png')
# 2016-12-08 00:02:09,951 INFO sqlalchemy.engine.base.Engine INSERT INTO job (company_id, type_, title, description, how_to_apply) VALUES (?, ?, ?, ?, ?)
# 2016-12-08 00:02:09,952 INFO sqlalchemy.engine.base.Engine (20, 1, 'Sr. iOS Developer', '<p>The telecom industry has far too long been dominated by the big, the bureaucratic and the unimaginative. Now is the time for someone to take this  ... (2733 characters truncated) ...  recruitment process are asked to contact the Human Resources team at <a href="mailto:Recruitment@textnow.com">Recruitment@textnow.com</a></em></p>\n', '<p>To apply visit our career page at <a href="http://about.textnow.com/careers/#openings-iOS-Developer">http://about.textnow.com/careers/#openings-iOS-Developer</a></p>\n')
# 2016-12-08 00:02:09,954 INFO sqlalchemy.engine.base.Engine INSERT INTO github_metadata (job_id, github_id, url, created_at) VALUES (?, ?, ?, ?)
# 2016-12-08 00:02:09,957 INFO sqlalchemy.engine.base.Engine (24, '42e14a90-a5d2-11e6-9bad-c0590158de94', 'http://jobs.github.com/positions/42e14a90-a5d2-11e6-9bad-c0590158de94', '2016-11-08 16:44:37.000000')
# 2016-12-08 00:02:09,959 INFO sqlalchemy.engine.base.Engine INSERT INTO location (job_id, description, remote_ok) VALUES (?, ?, ?)
# 2016-12-08 00:02:09,960 INFO sqlalchemy.engine.base.Engine (24, 'Waterloo, Canada', 0)
# 2016-12-08 00:02:09,963 INFO sqlalchemy.engine.base.Engine COMMIT
# 2016-12-08 00:02:09,968 INFO sqlalchemy.engine.base.Engine SELECT github_metadata.job_id, github_metadata.github_id, github_metadata.url, github_metadata.created_at
# FROM github_metadata
# WHERE github_metadata.github_id = ?
# 2016-12-08 00:02:09,971 INFO sqlalchemy.engine.base.Engine ('9862547e-526b-11e6-9c98-836c3746873d',)
# 2016-12-08 00:02:09,972 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2016-12-08 00:02:09,977 INFO sqlalchemy.engine.base.Engine SELECT company.id, company.name, company.url, company.logo_url
# FROM company
# WHERE company.url = ?
# 2016-12-08 00:02:09,979 INFO sqlalchemy.engine.base.Engine ('http://Booking.com',)
# 2016-12-08 00:02:09,981 INFO sqlalchemy.engine.base.Engine INSERT INTO company (name, url, logo_url) VALUES (?, ?, ?)
# 2016-12-08 00:02:09,983 INFO sqlalchemy.engine.base.Engine ('Booking.com', 'http://Booking.com', 'http://github-jobs.s3.amazonaws.com/b89761ee-526b-11e6-8d0c-3ec5ffda0b49.png')
# 2016-12-08 00:02:09,985 INFO sqlalchemy.engine.base.Engine INSERT INTO job (company_id, type_, title, description, how_to_apply) VALUES (?, ?, ?, ?, ?)
# 2016-12-08 00:02:09,985 INFO sqlalchemy.engine.base.Engine (21, 1, 'Data Scientist – Machine Learning', '<p>Would you like to translate terabytes of data into unforgettable holidays for millions of people around the globe? Booking.com, the world’s larges ... (3217 characters truncated) ... is looking for a Data Scientist - Machine Learning in Amsterdam, the Netherlands. All references to “Booking.com&quot; refer to Booking.com BV.</p>\n', '<p>Apply via this link:</p>\n\n<p><a href="http://grnh.se/rmwec5">http://grnh.se/rmwec5</a></p>\n')
# 2016-12-08 00:02:09,988 INFO sqlalchemy.engine.base.Engine INSERT INTO github_metadata (job_id, github_id, url, created_at) VALUES (?, ?, ?, ?)
# 2016-12-08 00:02:09,989 INFO sqlalchemy.engine.base.Engine (25, '9862547e-526b-11e6-9c98-836c3746873d', 'http://jobs.github.com/positions/9862547e-526b-11e6-9c98-836c3746873d', '2016-11-08 10:41:10.000000')
# 2016-12-08 00:02:09,991 INFO sqlalchemy.engine.base.Engine INSERT INTO location (job_id, description, remote_ok) VALUES (?, ?, ?)
# 2016-12-08 00:02:09,992 INFO sqlalchemy.engine.base.Engine (25, 'Amsterdam', 0)
# 2016-12-08 00:02:09,994 INFO sqlalchemy.engine.base.Engine COMMIT
# 2016-12-08 00:02:10,003 INFO sqlalchemy.engine.base.Engine SELECT github_metadata.job_id, github_metadata.github_id, github_metadata.url, github_metadata.created_at
# FROM github_metadata
# WHERE github_metadata.github_id = ?
# 2016-12-08 00:02:10,005 INFO sqlalchemy.engine.base.Engine ('bc0bbfa6-526a-11e6-8092-d5f4dbf20b0f',)
# 2016-12-08 00:02:10,008 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2016-12-08 00:02:10,030 INFO sqlalchemy.engine.base.Engine SELECT company.id, company.name, company.url, company.logo_url
# FROM company
# WHERE company.url = ?
# 2016-12-08 00:02:10,038 INFO sqlalchemy.engine.base.Engine ('http://Booking.com',)
# 2016-12-08 00:02:10,041 INFO sqlalchemy.engine.base.Engine INSERT INTO job (company_id, type_, title, description, how_to_apply) VALUES (?, ?, ?, ?, ?)
# 2016-12-08 00:02:10,042 INFO sqlalchemy.engine.base.Engine (21, 1, 'Data Scientist – Analytics', '<p>Booking.com is looking for data savvy professionals to join our team of data scientists. You will be working with stakeholders throughout the comp ... (2850 characters truncated) ... com BV is looking for a Data Scientist - Analytics in Amsterdam, the Netherlands. All references to “Booking.com&quot; refer to Booking.com BV.</p>\n', '<p>Apply via this link:</p>\n\n<p><a href="http://grnh.se/g1tl6m">http://grnh.se/g1tl6m</a></p>\n')
# 2016-12-08 00:02:10,044 INFO sqlalchemy.engine.base.Engine INSERT INTO github_metadata (job_id, github_id, url, created_at) VALUES (?, ?, ?, ?)
# 2016-12-08 00:02:10,045 INFO sqlalchemy.engine.base.Engine (26, 'bc0bbfa6-526a-11e6-8092-d5f4dbf20b0f', 'http://jobs.github.com/positions/bc0bbfa6-526a-11e6-8092-d5f4dbf20b0f', '2016-11-08 10:40:20.000000')
# 2016-12-08 00:02:10,048 INFO sqlalchemy.engine.base.Engine INSERT INTO location (job_id, description, remote_ok) VALUES (?, ?, ?)
# 2016-12-08 00:02:10,050 INFO sqlalchemy.engine.base.Engine (26, 'Amsterdam', 0)
# 2016-12-08 00:02:10,051 INFO sqlalchemy.engine.base.Engine COMMIT

# %%
from sqlalchemy.sql import text

s = text('SELECT * FROM company')
result = conn.execute(s)

for row in result:
    print('\n {}'.format(row))
# Out:
# 2016-12-08 00:04:57,202 INFO sqlalchemy.engine.base.Engine SELECT * FROM company
# 2016-12-08 00:04:57,204 INFO sqlalchemy.engine.base.Engine ()
#
#  (1, 'Network Merchants, LLC', 'http://nmi.com', 'http://github-jobs.s3.amazonaws.com/a1b8f9ec-bbed-11e6-960a-b1034c4cd71b.png')
#
#  (2, 'Stevens Capital Management LP', 'http://www.scm-lp.com', 'http://github-jobs.s3.amazonaws.com/5df90c6a-baf8-11e6-8a38-492033c01d86.png')
#
#  (3, 'GenePeeks, Inc', 'http://www.genepeeks.com', 'http://github-jobs.s3.amazonaws.com/67ea79ea-b8c6-11e6-81ec-ba6eeed777c6.jpg')
#
#  (4, 'Intel Corporation', 'http://jobs.intel.com', 'http://github-jobs.s3.amazonaws.com/0590279e-b7eb-11e6-92e0-095053d3f49d.png')
#
#  (5, 'PDT Partners', 'http://www.pdtpartners.com', 'http://github-jobs.s3.amazonaws.com/1dee7540-b7f8-11e6-8780-56e37987ae3b.png')
#
#  (6, 'CrowdFlower', None, None)
#
#  (7, 'Carbon Black, Inc.', 'https://www.carbonblack.com/', 'http://github-jobs.s3.amazonaws.com/309b531e-b679-11e6-8bed-4a8a3761e6da.jpg')
#
#  (8, 'SmarterTravel', 'http://www.wearesmartertravel.com', 'http://github-jobs.s3.amazonaws.com/d4a4f27e-b667-11e6-9318-ad870fa045f5.png')
#
#  (9, 'Teleopti', 'http://www.teleopti.com/index.aspx', 'http://github-jobs.s3.amazonaws.com/9d62e428-b57d-11e6-85ba-b1fdde6cc6ee.jpg')
#
#  (10, 'Booking.com', 'http://www.workingatbooking.com', 'http://github-jobs.s3.amazonaws.com/c9146712-b308-11e6-875e-1fa7ba6a7f42.jpeg')
#
#  (11, 'LiveStories', 'http://www.livestories.com', 'http://github-jobs.s3.amazonaws.com/a74585a0-b10d-11e6-80d4-bae80c66bb59.png')
#
#  (12, 'Mayfield Robotics', 'http://www.mayfieldrobotics.com/', 'http://github-jobs.s3.amazonaws.com/85454f34-adad-11e6-938c-da7ff962d92f.png')
#
#  (13, 'Spreemo', 'http://www.spreemo.com', 'http://github-jobs.s3.amazonaws.com/8530b198-ab62-11e6-9227-10b58f5dcfab.png')
#
#  (14, 'Johnson Controls', 'http://www.tyco.com/', 'http://github-jobs.s3.amazonaws.com/9c77a9be-aa9b-11e6-9186-3e169096f20b.png')
#
#  (15, 'SAP', 'https://jobs.sap.com/search/?q=SAPmachinelearningcareers&locationsearch=&utm_source=github&utm_campaign=sap_machinelearning', 'http://github-jobs.s3.amazonaws.com/05fe7560-aa98-11e6-9e8a-0e66c883b7dd.png')
#
#  (16, 'Leadpages', 'http://www.leadpages.net/', 'http://github-jobs.s3.amazonaws.com/314925f0-a83e-11e6-8350-38442bc0d153.png')
#
#  (17, 'FiftyThree, Inc.', 'http://www.fiftythree.com', None)
#
#  (18, 'Advent Software', 'http://www.advent.com', 'http://github-jobs.s3.amazonaws.com/d2a7bac8-a614-11e6-8826-887b1b0177e2.png')
#
#  (19, 'Advent Software', 'http://www.advent.com/', 'http://github-jobs.s3.amazonaws.com/58e7118a-a613-11e6-8443-a2a8b996310d.png')
#
#  (20, 'TextNow', 'https://www.textnow.com/', 'http://github-jobs.s3.amazonaws.com/c8d2ddfe-a5cc-11e6-9efa-20771e165637.png')
#
#  (21, 'Booking.com', 'http://Booking.com', 'http://github-jobs.s3.amazonaws.com/b89761ee-526b-11e6-8d0c-3ec5ffda0b49.png')

# %%
s = text('SELECT * FROM job')
result = conn.execute(s)

for row in result:
    print('\n {}'.format(row))
# Out:
# 2016-12-08 00:06:50,892 INFO sqlalchemy.engine.base.Engine SELECT * FROM job
# 2016-12-08 00:06:50,894 INFO sqlalchemy.engine.base.Engine ()
#
#  (1, 1, 1, 'Linux Systems Engineer', '<p><strong>Summary</strong> </p>\n\n<ul>\n<li>The engineering team at NMI is a small, agile group that works closely together but requires independen ... (2957 characters truncated) ... >\n<li>Jira and Confluence for task and project management</li>\n<li>Computer</li>\n<li>Printer</li>\n<li>Fax Machine</li>\n<li>Scanner</li>\n</ul>\n', '<p>Please E-mail your resume to <a href="mailto:hr@nmi.com">hr@nmi.com</a></p>\n')
#
#  (2, 2, 1, 'Implementation Developer', '<p>Stevens Capital Management LP (“SCM”) is a registered investment adviser that manages a multi-billion dollar hedge fund that has been in business  ... (1396 characters truncated) ... Experience with relational databases including Sybase, SQL Server and Oracle is a plus.</li>\n<li>Experience with GUI design is a plus.</li>\n</ul>\n', '<p>Please submit your resume to: <a href="mailto:recruiting@scm-lp.com">recruiting@scm-lp.com</a></p>\n\n<p>Website: <a href="http://www.scm-lp.com">www.scm-lp.com</a></p>\n')
#
#  (3, 3, 1, 'Software Engineer, DevOps', '<p>Job description</p>\n\n<p>GenePeeks is a data-driven genetics start-up pushing the boundaries of reproductive health care and computational geneti ... (2494 characters truncated) ... l>\n\n<p>Location:\nThis position will be located in the Boston or New York area.\n*GenePeeks will not offer visa sponsorship for this position</p>\n', '<p><a href="http://careers.genepeeks.com/o/software-engineer-devops=GitHub">http://careers.genepeeks.com/o/software-engineer-devops=GitHub</a></p>\n')
#
#  (4, 4, 1, 'Automated Driving SW Development Engineer', '<p>Employees of the Internet of Things Solutions Group (IOTG) have an exciting opportunity before them: To grow Intel&#39;s leadership position in th ... (4089 characters truncated) ... ated to helping Intel drive the next major growth inflection through productivity and new business models that are emerging as a result of IoT.</p>\n', '<p>Apply on company website: <a href="http://career.intel.com/TpLVa">http://career.intel.com/TpLVa</a></p>\n')
#
#  (5, 4, 1, 'Software Development Engineer C, C++', '<p>Duties are focused on development open-source LLVM/GCC toolchain for Intel Architecture in Linux and Android target environments.  </p>\n\n<p><str ... (2188 characters truncated) ... global leadership to the software community through its technical expertise, industry enabling activities, and developer products and programs.</p>\n', '<p>Apply on company website: <a href="http://career.intel.com/TpHFE">http://career.intel.com/TpHFE</a></p>\n')
#
#  (6, 5, 1, 'C++/Python Developer', '<p><strong>C++/Python Engineers</strong></p>\n\n<p>We’re looking for a select few uniquely excellent C++/Python engineers to join our world-class tea ... (5267 characters truncated) ... ed</li>\n</ul>\n\n<p><strong>Education:</strong></p>\n\n<p>Bachelor’s or master’s degree in computer science from an excellent academic program</p>\n', '<p><a href="http://grnh.se/h8l4dk1">http://grnh.se/h8l4dk1</a></p>\n')
#
#  (7, 6, 1, 'Ruby/Rails BackEnd Developer', '<p><h2><strong>About CrowdFlower...</strong></h2><p>CrowdFlower is the essential human-in-the-loop platform for data science teams. CrowdFlower helps ... (3313 characters truncated) ... ve total compensation package including outstanding benefits and stock options.</p> <img src="https://www.applytracking.com/track.aspx/7IJjT"/></p>\n', '<p><a href="https://www.applytracking.com/track.aspx/7IJjd">https://www.applytracking.com/track.aspx/7IJjd</a></p>\n')
#
#  (8, 7, 1, 'Senior Software Engineer - Cloud', '<p><strong>Why Carbon Black?</strong></p>\n\n<p>At Carbon Black, you’ll have the opportunity to make a huge impact while working alongside a global c ... (4315 characters truncated) ... oint Protection by security professionals in the SANS Institute’s Best of 2015 Awards.</p>\n\n<p>Carbon Black is an Equal Opportunity Employer.</p>\n', '<p><a href="https://lifeatcb.carbonblack.com/job-postings/?p=job/oMPL3fw9&amp;__jvst=JobBoard&amp;__jvsd=Github&amp;nl=1">Click here to apply.</a></p>\n')
#
#  (9, 8, 1, 'Software Engineering Manager, Oyster.com', '<p>SmarterTravel, a TripAdvisor Company, offers travelers a portfolio of travel sites to help them find the right trip at the right price.  We are a  ... (3479 characters truncated) ... d, if necessary, the Department of Homeland Security (DHS) with information from each new employee&#39;s I-9 to confirm work authorization. ***</p>\n', '<p>Please apply online at <a href="http://grnh.se/ta5py11">http://grnh.se/ta5py11</a> or email your resume to <a href="mailto:careers@smartertravel.com">careers@smartertravel.com</a></p>\n')
#
#  (10, 9, 1, 'Front-End Lead Developer to Teleopti ', '<p>If you are a team player who appreciates freedom with responsibility and working in an international and creative environment, this is the job for ... (5667 characters truncated) ... e third year in a row, Teleopti is ranked by Great Place to Work as one of Sweden´s best workplaces, in the category of medium-sized companies.</p>\n', '<p>Do you meet the requirements? Click on the link below:\n<a href="https://www.academicwork.se/annons/front-end-lead-developer-to-teleopti/14979312? ... (435 characters truncated) ... academicwork.se</a> and we will answer during office hours. Please write the advert title in the subject and paste the advert link in the mail.</p>\n')
#
#  (11, 10, 1, 'Data Scientist – Machine Learning', '<p>Would you like to translate terabytes of data into unforgettable holidays for millions of people around the globe? Booking.com, the world’s larges ... (3049 characters truncated) ... is looking for a Data Scientist - Machine Learning in Amsterdam, the Netherlands. All references to “Booking.com&quot; refer to Booking.com BV.</p>\n', '<p>Apply: <a href="http://grnh.se/62yip51">http://grnh.se/62yip51</a></p>\n')
#
#  (12, 10, 1, 'Data Scientist – Analytics', '<p>Booking.com is looking for data savvy professionals to join our team of data scientists. You will be working with stakeholders throughout the comp ... (2719 characters truncated) ... com BV is looking for a Data Scientist - Analytics in Amsterdam, the Netherlands. All references to “Booking.com&quot; refer to Booking.com BV.</p>\n', '<p>Apply:  <a href="http://grnh.se/62yip51">http://grnh.se/62yip51</a></p>\n')
#
#  (13, 11, 1, '(Sr.) Front End Engineer', '<h1>Why LiveStories?</h1>\n\n<p>LiveStories is a venture-backed company building modern tools to help the world’s largest sector be more data-driven, ... (2026 characters truncated) ... ental, and vision benefits </li>\n<li>Flexible vacation policy </li>\n<li>An incredible team of smart, dedicated, and supportive people</li>\n</ul>\n', '<p>Send your resume to <a href="mailto:careers@livestories.com">careers@livestories.com</a></p>\n')
#
#  (14, 12, 1, 'Software Test Engineer (Python)', '<p>About the Company:</p>\n\n<p>At Mayfield Robotics, we make home robots that are joyful, useful, and inspiring. We move fast, we like and respect e ... (3997 characters truncated) ... es </li>\n<li>Tuition reimbursement </li>\n<li>401K </li>\n<li>Laundry/dry cleaning service </li>\n<li>Happy hours &amp; company events</li>\n</ul>\n', '<p>To apply, send your resume to <a href="mailto:jobs+qa@mayfieldrobotics.com">jobs+qa@mayfieldrobotics.com</a>.</p>\n')
#
#  (15, 13, 1, 'Software Engineer', '<h2><strong>Who are we?</strong></h2>\n\n<p>At Spreemo we believe that advanced data science can prevent serious misdiagnoses and poor outcomes. Usin ... (2839 characters truncated) ... t benefits. Benefits include: medical + dental insurance, FSA, pre-tax commuter benefits, lots of paid time off, and Macbook Pro + XL monitors.</p>\n', '<p>Visit <a href="https://jobs.lever.co/spreemo.com/76c7822a-481a-4629-9a6e-ac6fe811885f">https://jobs.lever.co/spreemo.com/76c7822a-481a-4629-9a6e-ac6fe811885f</a></p>\n')
#
#  (16, 6, 1, 'Software Project Manager', '<p>Summary:</p>\n\n<p>eHealth Africa is focused on improving healthcare by creating effective ways to implement reliable health information managemen ... (3184 characters truncated) ... -paced environment</p>\n\n<p>Ability to work on multiple projects simultaneously and deliver within tight timelines</p>\n\n<p>Fluent in English</p>\n', '<p><a href="https://eHealthAfrica.bamboohr.com/jobs/view.php?id=40">https://eHealthAfrica.bamboohr.com/jobs/view.php?id=40</a></p>\n')
#
#  (17, 6, 1, 'Senior Andriod Developer(Freelance for 6 months)', '<p>Summary:</p>\n\n<p>eHealth Africa is focused on improving healthcare by creating effective ways to implement reliable health information managemen ... (3582 characters truncated) ... our priority as well as rewarding them for their hard work.</p>\n\n<p>Note: The successful candidate will work either from Freetown or  Berlin.</p>\n', '<p><a href="https://eHealthAfrica.bamboohr.com/jobs/view.php?id=38">https://eHealthAfrica.bamboohr.com/jobs/view.php?id=38</a></p>\n')
#
#  (18, 14, 1, 'Senior Android Engineer', '<p>ANDROID JOB DESCRIPTION\niOS and/or wearable is nice to have. Bluetooth and Embedded Experience also nice to have.</p>\n\n<p>As a Senior Mobile En ... (4111 characters truncated) ... t importantly, (Have a Personality  ) we are a fun crowd and like to work with other fun talented people.</li>\n</ul>\n\n<p>Job Type: Full-Time</p>\n', '<p>Visit:\n<a href="https://jobs.johnsoncontrols.com/job-details/software-engineer-iii-mobile/649849012/">https://jobs.johnsoncontrols.com/job-detail ... (25 characters truncated) ... obile/649849012/</a></p>\n\n<p>or</p>\n\n<p>send resume directly to <a href="mailto:JoPedroza@tycoint.com">JoPedroza@tycoint.com</a> for review</p>\n')
#
#  (19, 15, 1, 'Developer with ML background for Machine Learning development Job', '<p><a href="https://jobs.sap.com/job/Palo-Alto-Developer-with-ML-background-for-Machine-Learning-development-Job-CA-94301/327259801/?feedId=203001&ut ... (1486 characters truncated) ... arning-development-Job-CA-94301/327259801/?feedId=203001&utm_source=github&utm_campaign=sap_machinelearning">Apply on our career site here.</a></p>\n', '<p><a href="https://jobs.sap.com/job/Palo-Alto-Developer-with-ML-background-for-Machine-Learning-development-Job-CA-94301/327259801/?feedId=203001&utm_source=github&utm_campaign=sap_machinelearning">Apply on our career site here.</a></p>\n')
#
#  (20, 16, 1, 'Site Reliability Engineer', '<p>We promise you haven’t worked with anyone <a href="http://www.leadpages.net/careers">like us</a> before.  We’re a Minneapolis / St. Paul, MN based ... (6317 characters truncated) ... leadpages.net/apply/YN38C7/Site-Reliability-Engineer?source=Github">HERE</a>. Thanks for checking us out - we look forward to hearing from you!</p>\n', '<p><strong>Sound like you?</strong></p>\n\n<p>To apply, please submit your tailored resume, a link to your LinkedIn profile, and a cover letter expla ... (95 characters truncated) ... leadpages.net/apply/YN38C7/Site-Reliability-Engineer?source=Github">HERE</a>. Thanks for checking us out - we look forward to hearing from you!</p>\n')
#
#  (21, 17, 1, 'Software Engineer, Front-End Web', '<p>Job Profile:</p>\n\n<p>Build rich, dynamic, magical web applications. Work hand-in-hand with the design and product teams to implement interfaces  ... (2360 characters truncated) ... >Catered in-office lunches twice weekly and fully stocked pantry </li>\n<li>Flexible Time Off Policy </li>\n<li>Employee Equity Program</li>\n</ul>\n', '<p><a href="http://grnh.se/bdfpi81">http://grnh.se/bdfpi81</a></p>\n')
#
#  (22, 18, 1, 'Senior Software Engineer (Java)', '<p>SS&amp;C Advent, a leading provider of award-winning software and services for the global investment management industry, is seeking a Senior Soft ... (2185 characters truncated) ... achelor in Science/ Engineering preferred</li>\n</ul>\n\n<p>SS&amp;C Advent is an equal opportunity employer, committed to a diverse workforce.</p>\n', '<p><a href="https://app.jobvite.com/j?cj=o86d3fwe&s=GitHub">Click here to apply</a></p>\n')
#
#  (23, 19, 1, 'Software Engineer (Java)', '<p>SS&amp;C Advent, a leading provider of award-winning software and services for the global investment management industry, is seeking a Software En ... (1663 characters truncated) ... achelor in Science/ Engineering preferred</li>\n</ul>\n\n<p>SS&amp;C Advent is an equal opportunity employer, committed to a diverse workforce.</p>\n', '<p><a href="https://app.jobvite.com/j?cj=odXy2fwu&s=GitHub">Click here to apply</a></p>\n')
#
#  (24, 20, 1, 'Sr. iOS Developer', '<p>The telecom industry has far too long been dominated by the big, the bureaucratic and the unimaginative. Now is the time for someone to take this  ... (2733 characters truncated) ...  recruitment process are asked to contact the Human Resources team at <a href="mailto:Recruitment@textnow.com">Recruitment@textnow.com</a></em></p>\n', '<p>To apply visit our career page at <a href="http://about.textnow.com/careers/#openings-iOS-Developer">http://about.textnow.com/careers/#openings-iOS-Developer</a></p>\n')
#
#  (25, 21, 1, 'Data Scientist – Machine Learning', '<p>Would you like to translate terabytes of data into unforgettable holidays for millions of people around the globe? Booking.com, the world’s larges ... (3217 characters truncated) ... is looking for a Data Scientist - Machine Learning in Amsterdam, the Netherlands. All references to “Booking.com&quot; refer to Booking.com BV.</p>\n', '<p>Apply via this link:</p>\n\n<p><a href="http://grnh.se/rmwec5">http://grnh.se/rmwec5</a></p>\n')
#
#  (26, 21, 1, 'Data Scientist – Analytics', '<p>Booking.com is looking for data savvy professionals to join our team of data scientists. You will be working with stakeholders throughout the comp ... (2850 characters truncated) ... com BV is looking for a Data Scientist - Analytics in Amsterdam, the Netherlands. All references to “Booking.com&quot; refer to Booking.com BV.</p>\n', '<p>Apply via this link:</p>\n\n<p><a href="http://grnh.se/g1tl6m">http://grnh.se/g1tl6m</a></p>\n')

# %%
s = text('SELECT * FROM location')
result = conn.execute(s)

for row in result:
    print('\n {}'.format(row))
# Out:
# 2016-12-08 00:07:38,221 INFO sqlalchemy.engine.base.Engine SELECT * FROM location
# 2016-12-08 00:07:38,225 INFO sqlalchemy.engine.base.Engine ()
#
#  (1, 'Roselle, IL', 0)
#
#  (2, 'Radnor, PA. USA', 0)
#
#  (3, 'Cambridge, MA', 0)
#
#  (4, 'Karlsruhe, Germany', 0)
#
#  (5, 'Gdansk, Poland ', 0)
#
#  (6, 'New York', 0)
#
#  (7, 'San Francisco, CA, US', 0)
#
#  (8, 'Waltham, MA or Telecommute', 1)
#
#  (9, 'New York, NY', 0)
#
#  (10, 'Stockholm', 0)
#
#  (11, 'Amsterdam', 0)
#
#  (12, 'Amsterdam', 0)
#
#  (13, 'Seattle', 0)
#
#  (14, 'Redwood City, CA', 0)
#
#  (15, 'New York, NY', 0)
#
#  (16, 'Sierra Leone', 0)
#
#  (17, 'Sierra Leone', 0)
#
#  (18, 'Irvine, CA', 0)
#
#  (19, 'Palo Alto', 0)
#
#  (20, 'Minneapolis, MN', 0)
#
#  (21, 'New York, NY', 0)
#
#  (22, 'San Francisco, CA', 0)
#
#  (23, 'San Francisco, CA', 0)
#
#  (24, 'Waterloo, Canada', 0)
#
#  (25, 'Amsterdam', 0)
#
#  (26, 'Amsterdam', 0)

# %%
s = text('SELECT * FROM github_metadata')
result = conn.execute(s)

for row in result:
    print('\n {}'.format(row))
# Out:
# 2016-12-08 00:08:35,161 INFO sqlalchemy.engine.base.Engine SELECT * FROM github_metadata
# 2016-12-08 00:08:35,166 INFO sqlalchemy.engine.base.Engine ()
#
#  (1, 'beb74684-bbed-11e6-8197-64e617b51adf', 'http://jobs.github.com/positions/beb74684-bbed-11e6-8197-64e617b51adf', '2016-12-06 19:54:25.000000')
#
#  (2, '61433012-baf8-11e6-8d18-1baa36e6dbf5', 'http://jobs.github.com/positions/61433012-baf8-11e6-8d18-1baa36e6dbf5', '2016-12-05 14:38:11.000000')
#
#  (3, '6d409aaa-b8c6-11e6-8408-7debc09d256f', 'http://jobs.github.com/positions/6d409aaa-b8c6-11e6-8408-7debc09d256f', '2016-12-02 19:36:23.000000')
#
#  (4, '47b78b5e-b7ef-11e6-86f0-a00baabc0c92', 'http://jobs.github.com/positions/47b78b5e-b7ef-11e6-86f0-a00baabc0c92', '2016-12-02 11:49:17.000000')
#
#  (5, '88d7a11e-b7ef-11e6-8839-4baedb4f1c00', 'http://jobs.github.com/positions/88d7a11e-b7ef-11e6-8839-4baedb4f1c00', '2016-12-02 11:49:15.000000')
#
#  (6, '24d6d212-b7f8-11e6-9bc0-4c468fa010c5', 'http://jobs.github.com/positions/24d6d212-b7f8-11e6-9bc0-4c468fa010c5', '2016-12-01 18:59:13.000000')
#
#  (7, '53eb1432-b68b-11e6-805c-42ae75f605e1', 'http://jobs.github.com/positions/53eb1432-b68b-11e6-805c-42ae75f605e1', '2016-11-29 23:27:00.000000')
#
#  (8, 'f2dff876-b679-11e6-896e-3954f140fe85', 'http://jobs.github.com/positions/f2dff876-b679-11e6-896e-3954f140fe85', '2016-11-29 21:23:04.000000')
#
#  (9, 'b3d3c3fe-b65d-11e6-9da9-6e5efb70d328', 'http://jobs.github.com/positions/b3d3c3fe-b65d-11e6-9da9-6e5efb70d328', '2016-11-29 19:14:14.000000')
#
#  (10, 'ada0319c-b57d-11e6-9c3c-d13afadb65a8', 'http://jobs.github.com/positions/ada0319c-b57d-11e6-9c3c-d13afadb65a8', '2016-11-28 15:17:34.000000')
#
#  (11, 'cf34f21a-b308-11e6-9192-6f14e27e77e8', 'http://jobs.github.com/positions/cf34f21a-b308-11e6-9192-6f14e27e77e8', '2016-11-25 12:15:59.000000')
#
#  (12, '4e2c3674-b308-11e6-9dbe-b0fc9cbe45b2', 'http://jobs.github.com/positions/4e2c3674-b308-11e6-9dbe-b0fc9cbe45b2', '2016-11-25 12:12:50.000000')
#
#  (13, 'f2648464-b10d-11e6-9bd0-5ecee6c9ffa7', 'http://jobs.github.com/positions/f2648464-b10d-11e6-9bd0-5ecee6c9ffa7', '2016-11-22 23:48:04.000000')
#
#  (14, '048cd71c-adae-11e6-9327-2b710fbf6e21', 'http://jobs.github.com/positions/048cd71c-adae-11e6-9327-2b710fbf6e21', '2016-11-18 16:43:44.000000')
#
#  (15, 'b92c77de-ab62-11e6-9d5d-0f03dd750bd7', 'http://jobs.github.com/positions/b92c77de-ab62-11e6-9d5d-0f03dd750bd7', '2016-11-15 18:39:28.000000')
#
#  (16, 'd409edb0-ab4a-11e6-8eed-c01232d09e01', 'http://jobs.github.com/positions/d409edb0-ab4a-11e6-8eed-c01232d09e01', '2016-11-15 15:49:15.000000')
#
#  (17, '2e1b4148-ab49-11e6-8b5d-230703ad0bc9', 'http://jobs.github.com/positions/2e1b4148-ab49-11e6-8b5d-230703ad0bc9', '2016-11-15 15:39:44.000000')
#
#  (18, 'a0e32852-aa9b-11e6-93e6-4146165b3b6f', 'http://jobs.github.com/positions/a0e32852-aa9b-11e6-93e6-4146165b3b6f', '2016-11-14 18:54:05.000000')
#
#  (19, '0e70b42e-aa98-11e6-9dc7-99d5c3a10bc9', 'http://jobs.github.com/positions/0e70b42e-aa98-11e6-9dc7-99d5c3a10bc9', '2016-11-14 18:29:10.000000')
#
#  (20, '43b8b066-a83e-11e6-9dcf-84f334f5295b', 'http://jobs.github.com/positions/43b8b066-a83e-11e6-9dcf-84f334f5295b', '2016-11-11 18:41:52.000000')
#
#  (21, '7978e922-a781-11e6-9907-af5d98bf0bd7', 'http://jobs.github.com/positions/7978e922-a781-11e6-9907-af5d98bf0bd7', '2016-11-10 20:23:11.000000')
#
#  (22, '309a94b6-a615-11e6-8e0d-46596a6e8706', 'http://jobs.github.com/positions/309a94b6-a615-11e6-8e0d-46596a6e8706', '2016-11-09 00:42:36.000000')
#
#  (23, '7e51dc7a-a613-11e6-919f-32ba27ee5a07', 'http://jobs.github.com/positions/7e51dc7a-a613-11e6-919f-32ba27ee5a07', '2016-11-09 00:29:16.000000')
#
#  (24, '42e14a90-a5d2-11e6-9bad-c0590158de94', 'http://jobs.github.com/positions/42e14a90-a5d2-11e6-9bad-c0590158de94', '2016-11-08 16:44:37.000000')
#
#  (25, '9862547e-526b-11e6-9c98-836c3746873d', 'http://jobs.github.com/positions/9862547e-526b-11e6-9c98-836c3746873d', '2016-11-08 10:41:10.000000')
#
#  (26, 'bc0bbfa6-526a-11e6-8092-d5f4dbf20b0f', 'http://jobs.github.com/positions/bc0bbfa6-526a-11e6-8092-d5f4dbf20b0f', '2016-11-08 10:40:20.000000')

# %% [markdown]
# # This should be the output from our queries:
#
# There are 27 jobs with the 'Data Science' term, and 40% of them have 'Python' in the description.
#
# 22% of them have been created in the past 7 days.
#
# 2 of those are remote ok. The companies with remote jobs are: ['Carbon Black, Inc.', 'Kaggle']

# %%
from sqlalchemy import func

s = text("SELECT COUNT() "
         "FROM job")
total, = conn.execute(s).fetchone()

# s = select([func.count()]).select_from(job_table).where(
#     job_table.c.description.contains('python'))
s = text("SELECT COUNT() "
         "FROM job "
         "WHERE description LIKE '%python%'")
python, = conn.execute(s).fetchone()

print("\nThere are {} jobs with the 'Data Science' term, and {}% of them have 'Python' in the description."
      .format(total, 100 * python // total))
# Out:
# 2016-12-08 00:16:35,572 INFO sqlalchemy.engine.base.Engine SELECT COUNT() FROM job
# 2016-12-08 00:16:35,573 INFO sqlalchemy.engine.base.Engine ()
# 2016-12-08 00:16:35,576 INFO sqlalchemy.engine.base.Engine SELECT COUNT() FROM job WHERE description LIKE '%python%'
# 2016-12-08 00:16:35,577 INFO sqlalchemy.engine.base.Engine ()
#
# There are 26 jobs with the 'Data Science' term, and 38% of them have 'Python' in the description.

# %%
from datetime import datetime, timedelta

s = text("SELECT COUNT() "
         "FROM github_metadata "
         "WHERE created_at >= :week_ago")
last_week, = conn.execute(s, week_ago=datetime.today() - timedelta(days=7)
                         ).fetchone()

print("\n{}% of them have been created in the past 7 days."
      .format(100 * last_week // total))
# Out:
# 2016-12-08 00:19:56,993 INFO sqlalchemy.engine.base.Engine SELECT COUNT() FROM github_metadata WHERE created_at >= ?
# 2016-12-08 00:19:56,995 INFO sqlalchemy.engine.base.Engine (datetime.datetime(2016, 12, 1, 0, 19, 56, 993263),)
#
# 23% of them have been created in the past 7 days.

# %%
s = text("SELECT COUNT() "
         "FROM job "
         "JOIN location ON job.id = location.job_id "
         "WHERE remote_ok = :true")
remote_jobs, = conn.execute(s, true=int(True)).fetchone()

# s = select([job_table.c.title]).select_from(job_table.join(location_table)).where(
#      location_table.c.remote_ok == int(True))
s = text("SELECT name "
         "FROM company "
         "JOIN job ON company.id = job.company_id "
         "JOIN location ON job.id = location.job_id "
         "WHERE location.remote_ok = :true")
remote_companies = conn.execute(s, true=int(True)).fetchall()

print("\n{} of those is remote ok. The company with the remote job is: {}"
      .format(remote_jobs, [company for company, in remote_companies]))
# Out:
# 2016-12-08 00:25:29,613 INFO sqlalchemy.engine.base.Engine SELECT COUNT() FROM job JOIN location ON job.id = location.job_id WHERE remote_ok = ?
# 2016-12-08 00:25:29,615 INFO sqlalchemy.engine.base.Engine (1,)
# 2016-12-08 00:25:29,616 INFO sqlalchemy.engine.base.Engine SELECT name FROM company JOIN job ON company.id = job.company_id JOIN location ON job.id = location.job_id WHERE location.remote_ok = ?
# 2016-12-08 00:25:29,617 INFO sqlalchemy.engine.base.Engine (1,)
#
# 1 of those is remote ok. The company with the remote job is: ['Carbon Black, Inc.']

# %%
conn.close()
