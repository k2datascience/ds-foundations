# %%
import requests

url = 'https://jobs.github.com/positions.json'
search_term = 'data science'

params = {'description': search_term}
response = requests.get(url, params=params)

print(response.status_code)
# Out:
# 200

# %%
json_response = response.json()

print('There are {n} results for the term "{term}".'
      .format(n=len(json_response), term=search_term))
# Out:
# There are 25 results for the term "data science".

# %%
import json
print(json_response == json.loads(response.text))
# Out:
# True

# %%
print(json.dumps(json_response, sort_keys=True, indent=4))
# Out:
# [
#     {
#         "company": "The Nordam Group",
#         "company_logo": "http://github-jobs.s3.amazonaws.com/f53d44ee-be25-11e6-957a-f616239dc5c8.png",
#         "company_url": "http://nordam.com/",
#         "created_at": "Fri Dec 09 15:42:07 UTC 2016",
#         "description": "<p>Onsite, Relocation available.</p>\n\n<p>We\u2019re an independent development team inside The NORDAM Group building a brand new public web service. The aerospace industry we\u2019re modernizing has yet to fully benefit from the data revolution. We pride ourselves on our \u201cstartup\u201d approach: we leverage modern technologies and methodologies and we prefer results over tradition. By being a totally separate unit in a large corporation, we benefit from its support and extensive business network, without all the downsides that come with software development at larger companies.</p>\n\n<p>You&#39;ll be responsible for leading a team of developers. This position will work on virtually all aspects of the product and will help drive product and technology strategy. You&#39;ll be designing solutions to complex or unusual problems or assignments requiring considerable ingenuity and judgement.</p>\n\n<p>Our product needs to handle information at scale, safely. We deal with items often worth tens of thousands of dollars or more. We do things the right way from the first time - cutting corners is not worth it in our case.</p>\n\n<p>You know Ruby inside and out, both the pretty and the ugly. You can tell when a piece of code will be inefficient just by looking at it and you know how to optimize it.</p>\n\n<p>As an early dev hire, you will be in a unique position to work on virtually all aspects of our product and have a strong voice in product and technology strategy. This position is a great opportunity for a smart and ambitious developer to advance their career and have a major impact on a large, important and clean project</p>\n\n<p>JOB QUALIFICATIONS:\nFormal Education, Training, Professional Certification and Work Experience:</p>\n\n<ul>\n<li>BS degree in Computer Science, related technical field or equivalent practical software development experience.</li>\n<li>At least 6 years of software development experience.</li>\n<li>Master of at least one scripting language (e.g., Ruby, Python, etc.) and at least one compiled language (e.g., Java, C/C++).</li>\n<li>Proficient with SQL, relational databases and excellent data modeling skills.</li>\n<li>Good knowledge of at least one frontend framework (e.g., Backbone, Angular, React, etc.).</li>\n</ul>\n\n<p>Preferred Qualifications:</p>\n\n<ul>\n<li>Experience with AWS, Docker and other \u201cdevops\u201d technologies is a plus.</li>\n<li>Strong sense of web design and attuned to the fundamentals of user experience.</li>\n<li>Familiarity with the whole web stack, including protocols and web server optimization techniques.\u00a0</li>\n<li>An understanding of the principles of accessibility and can build products that are accessible to users with disabilities.</li>\n<li>Experience developing \u201cresponsive\u201d websites.</li>\n</ul>\n",
#         "how_to_apply": "<p>Email your resume and a link to your Github profile to <a href=\"mailto:simon.grondin@outlook.com\">simon.grondin@outlook.com</a></p>\n",
#         "id": "f9891adc-be25-11e6-9511-e40bbeeef49d",
#         "location": "Tulsa, OK, USA",
#         "title": "Team Lead, Fullstack Software Developer",
#         "type": "Full Time",
#         "url": "http://jobs.github.com/positions/f9891adc-be25-11e6-9511-e40bbeeef49d"
#     },
#     {
#         "company": "The Nordam Group",
#         "company_logo": "http://github-jobs.s3.amazonaws.com/84d3f7fc-be25-11e6-8246-d8c9aaae18e6.png",
#         "company_url": "http://nordam.com/",
#         "created_at": "Fri Dec 09 15:39:49 UTC 2016",
#         "description": "<p>We\u2019re an independent development team inside The NORDAM Group building a brand new public web service. The aerospace industry we\u2019re modernizing has yet to fully benefit from the data revolution. We pride ourselves on our \u201cstartup\u201d approach: we leverage modern technologies and methodologies and we prefer results over tradition. By being a totally separate unit in a large corporation, we benefit from its support and extensive business network, without all the downsides that come with software development at larger companies.</p>\n\n<p>Our product needs to handle information at scale, safely. We deal with items often worth tens of thousands of dollars or more. We do things the right way from the first time - cutting corners is not worth it in our case.</p>\n\n<p>You know Ruby inside and out, both the pretty and the ugly. You can tell when a piece of code will be inefficient just by looking at it and you know how to optimize it.</p>\n\n<p>However, you are not married to any programming language and would welcome the opportunity to learn a new one on the job with open arms.</p>\n\n<p>As an early dev hire, you will be in a unique position to work on virtually all aspects of our product and have a strong voice in product and technology strategy. This position is a great opportunity for a smart and ambitious developer to advance their career and have a major impact on a large, important and clean project</p>\n\n<p>Job Qualifications:\nFormal Education, Training, Professional Certification and Work Experience:</p>\n\n<ul>\n<li>BS degree in Computer Science, related technical field or equivalent practical software development experience.</li>\n<li>At least 4 years of software development experience.</li>\n<li>Master of at least one scripting language (e.g., Ruby, Python, etc.).</li>\n<li>Proficient with SQL, relational databases and excellent data modeling skills.</li>\n<li>Familiarity with at least one frontend framework (e.g., Backbone, Angular, React, etc.).</li>\n</ul>\n\n<p>Preferred Qualifications:</p>\n\n<ul>\n<li>Experience with AWS, Docker and other \u201cdevops\u201d technologies is a plus.</li>\n<li>Strong sense of UI/UX fundamentals.</li>\n<li>Familiarity with the whole web stack, including protocols and web server optimization techniques.\u00a0</li>\n<li>An understanding of the principles of accessibility and can build products that are accessible to users with disabilities.</li>\n<li>Experience with front end development technologies like HTML5 and CSS3, and experience building responsive websites.</li>\n</ul>\n",
#         "how_to_apply": "<p>Email your resume and a link to your Github profile to <a href=\"mailto:simon.grondin@outlook.com\">simon.grondin@outlook.com</a></p>\n",
#         "id": "8ae1f6bc-be25-11e6-89a1-99b30fbe0cd6",
#         "location": "Tulsa, OK, USA",
#         "title": "Fullstack Developer",
#         "type": "Full Time",
#         "url": "http://jobs.github.com/positions/8ae1f6bc-be25-11e6-89a1-99b30fbe0cd6"
#     },
#     {
#         "company": "Make School",
#         "company_logo": "http://github-jobs.s3.amazonaws.com/1a750858-bd92-11e6-86c4-3164e610a489.png",
#         "company_url": "http://www.makeschool.com",
#         "created_at": "Thu Dec 08 22:03:30 UTC 2016",
#         "description": "<p>We&#39;re looking for an iOS Instructor &amp; Curriculum Engineer to develop and teach the iOS curriculum for our Product College.</p>\n\n<p>Make School\u2019s Product College is a 2-year higher education program for aspiring software engineers and founders. Students spend two years learning computer science foundations, software engineering, and product development through a blend of project-based learning and industry experience. Unlike traditional university, students have zero upfront cost for the program; instead they pay tuition through earnings.</p>\n\n<p>Your work will serve as the foundation for the Make School educational experience as we scale from 50 students to 5,000 students and beyond. By joining our team, you\u2019ll be creating the blueprint for the future of higher education.</p>\n\n<p>Our curriculum will be open sourced -- parts are already used by MIT and Carnegie Mellon as well as by tens of thousands of students online. You\u2019ll have the unique opportunity to engage and inspire young software engineers face-to-face as well as to impact those across the world.</p>\n\n<p><strong>What you\u2019ll do:</strong></p>\n\n<ul>\n<li>Extend and customize Make School&#39;s extensive iOS curriculum</li>\n<li>Teach core iOS mobile technologies (Swift, Objective-C)</li>\n<li>Spend 40% of your time time in the classroom, helping students with projects and identifying areas of need</li>\n<li>Spend 30% of your time working with the Curriculum Team building and updating content</li>\n<li>Spend 30% of your time working on open source projects, attending hackathons, building internal tools, etc.</li>\n</ul>\n\n<p><strong>What we&#39;re looking for:</strong></p>\n\n<ul>\n<li>Passion for teaching and mentoring developers</li>\n<li>A strongly held belief that students learn best through guided, hands-on experience</li>\n<li>Industry experience building and maintaining iOS apps, using either Objective-C or Swift</li>\n<li>Strong understanding of development best practices (TDD, version control, design patterns, performance), math principles (calculus and statistics), CS principles (algorithms and data structures), and advanced CS concepts</li>\n<li>A positive impact on the people around you</li>\n</ul>\n\n<p><strong>Become a better developer and teacher:</strong></p>\n\n<ul>\n<li>Receive expert training in research-driven teaching techniques</li>\n<li>Be involved in the development and launch of 50+ apps</li>\n<li>Contribute to open source projects and attend hackathons for free</li>\n<li>Explore the latest tools and technologies</li>\n<li>Teaching is the path to mastery!</li>\n</ul>\n\n<p><strong>Grow your professional network:</strong></p>\n\n<ul>\n<li>Networking opportunities with Make School&#39;s Corporate Partners including LinkedIn, Lyft, and MindBodyOnline</li>\n<li>Our team is a family: join us for regular networking events, city outings, company game nights, etc.</li>\n</ul>\n\n<p><strong>About Make School</strong></p>\n\n<p>Make School was founded in 2012 to empower students to build and ship products that impact their communities. Our core products include:</p>\n\n<ul>\n<li><p>Product College - An accelerated college replacement program for students who want a hands-on and product-oriented educational experience. The program spans two years, divided by a six-month internship at a tech startup. Students learn the Computer Science theory covered by traditional universities paired with the practical experience of building and shipping products, plus soft skills such as ethics, storytelling, and interpersonal communication. The program has no up front cost, and instead students pay tuition through internship and post-grad earnings.</p></li>\n<li><p>Summer Academy - An eight week program where students of all ages build and ship their own iOS app or VR experience. Locations include San Francisco, Sunnyvale, Los Angeles, New York City, Singapore, Taipei, Hong Kong, and Tokyo.</p></li>\n<li><p>S ...
#         "how_to_apply": "<p><a href=\"https://jobs.lever.co/makeschool/d87353c7-05b1-4afe-95bf-abb4fb1a8aa8/apply\">https://jobs.lever.co/makeschool/d87353c7-05b1-4afe-95bf-abb4fb1a8aa8/apply</a></p>\n",
#         "id": "1e8c129c-bd92-11e6-8617-152c7092fed4",
#         "location": "San Francisco",
#         "title": "iOS Instructor and Curriculum Engineer",
#         "type": "Full Time",
#         "url": "http://jobs.github.com/positions/1e8c129c-bd92-11e6-8617-152c7092fed4"
#     },
#     {
#         "company": "imo messenger",
#         "company_logo": "http://github-jobs.s3.amazonaws.com/a1d804d0-bce3-11e6-8a7f-9700ffb8862d.png",
#         "company_url": "https://imo.im",
#         "created_at": "Thu Dec 08 01:15:35 UTC 2016",
#         "description": "<p>imo, based in Palo Alto, is a fast growing mobile messaging app. We\u2019re building products that help hundreds of millions of people around the world easily connect with family and friends through text, voice and video chat. </p>\n\n<p>We are currently seeking experienced software engineers to work on our messaging platform. We are growing quickly and are looking for developers who have experience with highly-scalable distributed systems and developers with extensive mobile experience.</p>\n\n<p>Requirements: </p>\n\n<ul>\n<li>BS/MS/PhD in computer science (or the equivalent) </li>\n<li>Strong grasp of data structures and algorithms</li>\n</ul>\n\n<p>Extra credit: </p>\n\n<ul>\n<li>Experience building and designing scalable distributed systems </li>\n<li>Ability to design and implement systems in Java </li>\n<li>Extensive experience writing networking code in C/C++ </li>\n<li>Thorough understanding of TCP/IP and network programming </li>\n<li>Adept at hacking open source software </li>\n<li>1+ years of experience at a company that went through a significant growth stage</li>\n</ul>\n\n<p>Compensation &amp; Perks: </p>\n\n<ul>\n<li>Competitive salary plus $30K starting bonus and stock options </li>\n<li>$500/month housing stipend for living within a five-mile radius of the office </li>\n<li>Four weeks of paid vacation per year (plus paid holidays and sick days) </li>\n<li>401(k), medical, dental and vision benefits </li>\n<li>Access to a concierge medical group </li>\n<li>Catered lunch or dinner daily and a fully-stocked kitchen </li>\n<li>Data plan reimbursement </li>\n<li>Gym membership at Equinox </li>\n<li>Yearly conference stipend </li>\n<li>imo-sponsored team events and outings</li>\n</ul>\n",
#         "how_to_apply": "<p>Email your resume to <a href=\"mailto:jobs@imo.im\">jobs@imo.im</a></p>\n",
#         "id": "bb1644a2-bce3-11e6-9406-ccfe9cedada7",
#         "location": "Palo Alto, CA",
#         "title": "Software Engineer",
#         "type": "Full Time",
#         "url": "http://jobs.github.com/positions/bb1644a2-bce3-11e6-9406-ccfe9cedada7"
#     },
#     {
#         "company": "Network Merchants, LLC",
#         "company_logo": "http://github-jobs.s3.amazonaws.com/a1b8f9ec-bbed-11e6-960a-b1034c4cd71b.png",
#         "company_url": "http://nmi.com",
#         "created_at": "Tue Dec 06 19:54:25 UTC 2016",
#         "description": "<p><strong>Summary</strong> </p>\n\n<ul>\n<li>The engineering team at NMI is a small, agile group that works closely together but requires independent thinking and motivation. Engineers have direct influence over the design and implementation of systems, and infrastructure. Expertise should include fluency in Linux and security, strong troubleshooting and analytical skills, good communication skills and a genuine passion for solving problems related to scalability, performance, security and redundancy.</li>\n</ul>\n\n<p><strong>Essential Functions</strong> </p>\n\n<ul>\n<li>Communicate with staff or clients to understand specific system requirements.</li>\n<li>Provide advice on project costs, design concepts, or design changes.</li>\n<li>Document design specifications, installation instructions, and other system-related information.</li>\n<li>Verify stability, interoperability, portability, security, or scalability of system architecture.</li>\n<li>Collaborate with engineers or software developers to select appropriate design solutions or ensure the compatibility of system components.</li>\n<li>Provide technical guidance or support for the development or troubleshooting of systems.</li>\n<li>Identify system data, hardware, or software components required to meet user needs.</li>\n<li>Monitor system operation to detect protential problems.</li>\n<li>Perform all other related duties, as assigned.</li>\n</ul>\n\n<p><strong>Qualifications and Education Requirements</strong> </p>\n\n<ul>\n<li>Bachelor of Science degree in a related field and/or commensurate experience.</li>\n<li>5+ years working with enterprise level Linux servers, monitoring and storage</li>\n</ul>\n\n<p><strong>Knowledge, skills, abilities and other characteristics</strong> </p>\n\n<ul>\n<li>Familiarity with networking equipment such as switches, firewalls and load balancers from Cisco, - Juniper and F5 Working knowledge of PHP and Perl</li>\n<li>Expertise with Linux Servers particularly Redhat or CentOS</li>\n<li>Expertise with Apache, MySQL, Bash Scripting, Security and\nMonitoring Tools</li>\n<li>Expertise with Puppet configuration and maintenance</li>\n<li>Being cognizant of Systems Security</li>\n<li>Fluent written communication and verbal agility</li>\n<li>Working knowledge of PCI-DSS is a plus</li>\n<li>Strong troubleshooting and analytical skills</li>\n<li>Good communication skills</li>\n<li>Genuine passion for solving problems related to scalability, performance, security and redundancy.</li>\n<li>Working knowledge of source control repositories like GIT</li>\n</ul>\n\n<p><strong>Physical requirements and environment</strong> </p>\n\n<ul>\n<li>The ability to see details at close range (within a few feet of the observer).</li>\n<li>General office conditions.</li>\n<li>Regular attendance and reliability is mandatory.</li>\n</ul>\n\n<p><strong>Tools used</strong> </p>\n\n<ul>\n<li>Enterprise hardware (Rack servers, SAN, load balancers, networking equipment)</li>\n<li>Linux based servers and services \u2013 Web, Application, FTP, SMTP, Puppet</li>\n<li>Linux based monitoring systems</li>\n<li>Jira and Confluence for task and project management</li>\n<li>Computer</li>\n<li>Printer</li>\n<li>Fax Machine</li>\n<li>Scanner</li>\n</ul>\n",
#         "how_to_apply": "<p>Please E-mail your resume to <a href=\"mailto:hr@nmi.com\">hr@nmi.com</a></p>\n",
#         "id": "beb74684-bbed-11e6-8197-64e617b51adf",
#         "location": "Roselle, IL",
#         "title": "Linux Systems Engineer",
#         "type": "Full Time",
#         "url": "http://jobs.github.com/positions/beb74684-bbed-11e6-8197-64e617b51adf"
#     },
#     {
#         "company": "Stevens Capital Management LP",
#         "company_logo": "http://github-jobs.s3.amazonaws.com/5df90c6a-baf8-11e6-8a38-492033c01d86.png",
#         "company_url": "http://www.scm-lp.com",
#         "created_at": "Mon Dec 05 14:38:11 UTC 2016",
#         "description": "<p>Stevens Capital Management LP (\u201cSCM\u201d) is a registered investment adviser that manages a multi-billion dollar hedge fund that has been in business for 25+ years.\nSCM specializes in the rigorous development and disciplined implementation of empirically based quantitative trading strategies. Our highly productive team works in a fast-paced collegial environment, utilizing extensive data sets, technology and the scientific method to devise and employ trading strategies throughout the world\u2019s most liquid financial markets.</p>\n\n<p>Implementation Developer</p>\n\n<p>We&#39;re seeking highly driven, production-oriented developers who possess strong technical skills and the ability to work in a fast-paced collaborative environment.  </p>\n\n<p>Primary Responsibilities</p>\n\n<ul>\n<li>Develop and support multi-threaded applications with a strong emphasis on high performance.</li>\n<li>Optimize our trading strategy implementation and performance analysis platform using network and systems programming.</li>\n<li>Create tools to process, store and analyze quote, order and financial data.</li>\n<li>Work closely with our quantitative research analysts, engineers and other groups to provide software solutions.</li>\n</ul>\n\n<p>Requirements</p>\n\n<ul>\n<li>Professional-level C++ programming experience in a Linux environment. </li>\n<li>A Computer Science or Mathematics degree.</li>\n<li>Outstanding problem solving skills.</li>\n<li>Knowledge of shell scripts and other languages including Perl, Bash or CSH is a plus.</li>\n<li>Experience with relational databases including Sybase, SQL Server and Oracle is a plus.</li>\n<li>Experience with GUI design is a plus.</li>\n</ul>\n",
#         "how_to_apply": "<p>Please submit your resume to: <a href=\"mailto:recruiting@scm-lp.com\">recruiting@scm-lp.com</a></p>\n\n<p>Website: <a href=\"http://www.scm-lp.com\">www.scm-lp.com</a></p>\n",
#         "id": "61433012-baf8-11e6-8d18-1baa36e6dbf5",
#         "location": "Radnor, PA. USA",
#         "title": "Implementation Developer",
#         "type": "Full Time",
#         "url": "http://jobs.github.com/positions/61433012-baf8-11e6-8d18-1baa36e6dbf5"
#     },
#     {
#         "company": "GenePeeks, Inc",
#         "company_logo": "http://github-jobs.s3.amazonaws.com/67ea79ea-b8c6-11e6-81ec-ba6eeed777c6.jpg",
#         "company_url": "http://www.genepeeks.com",
#         "created_at": "Fri Dec 02 19:36:23 UTC 2016",
#         "description": "<p>Job description</p>\n\n<p>GenePeeks is a data-driven genetics start-up pushing the boundaries of reproductive health care and computational genetics. As a result, we are looking for an engineer who is passionate in helping us shape how we, as humans, consume and interpret genetic information.  The right candidate has proven experience designing and growing cloud-based architectures and infrastructures. You should never have to manually perform a task more than once, since you have a passion for automation and wrote a deploy script to do it for you on day one. You will have built solutions that scaled rapidly to meet global needs, and have the battle scars to prove that not everything goes according to plan, but you\u2019ve learned and are better for it. Lastly, you pride yourself on elegant solutions which are built for the future and your fellow engineers,  all while not losing sight of the bigger picture.</p>\n\n<p>Relevant Experience:</p>\n\n<ul>\n<li>4+ years of relevant industry experience, someone who has \u2018been there\u2019 and \u2018done that\u2019.</li>\n<li>Familiarity with most of the heavy hitters in our stack which are AWS, NGINX, Python, Django, PostgreSQL, MongoDB, and Redis.</li>\n<li>Experience with industry staples in automation like Puppet, Chef, or Ansible. Also uses CI services like CircleCI, TravisCI, or Jenkins.</li>\n<li>Experience developing with containers/virtualized applications in the cloud i.e. Docker with EC2.</li>\n<li>Experience utilizing and contributing to open-source tools and code.</li>\n<li>Utilize data-driven development in monitoring and logging with analytics being second-nature</li>\n</ul>\n\n<p>Nice-to-haves:</p>\n\n<ul>\n<li>B.S. or equivalent in computer science or related field.</li>\n<li>Scripting/programming experience using Bash or Python.</li>\n<li>Experience working with SQL(PostgreSQL), NoSQL(MongoDB), Key-value store(Redis) in a production environment i.e. vertical scaling, replica sets, and sharding.</li>\n<li>Experience with load balancing and stress testing deployment configurations.</li>\n<li>A strong grasp of data structures, algorithms, databases, etc.</li>\n<li>You wear every 9 of uptime as a badge of honor.</li>\n</ul>\n\n<p>Other Benefits:</p>\n\n<ul>\n<li>Competitive Salary</li>\n<li>Stock Options</li>\n<li>Comprehensive Health and Dental benefits.</li>\n<li>Apple equipment</li>\n<li>Your coworkers are as passionate about applied genetics as they are about climbing, sailing, biking, and Game of Thrones! (and Harry Potter)</li>\n<li>Our office space is on the Red Line, has tons of natural light, and plenty of brick-and-beam Cambridge character.</li>\n</ul>\n\n<p>Location:\nThis position will be located in the Boston or New York area.\n*GenePeeks will not offer visa sponsorship for this position</p>\n",
#         "how_to_apply": "<p><a href=\"http://careers.genepeeks.com/o/software-engineer-devops=GitHub\">http://careers.genepeeks.com/o/software-engineer-devops=GitHub</a></p>\n",
#         "id": "6d409aaa-b8c6-11e6-8408-7debc09d256f",
#         "location": "Cambridge, MA",
#         "title": "Software Engineer, DevOps",
#         "type": "Full Time",
#         "url": "http://jobs.github.com/positions/6d409aaa-b8c6-11e6-8408-7debc09d256f"
#     },
#     {
#         "company": "Intel Corporation",
#         "company_logo": "http://github-jobs.s3.amazonaws.com/0590279e-b7eb-11e6-92e0-095053d3f49d.png",
#         "company_url": "http://jobs.intel.com",
#         "created_at": "Fri Dec 02 11:49:17 UTC 2016",
#         "description": "<p>Employees of the Internet of Things Solutions Group (IOTG) have an exciting opportunity before them: To grow Intel&#39;s leadership position in the rapidly evolving IoT market by delivering the best silicon, software and services that meet a wide range of customer requirements - from Intel\u00ae Xeon\u00ae to Intel\u00ae Quark\u00ae. The group, a fresh, dynamic collaboration between Intel&#39;s Intelligent Solutions Group and Wind River Systems, utilizes assets from across all of Intel in such areas as industrial automation, retail, automobiles and aerospace.\nThe IOTG team is dedicated to helping Intel drive the next major growth inflection through productivity and new business models that are emerging as a result of IoT. Intel&#39;s Transportation Solutions Division is at the forefront of bringing highly and fully automated vehicles to market with our partners from the automotive industry.  </p>\n\n<p>Come join a dynamic and fast paced environment where the possibilities are limited only by your imagination.  </p>\n\n<p>We are looking for the Software Engineer on the Automated Driving team who will design and develop software for next generation automated driving systems. The position will include design and implementation of embedded software.  </p>\n\n<p>In the role you will be responsible for supporting research and developmental efforts in automated vehicle technologies ranging from Advanced Driver Assistance Systems (ADAS) to semi- and fully-autonomous driving capabilities.\nAs an Automated Driving Software Development Engineer, your responsibilities will include but are not be limited to:</p>\n\n<ul>\n<li>Design and develop state-of-the-art computing platforms for next generation automated driving systems</li>\n<li>System Modelling of complete AD systems and subsystems</li>\n<li>Development of middleware components for highly efficient embedded systems font size\nRequirements:</li>\n<li>Qualifications: Bachelor degree in Computer Science, Electrical Engineering, or related field plus 6 years of work experience, Master&#39;s degree in Computer Science, Electrical Engineering, or related field plus 4 years of related work experience, or PhD in Computer Science, Electrical Engineering, or related field plus 2 years of related work experience.</li>\n<li>Excellent skills in C++ and standard libraries (e.g. STL, OpenCL, Boost)Experience developing software for Linux</li>\n<li>Advanced English communication skills, both written \u00a0verbal\nYou will have some of the following:</li>\n<li>Master\u2019s degree or PhD in Electrical or Computer Engineering or similar field of study \u2022 Familiarity with ADAS or AD</li>\n<li>Experience with Functional Safety</li>\n<li>Experience with embedded RTOS</li>\n<li>Experiences with machine learning systems</li>\n<li>Experience in image processing, computer vision, OpenCV</li>\n<li>Experiences with Robot Operating System (ROS)</li>\n<li>Software/firmware development in one or more languages/platforms/libraries (C/C++, VHDL/Verilog, MATLAB, CUDA, OpenCL)</li>\n<li>Familiarity with sensor modalities used in robotics and automated driving applications (Camera/Vision, RADAR, LIDAR, INS/IMU)</li>\n<li>Familiarity with commonly used approaches for autonomous systems (sensor data processing, data fusion, scene analytics, scene interpretation, behavior prediction, trajectory planning, et.)</li>\n<li>Working Knowledge of Linux in embedded applications</li>\n<li>Experiences in system modelling (UML, SysML) and automated code generation \u2022 Experiences with Eclipse and Yocto</li>\n<li>Experiences with ADTF and ROS<br></li>\n</ul>\n\n<p>\u2028Qualifications\u2028<br>\nInside this Business Group\u2028<br>\nEmployees of the Internet of Things Solutions Group (IOTG) have an exciting opportunity before them: To grow Intel&#39;s leadership position in the rapidly evolving IoT market by delivering the best silicon, software and services that meet a wide range of customer requ ...
#         "how_to_apply": "<p>Apply on company website: <a href=\"http://career.intel.com/TpLVa\">http://career.intel.com/TpLVa</a></p>\n",
#         "id": "47b78b5e-b7ef-11e6-86f0-a00baabc0c92",
#         "location": "Karlsruhe, Germany",
#         "title": "Automated Driving SW Development Engineer",
#         "type": "Full Time",
#         "url": "http://jobs.github.com/positions/47b78b5e-b7ef-11e6-86f0-a00baabc0c92"
#     },
#     {
#         "company": "Intel Corporation",
#         "company_logo": "http://github-jobs.s3.amazonaws.com/8fe64a66-b7ed-11e6-9afe-3b4e9182fd07.png",
#         "company_url": "http://jobs.intel.com",
#         "created_at": "Fri Dec 02 11:49:15 UTC 2016",
#         "description": "<p>Duties are focused on development open-source LLVM/GCC toolchain for Intel Architecture in Linux and Android target environments.  </p>\n\n<p><strong>Responsibilities include:</strong> \nDesign modules and software systems for compiler toolchain, including enabling new IA technology or improving performance and quality of existing functionality. Research fundamental problems and implement algorithm solutions with primary focus on backend compiler optimizations.  </p>\n\n<p><strong>What do we offer:</strong><br>\n\u2028On top of that we at Intel provide you with bonuses, trainings, conferences, private medical plan, life insurance, lunch coupons and a chance to participate in Intel Great Place to Work programs supporting diverse activities/hobbies (e.g. running, cycling, squash, tennis, cross fit, photography).  </p>\n\n<p><strong>\u2028Qualifications\u2028\u2028</strong><br>\n<strong>Must have:</strong>\u00a0 \n\u2028- B.S or M.S in Computer Science, or Electrical Engineering, or Computer Engineering or equivalent<br>\n\u2028- Excellent knowledge of C and C++ programming language\u00a0 \n\u2028- Familiarity with source control systems such as git/svn/cvs\u00a0 \n\u2028- Knowledge of Unix-based operating systems and development environment, tools such as shell/make/etc.\u00a0\u2028 </p>\n\n<ul>\n<li>Excellent understanding of algorithms design and data structures\u00a0 \n\u2028- Good experience of debugging issues with gdb/lldb/idb.\u00a0\u2028 </li>\n<li>Familiarity with x86 Intel Architecture Positive team work experience Fluent English\u00a0\u2028\u2028Highly<br></li>\n</ul>\n\n<p><strong>Recommended:</strong>\u00a0\u2028 </p>\n\n<ul>\n<li>Experience of development and knowledge of internals of LLVM/GCC is a great advantage for any candidate.\u00a0 \n\u2028- Experience of work with Open Source communities. Understanding the principles of open source contributions.</li>\n</ul>\n\n<p><strong>Inside this Business Group</strong>\u2028\nThe Intel Software and Services Group (SSG) connects Intel to the worldwide software community. SSG strives to bring competitive advantage to Intel platforms by helping independent software vendors, operating system developers, OEMs, channel members and systems integrators deliver exceptional customer value and achieve differentiation on Intel\u00ae processor technologies. SSG provides global leadership to the software community through its technical expertise, industry enabling activities, and developer products and programs.</p>\n",
#         "how_to_apply": "<p>Apply on company website: <a href=\"http://career.intel.com/TpHFE\">http://career.intel.com/TpHFE</a></p>\n",
#         "id": "88d7a11e-b7ef-11e6-8839-4baedb4f1c00",
#         "location": "Gdansk, Poland ",
#         "title": "Software Development Engineer C, C++",
#         "type": "Full Time",
#         "url": "http://jobs.github.com/positions/88d7a11e-b7ef-11e6-8839-4baedb4f1c00"
#     },
#     {
#         "company": "PDT Partners",
#         "company_logo": "http://github-jobs.s3.amazonaws.com/1dee7540-b7f8-11e6-8780-56e37987ae3b.png",
#         "company_url": "http://www.pdtpartners.com",
#         "created_at": "Thu Dec 01 18:59:13 UTC 2016",
#         "description": "<p><strong>C++/Python Engineers</strong></p>\n\n<p>We\u2019re looking for a select few uniquely excellent C++/Python engineers to join our world-class team. PDTers are creative, energetic, friendly, entrepreneurial, and collaborative. If you could walk around our office, you\u2019d see that we\u2019re a focused, intent, and nimble company with none of the attitude and bureaucracy a stereotypical Wall Street trading firm. Our engineers love to work on challenging and complicated problems, and in return, they have a chance to make a direct impact on our bottom line. For the right talent, there is fantastic growth potential. </p>\n\n<p>Our standards for code quality are high, and our bar for the software engineers who write it is stratospheric.  The most successful engineers at PDT move fluidly between roles over time. Engineering jobs at PDT have some different flavors with a mix of C++ and Python focuses:</p>\n\n<p><strong>Trading Infrastructure Technology (C++ Focus)</strong></p>\n\n<p>Every action we take in the market is conceived, executed, verified, processed, and reported using software we wrote expressly for the purpose.  Our business depends on automated trading platforms that are fast, stable, resilient, and innovative.</p>\n\n<ul>\n<li>Create, support, and improve our fast real-time global trading engine \u2013 the automated platform on which all of our trading strategies run</li>\n<li>Manage the codebase that runs order routing and execution, exchange connectivity, and market data</li>\n<li>Be a partner to our research strategies, systems engineers, and business operations teams to ensure success</li>\n</ul>\n\n<p><strong>Trading Business Technology (Python Focus)</strong> </p>\n\n<p>Running our business responsibly means keeping close track of our fund positions, risks, compliance, and the value of every single asset we hold at any given time. Designing and engineering our next generation platform for routing and managing all of our post-trade data is an exceptional challenge and a top business priority.</p>\n\n<ul>\n<li>Redesign, build, and evolve our post-trade technology stack for finance, fund operations, analytics, risk, and compliance.</li>\n<li>Own the selection, vetting, and integration of open-source and third-party platforms.</li>\n<li>Be a business partner to our CFO, COO, and operations teams</li>\n</ul>\n\n<p><strong>Software Infrastructure (C++ and Python Focus)</strong></p>\n\n<p>Although we write plenty of our software completely from scratch, we also create an ever-expanding set of powerful tools, services, and common frameworks our developers can use used as building blocks. If you\u2019re the kind of developer who loves writing ingenious code that helps other people write more ingenious code, you\u2019ll love this job.</p>\n\n<ul>\n<li>Write, manage, and evolve the core software DNA of libraries and services that our engineers use to write all of the code that runs our business: logging and discovery, orchestration, tooling, services, etc.</li>\n<li>Innovate in and improve the quality of our development environment, from source control to compilers and beyond</li>\n<li>Work closely with Systems Infrastructure engineers to ensure that the software development lifecycle is woven into the fabric of our environment</li>\n<li>Play a transformative role in increasing the effectiveness of our software engineers and the quality of our codebase</li>\n</ul>\n\n<p><strong>Research Infrastructure (C++ and Python Focus)</strong></p>\n\n<p>In order to work their magic, our research scientists and software engineers rely on a suite of bespoke tools, libraries, and applications, running in a fast and stable research grid environment.  It\u2019s this technical foundation that makes our innovative research possible, so we devote significant time and attention to getting it right.</p>\n\n<ul>\n<li>Build and manage libraries and APIs, as well as the container, distributed algorithm, grid-abstr ...
#         "how_to_apply": "<p><a href=\"http://grnh.se/h8l4dk1\">http://grnh.se/h8l4dk1</a></p>\n",
#         "id": "24d6d212-b7f8-11e6-9bc0-4c468fa010c5",
#         "location": "New York",
#         "title": "C++/Python Developer",
#         "type": "Full Time",
#         "url": "http://jobs.github.com/positions/24d6d212-b7f8-11e6-9bc0-4c468fa010c5"
#     },
#     {
#         "company": "CrowdFlower",
#         "company_logo": null,
#         "company_url": null,
#         "created_at": "Tue Nov 29 23:27:00 UTC 2016",
#         "description": "<p><h2><strong>About CrowdFlower...</strong></h2><p>CrowdFlower is the essential human-in-the-loop platform for data science teams. CrowdFlower helps customers generate high quality customized training data for their machine learning initiatives and to automate business processes with easy-to-deploy ML models and integrated human-in-the-loop workflows. The CrowdFlower platform supports a wide range of use cases including self-driving cars, intelligent personal assistants, medical image labeling, content categorization, customer support ticket classification, social data insight, CRM data enrichment, product categorization, and search relevance.\u00a0</p><p>Headquartered in San Francisco and backed by Canvas Venture Fund, Trinity Ventures, and Microsoft Ventures, CrowdFlower serves data science teams at Fortune 500 and fast-growing data-driven organizations across a wide variety of industries. For more information, visit <a href=\"http://www.crowdflower.com\">www.crowdflower.com</a>.</p><p>We are looking for smart, innovative people to help us build scalable, resilient and responsive systems, working with our team based in either San Francisco\u2019s Mission District or Sacramento California.\u00a0</p><h2><strong>The Ideal Candidate</strong></h2><p>You are an experienced application developer who knows how to design and implement scalable, resilient, secure and responsive systems. You like to work with different technologies and are passionate about learning new things. You take pride in designing elegant, simple solutions to challenging problems, whether updating legacy systems or creating new micro-services. You can help to ensure we continue to evolve and keep our edge as a world\u00ac-class development team building great products. You are looking to join a team where you can make a difference while also being challenged to improve your own skills.</p><h3>Responsibilities:</h3><ul><li>Participate in designing and developing robust, scalable systems with modern design patterns in a services oriented architecture.</li><li>Take the initiative to share your skills &amp; knowledge with other members of the team and learn from them in return. Collaboration is key.</li><li>Demonstrate ownership and pride in your work and encourage others to do the same.</li><li>Analyze and improve existing systems and offer go-forward suggestions to enhance scalability, resiliency and performance.</li><li>Promote best practices for writing maintainable, well\u00ac-tested code within a scrum based agile process.</li></ul><h3>Skills &amp; Experience:</h3><ul><li>Bachelor&#39;s degree or higher in Computer Science, or equivalent work experience.</li><li>Strong expertise with Ruby and Rails is a must. Experience with other programming languages such as Node.js or Java are a definite asset.</li><li>Experience with a range of data stores, including relational (SQL), column\u00ac-oriented and key\u00acvalue stores (ideally Postgres, Memcache, Redis, RedShift).</li><li>Knowledge of professional software engineering best practices for the full software development life cycle, including coding standards, code reviews, source control management, agile development, build processes, testing, and operations.</li><li>Experience with the AWS platform and its many components (S3, API Gateway, Lambda etc) is a plus.</li><li>Experience creating RESTful API\u2019s is a plus.</li><li>Experience with Docker containerization is a plus.</li></ul><p>CrowdFlower offers an attractive total compensation package including outstanding benefits and stock options.</p> <img src=\"https://www.applytracking.com/track.aspx/7IJjT\"/></p>\n",
#         "how_to_apply": "<p><a href=\"https://www.applytracking.com/track.aspx/7IJjd\">https://www.applytracking.com/track.aspx/7IJjd</a></p>\n",
#         "id": "53eb1432-b68b-11e6-805c-42ae75f605e1",
#         "location": "San Francisco, CA, US",
#         "title": "Ruby/Rails BackEnd Developer",
#         "type": "Full Time",
#         "url": "http://jobs.github.com/positions/53eb1432-b68b-11e6-805c-42ae75f605e1"
#     },
#     {
#         "company": "Carbon Black, Inc.",
#         "company_logo": "http://github-jobs.s3.amazonaws.com/309b531e-b679-11e6-8bed-4a8a3761e6da.jpg",
#         "company_url": "https://www.carbonblack.com/",
#         "created_at": "Tue Nov 29 21:23:04 UTC 2016",
#         "description": "<p><strong>Why Carbon Black?</strong></p>\n\n<p>At Carbon Black, you\u2019ll have the opportunity to make a huge impact while working alongside a global community of passionate people who are leading the way in cutting-edge technology. Our valued employees across the world have made Carbon Black a Top Place to Work, as named by the Boston Globe for two consecutive years.</p>\n\n<p>Our Engineering team is moving at lightning speed on the breaking edge of technology. You\u2019ll be pulling things apart and tinkering, building new platforms, or playing in the cloud. Here, the engineering opportunities are endless. With this fast-paced, synergetic group, you\u2019ll be working together and across the organization to ensure customer success all while continuing to build a product that protects their dearest assets.</p>\n\n<p><strong>Why You Matter:</strong></p>\n\n<p>There\u2019s incredible excitement and urgency around cyber security software right now.  Protecting the world\u2019s Intellectual Property is an imperative and Carbon Black is at the forefront of this market, providing solutions that protect industry and thought leaders in the Commercial, Retail, Finance, Energy and Government sectors.</p>\n\n<p>We\u2019re looking for a Senior Software Engineer to join our Collective Defense Cloud Engineering Team building solutions that will help us enrich, analyze and deliver our industry leading Threat Intelligence data to our customers. You\u2019ll join a talented team of developers using a wide variety of cool technologies to solve big problems.  You\u2019ll partner with some impressive threat researchers who are on the bleeding edge of malware analysis. You\u2019ll build solutions that our customers are clamoring for, that will help our customers prevent the next front page security breach. You\u2019ll make a difference and help us win a huge market.  Sound good?  </p>\n\n<p><strong>What You\u2019ll Do:</strong></p>\n\n<ul>\n<li>Lead the development of new features while also maintaining and enhancing existing features within our Cb Collective Defense Cloud</li>\n<li>Design and implement RESTful web services (using python, Java, etc.) for an AWS cloud deployment, leveraging many AWS service offerings and technologies</li>\n<li>Participate in the design and implementation of a Big Data analytics platform (NoSQL, Hadoop, Spark, EMR, etc.)</li>\n<li>Deliver high quality, secure and scalable solutions alongside the rest of the dev team as part of an Agile SDLC</li>\n<li>Analyze performance of services and optimize / refactor as needed</li>\n<li>Investigate functional problems, finding and fixing defects as needed</li>\n<li>Independently schedule and manage work items (defects, user stories, features, etc.)</li>\n<li>Design proof of concepts or working prototypes for software services</li>\n<li>Ensure that software designs follow best-practices and architectural guidelines</li>\n</ul>\n\n<p><strong>What You\u2019ll Bring:</strong></p>\n\n<p>To perform this job successfully, an individual must be able to perform each essential duty satisfactorily.  Other duties may be assigned to meet business needs.  Reasonable accommodations may be made to enable individuals with disabilities to perform the essential functions.</p>\n\n<ul>\n<li>B.S. in Computer Science or equivalent experience</li>\n<li>Five+ years\u2019 experience in designing and delivering commercial software products</li>\n<li>High level of expertise programming in python, Java or equivalent programming languages on Linux</li>\n<li>Solid RDBMS experience and fundamentals</li>\n<li>Demonstrated aptitude in quickly mastering new languages and technologies</li>\n<li>Excellent communication and interpersonal skills</li>\n<li>Excellent problem solving and troubleshooting skills</li>\n<li>Amazon AWS experience a big plus</li>\n<li>Security Experience a big plus</li>\n<li>NoSQL experience a plus</li>\n</ul>\n\n<p><strong>Who We Are:</strong></p>\n\n<p>Carbon Bla ...
#         "how_to_apply": "<p><a href=\"https://lifeatcb.carbonblack.com/job-postings/?p=job/oMPL3fw9&amp;__jvst=JobBoard&amp;__jvsd=Github&amp;nl=1\">Click here to apply.</a></p>\n",
#         "id": "f2dff876-b679-11e6-896e-3954f140fe85",
#         "location": "Waltham, MA or Telecommute",
#         "title": "Senior Software Engineer - Cloud",
#         "type": "Full Time",
#         "url": "http://jobs.github.com/positions/f2dff876-b679-11e6-896e-3954f140fe85"
#     },
#     {
#         "company": "SmarterTravel",
#         "company_logo": "http://github-jobs.s3.amazonaws.com/d4a4f27e-b667-11e6-9318-ad870fa045f5.png",
#         "company_url": "http://www.wearesmartertravel.com",
#         "created_at": "Tue Nov 29 19:14:14 UTC 2016",
# ...
#         "location": "Sierra Leone",
#         "title": "Senior Andriod Developer(Freelance for 6 months)",
#         "type": "Full Time",
#         "url": "http://jobs.github.com/positions/2e1b4148-ab49-11e6-8b5d-230703ad0bc9"
#     },
#     {
#         "company": "Johnson Controls",
#         "company_logo": "http://github-jobs.s3.amazonaws.com/9c77a9be-aa9b-11e6-9186-3e169096f20b.png",
#         "company_url": "http://www.tyco.com/",
#         "created_at": "Mon Nov 14 18:54:05 UTC 2016",
#         "description": "<p>ANDROID JOB DESCRIPTION\niOS and/or wearable is nice to have. Bluetooth and Embedded Experience also nice to have.</p>\n\n<p>As a Senior Mobile Engineer you will be tasked with building Native Android projects from the ground up located here in Irvine, CA.\u00a0</p>\n\n<p>These projects are to follow the most modern practices and are intended to be Rapid Prototyping or Rapid Application Development for various innovative Projects. Tools may include:</p>\n\n<ul>\n<li>Android Studio</li>\n<li>Java</li>\n<li>Gradle</li>\n<li>NDK</li>\n<li>Open Source Libraries</li>\n<li>Reusable Internal Libraries</li>\n<li>Dependency Management Servers\nThis Engineer will be helping to set the standards for the rest of the company and build out reusable libraries that can help other teams to develop more rapidly. Some tools, some shared libraries, and some prototypes for testing out new technologies. Examples of needed libraries are:</li>\n<li>SDK for IoT integration</li>\n<li>SDKs for individual BUs fire, security, lighting, card access, burglary, home automation</li>\n<li>Libraries for logging, environment handling, custom UI Widgets and Libraries</li>\n<li>Bluetooth, embedded interactions, BLE communications, and various R&amp;D innovations</li>\n<li>Whatever else is innovative and reusable that we should abstract\nThis is a very diverse role that is continually challenging and evolving for a person who enjoys to learn and grow in their areas of expertise and expand into other areas while remaining current in best practices for the code that is written. We are looking for a tenacious and excitable consultant to join the team and help build this eco system from the ground up with us. We do not want developers who are stuck in their way, or desire to continue working with old technology when newer stuff is available. Candidate Must be innovative and comfortable in bleeding edge technologies as well as various communication protocols.</li>\n</ul>\n\n<p>If this sounds like you then come join us, invent, innovate, and help us light the way for future development across a 57,000 employee company while adding to a fun and excitable work environment meant to challenge and facilitate teamwork and fun.</p>\n\n<p>Our Requirements</p>\n\n<ul>\n<li>Minimum qualifications include a Bachelor&#39;s degree in Computer Science (or related field) from an accredited college or university (four years relevant work experience may be substituted for education). 5+ years developing large-scale, enterprise-wide, commercial software with minimum 3 years focused in Mobile.</li>\n<li>Leadership abilities to run a project, gather requirements and work directly with different customers to ensure their needs are met.</li>\n<li>Scrum Master experience is a plus, but must be open to learning it at least</li>\n<li>3+ years experience developing highly scalable data-driven applications with client/server interactions</li>\n<li>5+ years experience with object oriented programming languages (Objective-C, Swift, Java) with in-depth knowledge of the Language Idioms and usages. </li>\n<li>3+ years experience building mobile applications on Android platform.</li>\n<li>3+ years experience integrating with SOAP/REST web services.</li>\n<li>2+ years experience performance testing, monitoring, troubleshooting deployed applications, installed and actively used on mobile devices.</li>\n<li>Strong grasp of computer science, data structures and algorithms.</li>\n<li>Strong mobile UI design skills for resolution variations, orientation management and size handling.</li>\n<li>Excellent understanding of support, scaling, styling, and best practices for enterprise development</li>\n<li>1+ year experience using common cloud architecture, enabling components, and deployment platforms Parse, LAMP, MEAN, whatever infrastructure enables client/server interactions</li>\n<li>1+ year experience with mobile push notifications (APNs, GCM).</li>\n<li>Experience with development  ...
#         "how_to_apply": "<p>Visit:\n<a href=\"https://jobs.johnsoncontrols.com/job-details/software-engineer-iii-mobile/649849012/\">https://jobs.johnsoncontrols.com/job-details/software-engineer-iii-mobile/649849012/</a></p>\n\n<p>or</p>\n\n<p>send resume directly to <a href=\"mailto:JoPedroza@tycoint.com\">JoPedroza@tycoint.com</a> for review</p>\n",
#         "id": "a0e32852-aa9b-11e6-93e6-4146165b3b6f",
#         "location": "Irvine, CA",
#         "title": "Senior Android Engineer",
#         "type": "Full Time",
#         "url": "http://jobs.github.com/positions/a0e32852-aa9b-11e6-93e6-4146165b3b6f"
#     },
#     {
#         "company": "SAP",
#         "company_logo": "http://github-jobs.s3.amazonaws.com/05fe7560-aa98-11e6-9e8a-0e66c883b7dd.png",
#         "company_url": "https://jobs.sap.com/search/?q=SAPmachinelearningcareers&locationsearch=&utm_source=github&utm_campaign=sap_machinelearning",
#         "created_at": "Mon Nov 14 18:29:10 UTC 2016",
#         "description": "<p><a href=\"https://jobs.sap.com/job/Palo-Alto-Developer-with-ML-background-for-Machine-Learning-development-Job-CA-94301/327259801/?feedId=203001&utm_source=github&utm_campaign=sap_machinelearning\">Apply on our career site here.</a></p>\n\n<ul>\n<li>Initiates and participates in projects in the area of prediction, optimization, and processes using advanced statistical / mathematical approaches, in the enterprise environment.</li>\n<li>Design best architecture and select the most appropriate modeling techniques and data visualization for big data analysis.</li>\n<li>Ability to capture customer requirements and translate them into software specifications</li>\n<li>Iteratively test, refine and improve the models.</li>\n</ul>\n\n<p>You are a self-starter, goal-oriented, striving for perfection engineer. As an ideal candidate you will demonstrate a proven track record of enterprise-grade product releases preferably as cloud-based solutions.\nRequired</p>\n\n<ul>\n<li>M.S. or Ph.D. in Computer Science, Electrical Engineering, Statistics, Applied Math or related topics</li>\n<li>Strong background in mathematics, statistics and programming</li>\n<li>Experience in statistical modeling, machine learning, or data mining practice.</li>\n<li>Experience in SQL, relational databases, database concepts, dimensional modeling and database design</li>\n<li>Proficient in one or more programming languages such as Java, C++, Python, JavaScript</li>\n<li>Familiar with one or more machine learning or statistical modeling tools</li>\n</ul>\n\n<p><a href=\"https://jobs.sap.com/job/Palo-Alto-Developer-with-ML-background-for-Machine-Learning-development-Job-CA-94301/327259801/?feedId=203001&utm_source=github&utm_campaign=sap_machinelearning\">Apply on our career site here.</a></p>\n",
#         "how_to_apply": "<p><a href=\"https://jobs.sap.com/job/Palo-Alto-Developer-with-ML-background-for-Machine-Learning-development-Job-CA-94301/327259801/?feedId=203001&utm_source=github&utm_campaign=sap_machinelearning\">Apply on our career site here.</a></p>\n",
#         "id": "0e70b42e-aa98-11e6-9dc7-99d5c3a10bc9",
#         "location": "Palo Alto",
#         "title": "Developer with ML background for Machine Learning development Job",
#         "type": "Full Time",
#         "url": "http://jobs.github.com/positions/0e70b42e-aa98-11e6-9dc7-99d5c3a10bc9"
#     },
#     {
#         "company": "Leadpages",
#         "company_logo": "http://github-jobs.s3.amazonaws.com/314925f0-a83e-11e6-8350-38442bc0d153.png",
#         "company_url": "http://www.leadpages.net/",
#         "created_at": "Fri Nov 11 18:41:52 UTC 2016",
#         "description": "<p>We promise you haven\u2019t worked with anyone <a href=\"http://www.leadpages.net/careers\">like us</a> before.  We\u2019re a Minneapolis / St. Paul, MN based startup that\u2019s changing the way businesses do marketing, lead generation, and conversion rate optimization online.  With a growing team that works closely together, we move fast and enjoy what we do. </p>\n\n<p>As a <strong>Site Reliability Engineer</strong>, you&#39;ll work with a dynamic team to help build out and manage our cloud infrastructure and deployment pipelines. You\u2019ll partner with development teams to build and support tooling - specializing in centralized logging, monitoring and alerting. You will also develop a strong familiarity with all aspects of our overall architecture, including Javascript front-ends, Python API microservices, and Scala-based data science backends. There\u2019s nothing boring about this position!</p>\n\n<p>Come join the fun and build something great with us!</p>\n\n<p><strong>What you\u2019ll do:</strong></p>\n\n<p>Your day-to-day responsibilities will shift and grow but to start with, you will:</p>\n\n<ul>\n<li>Help manage our virtualized cloud infrastructure in the Google Cloud stack: App Engine, Container Engine (Kubernetes), Compute Engine, Cloud Datastore, Cloud Storage, Cloud SQL and BigQuery. Some familiarity with this stack or similar would be amazing!</li>\n<li>Automate application deployment and infrastructure creation processes with Jenkins, Ansible, Packer, Terraform and the Docker toolkit. Again, if you have hands-on experience with these tools or something similar, this could be your jam</li>\n<li>Think laterally and collaborate with other teams to work through tough challenges</li>\n<li>Craft awesome solutions while taking the needs of multiple areas of the organization into account</li>\n<li>Push back and voice your opinion if you think differently from the rest of the team. Yep! We truly value your opinion and we want to hear it</li>\n<li>Work within the fast-paced, lean startup environment, knowing it means we ship early and often.</li>\n<li>Watch what you\u2019ve made help your teammates create awesome customer value. This is what it\u2019s all about!</li>\n</ul>\n\n<p><strong>What you\u2019ve done:</strong></p>\n\n<p>You have a unique combination of skills, talents, and mindset, including:</p>\n\n<ul>\n<li>Experience with building and scaling complex application systems</li>\n<li>A background in scripted provisioning / configuration management tools (think Bash, Ansible, Packer, Terraform, Fabric, and similar)</li>\n<li>Familiarity with Docker and container-based building, deployment, orchestration and service discovery</li>\n<li>Building release pipelines using CI/CD tooling like Jenkins</li>\n<li>Experience with open source monitoring and logging, such as Prometheus, Elasticsearch, Logstash, Kibana and Grafana</li>\n<li>A solid understanding of Unix-like operating systems, Ubuntu/Debian in particular</li>\n<li>Proven development ability; you\u2019re confident with writing and testing robust scripts</li>\n<li>Strong interpersonal skills and the ability to clearly communicate with both technical and business team members</li>\n</ul>\n\n<p><strong>Who you are:</strong></p>\n\n<ul>\n<li>You are a tech and tooling enthusiast; you love staying up-to-date with the latest solutions for deploying and managing cloud infrastructure</li>\n<li>You build beautifully bulletproof systems that others can depend on, but you also dabble with prototypes and experimental new solutions</li>\n<li>You love improving the intelligence of various systems and environments through the implementation of sturdy and searchable monitoring and centralized logging</li>\n<li>You always look for new things to learn and new ways to leverage your knowledge. You would take great pride in becoming a Subject Matter Expert people can trust</li>\n<li>You have a passion for collaboration with software development teams t ...
#         "how_to_apply": "<p><strong>Sound like you?</strong></p>\n\n<p>To apply, please submit your tailored resume, a link to your LinkedIn profile, and a cover letter explaining why you feel you are a skill and culture match for this position <a href=\"http://careers.leadpages.net/apply/YN38C7/Site-Reliability-Engineer?source=Github\">HERE</a>. Thanks for checking us out - we look forward to hearing from you!</p>\n",
#         "id": "43b8b066-a83e-11e6-9dcf-84f334f5295b",
#         "location": "Minneapolis, MN",
#         "title": "Site Reliability Engineer",
#         "type": "Full Time",
#         "url": "http://jobs.github.com/positions/43b8b066-a83e-11e6-9dcf-84f334f5295b"
#     },
#     {
#         "company": "FiftyThree, Inc.",
#         "company_logo": null,
#         "company_url": "http://www.fiftythree.com",
#         "created_at": "Thu Nov 10 20:23:11 UTC 2016",
#         "description": "<p>Job Profile:</p>\n\n<p>Build rich, dynamic, magical web applications. Work hand-in-hand with the design and product teams to implement interfaces that look beautiful and adapt dynamically to all types of devices. Architect complex client-side interactions that push the boundaries of performance. Implement animations and transitions that make experiences in the browser come to life.</p>\n\n<p>Responsibilities:</p>\n\n<ul>\n<li>Execute on a software architecture and development plan to bring web products to life </li>\n<li>Write code to tackle challenging technical problems with a focus on readability, maintainability, performance, and quality </li>\n<li>Propose novel solutions to both design and technical challenges </li>\n<li>Communicate effectively with your team and other product disciplines, raising issues early and offering solutions </li>\n<li>Develop all software according to coding standards and processes </li>\n<li>Perform reviews of other engineers\u2019 code, designs, and architectures </li>\n<li>Make use of unit and integration tests wherever possible </li>\n<li>Participate in the interview process for new team members</li>\n</ul>\n\n<p>Requirements:</p>\n\n<ul>\n<li><p>BS degree in Computer Science or related field, or equivalent practical experience</p></li>\n<li><p>2+ years of relevant work experience </p></li>\n<li><p>A solid foundation in computer science, with strong competencies in software design and data structures </p></li>\n<li><p>Proven, self-motivated engineer with a track record of implementing end to end production-quality web experiences </p></li>\n<li><p>Posses a strong passion for building custom user experiences </p></li>\n<li><p>Able to work effectively in a cross-disciplinary environment, particularly with designers and product managers </p></li>\n<li><p>Able to create a development plan for a given feature set, estimate its tasks, and execute on those tasks in an efficient manner </p></li>\n<li><p>Experienced in defining architecture and implementing features of large scale modern web applications with technologies such as React.js </p></li>\n<li><p>Proficient in JavaScript and interested in bleeding edge language features ESNext </p></li>\n<li><p>Working knowledge of CSS </p></li>\n<li><p>Proficient with Git or similar revision control systems</p></li>\n</ul>\n\n<p>We Offer:</p>\n\n<ul>\n<li>Medical, Dental, Vision, 401(K) </li>\n<li>Life Insurance </li>\n<li>Commuter Benefits </li>\n<li>Corporate discounts through AnyPerk </li>\n<li>Catered in-office lunches twice weekly and fully stocked pantry </li>\n<li>Flexible Time Off Policy </li>\n<li>Employee Equity Program</li>\n</ul>\n",
#         "how_to_apply": "<p><a href=\"http://grnh.se/bdfpi81\">http://grnh.se/bdfpi81</a></p>\n",
#         "id": "7978e922-a781-11e6-9907-af5d98bf0bd7",
#         "location": "New York, NY",
#         "title": "Software Engineer, Front-End Web",
#         "type": "Full Time",
#         "url": "http://jobs.github.com/positions/7978e922-a781-11e6-9907-af5d98bf0bd7"
#     }
# ]

# %%
first_job = json_response[0]
first_job.keys()
# Out:
# dict_keys(['how_to_apply', 'company_url', 'created_at', 'description', 'company_logo', 'location', 'id', 'url', 'title', 'company', 'type'])

# %%
from IPython.display import Image
image_url = first_job['company_logo']
Image(url=image_url)
# Out:
# <img src="http://github-jobs.s3.amazonaws.com/f53d44ee-be25-11e6-957a-f616239dc5c8.png"/>

# %%
print(first_job['type'], 
      first_job['company'], 
      first_job['company_url'],
      first_job['title'],
      first_job['location'],
      first_job['created_at'],
      sep='\n')
# Out:
# Full Time
# The Nordam Group
# http://nordam.com/
# Team Lead, Fullstack Software Developer
# Tulsa, OK, USA
# Fri Dec 09 15:42:07 UTC 2016

# %%
from IPython.core.display import display, HTML

display(HTML(first_job['description']))
# Out:
# <p>Onsite, Relocation available.</p>
#
# <p>We’re an independent development team inside The NORDAM Group building a brand new public web service. The aerospace industry we’re modernizing has yet to fully benefit from the data revolution. We pride ourselves on our “startup” approach: we leverage modern technologies and methodologies and we prefer results over tradition. By being a totally separate unit in a large corporation, we benefit from its support and extensive business network, without all the downsides that come with software development at larger companies.</p>
#
# <p>You&#39;ll be responsible for leading a team of developers. This position will work on virtually all aspects of the product and will help drive product and technology strategy. You&#39;ll be designing solutions to complex or unusual problems or assignments requiring considerable ingenuity and judgement.</p>
#
# <p>Our product needs to handle information at scale, safely. We deal with items often worth tens of thousands of dollars or more. We do things the right way from the first time - cutting corners is not worth it in our case.</p>
#
# <p>You know Ruby inside and out, both the pretty and the ugly. You can tell when a piece of code will be inefficient just by looking at it and you know how to optimize it.</p>
#
# <p>As an early dev hire, you will be in a unique position to work on virtually all aspects of our product and have a strong voice in product and technology strategy. This position is a great opportunity for a smart and ambitious developer to advance their career and have a major impact on a large, important and clean project</p>
#
# <p>JOB QUALIFICATIONS:
# Formal Education, Training, Professional Certification and Work Experience:</p>
#
# <ul>
# <li>BS degree in Computer Science, related technical field or equivalent practical software development experience.</li>
# <li>At least 6 years of software development experience.</li>
# <li>Master of at least one scripting language (e.g., Ruby, Python, etc.) and at least one compiled language (e.g., Java, C/C++).</li>
# <li>Proficient with SQL, relational databases and excellent data modeling skills.</li>
# <li>Good knowledge of at least one frontend framework (e.g., Backbone, Angular, React, etc.).</li>
# </ul>
#
# <p>Preferred Qualifications:</p>
#
# <ul>
# <li>Experience with AWS, Docker and other “devops” technologies is a plus.</li>
# <li>Strong sense of web design and attuned to the fundamentals of user experience.</li>
# <li>Familiarity with the whole web stack, including protocols and web server optimization techniques. </li>
# <li>An understanding of the principles of accessibility and can build products that are accessible to users with disabilities.</li>
# <li>Experience developing “responsive” websites.</li>
# </ul>

# %%
display(HTML(first_job['how_to_apply']))
# Out:
# <p>Email your resume and a link to your Github profile to <a href="mailto:simon.grondin@outlook.com">simon.grondin@outlook.com</a></p>

# %%
print(first_job['id'], 
      first_job['url'],
      sep='\n')
# Out:
# f9891adc-be25-11e6-9511-e40bbeeef49d
# http://jobs.github.com/positions/f9891adc-be25-11e6-9511-e40bbeeef49d

# %%
from sqlalchemy import create_engine, MetaData, Table, Column, Integer, String, ForeignKey, DateTime

# A database engine URL follows the following format: dialect+driver://username:password@host:port/database

#engine = create_engine('postgresql+psycopg2://gabriel:easypwd@localhost/mydatabase')
#engine = create_engine('sqlite:///mydatabase.db')
#engine = create_engine('sqlite://')
engine = create_engine('sqlite:///:memory:', echo=True)

metadata = MetaData()

company_table = Table('company', metadata,
                      Column('id', Integer, primary_key=True),
                      Column('name', String, nullable=False),
                      Column('url', String, unique=True),
                      Column('logo_url', String))

job_table = Table('job', metadata,
                  Column('id', Integer, primary_key=True),
                  Column('company_id', None, ForeignKey('company.id'), nullable=False),
                  Column('type_', Integer),
                  Column('title', String, nullable=False),
                  Column('description', String),
                  Column('how_to_apply', String))

location_table = Table('location', metadata,
                      Column('job_id', None, ForeignKey('job.id'), primary_key=True),
                      Column('description', String),
                      Column('remote_ok', Integer))

github_metadata_table = Table('github_metadata', metadata,
                              Column('job_id', None, ForeignKey('job.id'), primary_key=True),
                              Column('github_id', String, unique=True),
                              Column('url', String, nullable=False),
                              Column('created_at', DateTime, nullable=False))

metadata.create_all(engine)
conn = engine.connect()
# Out:
# 2016-12-10 04:38:56,559 INFO sqlalchemy.engine.base.Engine SELECT CAST('test plain returns' AS VARCHAR(60)) AS anon_1
# 2016-12-10 04:38:56,559 INFO sqlalchemy.engine.base.Engine ()
# 2016-12-10 04:38:56,562 INFO sqlalchemy.engine.base.Engine SELECT CAST('test unicode returns' AS VARCHAR(60)) AS anon_1
# 2016-12-10 04:38:56,563 INFO sqlalchemy.engine.base.Engine ()
# 2016-12-10 04:38:56,569 INFO sqlalchemy.engine.base.Engine PRAGMA table_info("job")
# 2016-12-10 04:38:56,571 INFO sqlalchemy.engine.base.Engine ()
# 2016-12-10 04:38:56,576 INFO sqlalchemy.engine.base.Engine PRAGMA table_info("location")
# 2016-12-10 04:38:56,577 INFO sqlalchemy.engine.base.Engine ()
# 2016-12-10 04:38:56,579 INFO sqlalchemy.engine.base.Engine PRAGMA table_info("company")
# 2016-12-10 04:38:56,581 INFO sqlalchemy.engine.base.Engine ()
# 2016-12-10 04:38:56,582 INFO sqlalchemy.engine.base.Engine PRAGMA table_info("github_metadata")
# 2016-12-10 04:38:56,583 INFO sqlalchemy.engine.base.Engine ()
# 2016-12-10 04:38:56,586 INFO sqlalchemy.engine.base.Engine
# CREATE TABLE company (
# 	id INTEGER NOT NULL,
# 	name VARCHAR NOT NULL,
# 	url VARCHAR,
# 	logo_url VARCHAR,
# 	PRIMARY KEY (id),
# 	UNIQUE (url)
# )
#
#
# 2016-12-10 04:38:56,587 INFO sqlalchemy.engine.base.Engine ()
# 2016-12-10 04:38:56,588 INFO sqlalchemy.engine.base.Engine COMMIT
# 2016-12-10 04:38:56,590 INFO sqlalchemy.engine.base.Engine
# CREATE TABLE job (
# 	id INTEGER NOT NULL,
# 	company_id INTEGER NOT NULL,
# 	type_ INTEGER,
# 	title VARCHAR NOT NULL,
# 	description VARCHAR,
# 	how_to_apply VARCHAR,
# 	PRIMARY KEY (id),
# 	FOREIGN KEY(company_id) REFERENCES company (id)
# )
#
#
# 2016-12-10 04:38:56,591 INFO sqlalchemy.engine.base.Engine ()
# 2016-12-10 04:38:56,594 INFO sqlalchemy.engine.base.Engine COMMIT
# 2016-12-10 04:38:56,596 INFO sqlalchemy.engine.base.Engine
# CREATE TABLE location (
# 	job_id INTEGER NOT NULL,
# 	description VARCHAR,
# 	remote_ok INTEGER,
# 	PRIMARY KEY (job_id),
# 	FOREIGN KEY(job_id) REFERENCES job (id)
# )
#
#
# 2016-12-10 04:38:56,598 INFO sqlalchemy.engine.base.Engine ()
# 2016-12-10 04:38:56,599 INFO sqlalchemy.engine.base.Engine COMMIT
# 2016-12-10 04:38:56,606 INFO sqlalchemy.engine.base.Engine
# CREATE TABLE github_metadata (
# 	job_id INTEGER NOT NULL,
# 	github_id VARCHAR,
# 	url VARCHAR NOT NULL,
# 	created_at DATETIME NOT NULL,
# 	PRIMARY KEY (job_id),
# 	FOREIGN KEY(job_id) REFERENCES job (id),
# 	UNIQUE (github_id)
# )
#
#
# 2016-12-10 04:38:56,609 INFO sqlalchemy.engine.base.Engine ()
# 2016-12-10 04:38:56,611 INFO sqlalchemy.engine.base.Engine COMMIT

# %%
from enum import Enum

class JobType(Enum):
    full_time = 1
    part_time = 2

    @staticmethod
    def from_string(string):
        if string.lower() == 'full time' or string.lower() == 'full-time':
            return JobType.full_time
        elif string.lower() == 'part time' or string.lower() == 'part-time':
            return JobType.part_time
        else:
            raise RuntimeError('JobType not supported: {}'.format(string))

# %%
def insert_company(name, url, logo_url, connection=conn):
    """Inserts a new entry in company_table and returns its id."""
    insert = company_table.insert().values(name=name, url=url, logo_url=logo_url)
    result = connection.execute(insert)
    return result.inserted_primary_key[0]

# %%
def insert_job(company_id, type_str, title, description, how_to_apply, connection=conn):
    """Inserts a new entry in job_table and returns its id."""
    insert = job_table.insert().values(company_id=company_id, 
                                       type_=JobType.from_string(type_str).value, 
                                       title=title, description=description, how_to_apply=how_to_apply) 
    result = connection.execute(insert)
    return result.inserted_primary_key[0]

# %%
def insert_location(job_id, description, connection=conn):
    """Inserts a new entry in location_table and returns its job_id."""
    insert = location_table.insert().values(job_id=job_id, description=description, 
                                       remote_ok=int('remote' in description.lower() 
                                                     or 'telecommute' in description.lower())) 
    result = connection.execute(insert)
    return result.inserted_primary_key[0]

# %%
import datetime
created_at_pattern = '%a %b %d %X %Z %Y'

def insert_github_metadata(job_id, github_id, url, created_at_str, connection=conn):
    """Inserts a new entry in github_metadata_table and returns its job_id."""
    insert = github_metadata_table.insert().values(job_id=job_id, github_id=github_id, url=url,
                                       created_at=datetime.datetime.strptime(created_at_str, created_at_pattern))
    result = connection.execute(insert)
    return result.inserted_primary_key[0]

# %%
from sqlalchemy.sql import select

def select_or_insert_company(name, url, logo_url, connection=conn):
    """Returns the company id either by selecting from or inserting in company_table"""
    s = select([company_table]).where(company_table.c.url == url)
    result = connection.execute(s).fetchone()
    if result is not None:
        return result['id']
    else:
        new_id = insert_company(name, url, logo_url, connection)
        return new_id

# %%
def select_or_insert_job(company_name, company_url, company_logo_url, 
                         github_id, github_url, github_created_at_str,
                         type_str, title, description, how_to_apply,
                         location_description):
    """
    Returns the job id either by selecting from or inserting in job_table.
    
    This function might also insert new location, github_metadata and company entries.
    """
    s = select([github_metadata_table]).where(github_metadata_table.c.github_id == github_id)
    result = conn.execute(s).fetchone()
    if result is not None:
        return result['job_id']
    else:
        with engine.begin() as transaction:
            company_id = select_or_insert_company(company_name, company_url, company_logo_url, transaction)
            job_id = insert_job(company_id, type_str, title, description, how_to_apply, transaction)
            insert_github_metadata(job_id, github_id, github_url, github_created_at_str, transaction)
            insert_location(job_id, location_description, transaction)
            
        return job_id

# %%
for job in json_response:
    select_or_insert_job(
        job['company'],
        job['company_url'],
        job['company_logo'],
        job['id'],
        job['url'],
        job['created_at'],
        job['type'],
        job['title'],
        job['description'],
        job['how_to_apply'],
        job['location']
    )
# Out:
# 2016-12-10 04:40:21,216 INFO sqlalchemy.engine.base.Engine SELECT github_metadata.job_id, github_metadata.github_id, github_metadata.url, github_metadata.created_at
# FROM github_metadata
# WHERE github_metadata.github_id = ?
# 2016-12-10 04:40:21,217 INFO sqlalchemy.engine.base.Engine ('f9891adc-be25-11e6-9511-e40bbeeef49d',)
# 2016-12-10 04:40:21,218 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2016-12-10 04:40:21,220 INFO sqlalchemy.engine.base.Engine SELECT company.id, company.name, company.url, company.logo_url
# FROM company
# WHERE company.url = ?
# 2016-12-10 04:40:21,221 INFO sqlalchemy.engine.base.Engine ('http://nordam.com/',)
# 2016-12-10 04:40:21,223 INFO sqlalchemy.engine.base.Engine INSERT INTO company (name, url, logo_url) VALUES (?, ?, ?)
# 2016-12-10 04:40:21,223 INFO sqlalchemy.engine.base.Engine ('The Nordam Group', 'http://nordam.com/', 'http://github-jobs.s3.amazonaws.com/f53d44ee-be25-11e6-957a-f616239dc5c8.png')
# 2016-12-10 04:40:21,225 INFO sqlalchemy.engine.base.Engine INSERT INTO job (company_id, type_, title, description, how_to_apply) VALUES (?, ?, ?, ?, ?)
# 2016-12-10 04:40:21,226 INFO sqlalchemy.engine.base.Engine (1, 1, 'Team Lead, Fullstack Software Developer', '<p>Onsite, Relocation available.</p>\n\n<p>We’re an independent development team inside The NORDAM Group building a brand new public web service. The ... (2489 characters truncated) ... ssibility and can build products that are accessible to users with disabilities.</li>\n<li>Experience developing “responsive” websites.</li>\n</ul>\n', '<p>Email your resume and a link to your Github profile to <a href="mailto:simon.grondin@outlook.com">simon.grondin@outlook.com</a></p>\n')
# 2016-12-10 04:40:21,229 INFO sqlalchemy.engine.base.Engine INSERT INTO github_metadata (job_id, github_id, url, created_at) VALUES (?, ?, ?, ?)
# 2016-12-10 04:40:21,229 INFO sqlalchemy.engine.base.Engine (1, 'f9891adc-be25-11e6-9511-e40bbeeef49d', 'http://jobs.github.com/positions/f9891adc-be25-11e6-9511-e40bbeeef49d', '2016-12-09 15:42:07.000000')
# 2016-12-10 04:40:21,231 INFO sqlalchemy.engine.base.Engine INSERT INTO location (job_id, description, remote_ok) VALUES (?, ?, ?)
# 2016-12-10 04:40:21,232 INFO sqlalchemy.engine.base.Engine (1, 'Tulsa, OK, USA', 0)
# 2016-12-10 04:40:21,233 INFO sqlalchemy.engine.base.Engine COMMIT
# 2016-12-10 04:40:21,234 INFO sqlalchemy.engine.base.Engine SELECT github_metadata.job_id, github_metadata.github_id, github_metadata.url, github_metadata.created_at
# FROM github_metadata
# WHERE github_metadata.github_id = ?
# 2016-12-10 04:40:21,235 INFO sqlalchemy.engine.base.Engine ('8ae1f6bc-be25-11e6-89a1-99b30fbe0cd6',)
# 2016-12-10 04:40:21,236 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2016-12-10 04:40:21,238 INFO sqlalchemy.engine.base.Engine SELECT company.id, company.name, company.url, company.logo_url
# FROM company
# WHERE company.url = ?
# 2016-12-10 04:40:21,239 INFO sqlalchemy.engine.base.Engine ('http://nordam.com/',)
# 2016-12-10 04:40:21,240 INFO sqlalchemy.engine.base.Engine INSERT INTO job (company_id, type_, title, description, how_to_apply) VALUES (?, ?, ?, ?, ?)
# 2016-12-10 04:40:21,241 INFO sqlalchemy.engine.base.Engine (1, 1, 'Fullstack Developer', '<p>We’re an independent development team inside The NORDAM Group building a brand new public web service. The aerospace industry we’re modernizing ha ... (2254 characters truncated) ... ilities.</li>\n<li>Experience with front end development technologies like HTML5 and CSS3, and experience building responsive websites.</li>\n</ul>\n', '<p>Email your resume and a link to your Github profile to <a href="mailto:simon.grondin@outlook.com">simon.grondin@outlook.com</a></p>\n')
# 2016-12-10 04:40:21,243 INFO sqlalchemy.engine.base.Engine INSERT INTO github_metadata (job_id, github_id, url, created_at) VALUES (?, ?, ?, ?)
# 2016-12-10 04:40:21,244 INFO sqlalchemy.engine.base.Engine (2, '8ae1f6bc-be25-11e6-89a1-99b30fbe0cd6', 'http://jobs.github.com/positions/8ae1f6bc-be25-11e6-89a1-99b30fbe0cd6', '2016-12-09 15:39:49.000000')
# 2016-12-10 04:40:21,245 INFO sqlalchemy.engine.base.Engine INSERT INTO location (job_id, description, remote_ok) VALUES (?, ?, ?)
# 2016-12-10 04:40:21,246 INFO sqlalchemy.engine.base.Engine (2, 'Tulsa, OK, USA', 0)
# 2016-12-10 04:40:21,249 INFO sqlalchemy.engine.base.Engine COMMIT
# 2016-12-10 04:40:21,250 INFO sqlalchemy.engine.base.Engine SELECT github_metadata.job_id, github_metadata.github_id, github_metadata.url, github_metadata.created_at
# FROM github_metadata
# WHERE github_metadata.github_id = ?
# 2016-12-10 04:40:21,251 INFO sqlalchemy.engine.base.Engine ('1e8c129c-bd92-11e6-8617-152c7092fed4',)
# 2016-12-10 04:40:21,252 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2016-12-10 04:40:21,253 INFO sqlalchemy.engine.base.Engine SELECT company.id, company.name, company.url, company.logo_url
# FROM company
# WHERE company.url = ?
# 2016-12-10 04:40:21,254 INFO sqlalchemy.engine.base.Engine ('http://www.makeschool.com',)
# 2016-12-10 04:40:21,255 INFO sqlalchemy.engine.base.Engine INSERT INTO company (name, url, logo_url) VALUES (?, ?, ?)
# 2016-12-10 04:40:21,256 INFO sqlalchemy.engine.base.Engine ('Make School', 'http://www.makeschool.com', 'http://github-jobs.s3.amazonaws.com/1a750858-bd92-11e6-86c4-3164e610a489.png')
# 2016-12-10 04:40:21,257 INFO sqlalchemy.engine.base.Engine INSERT INTO job (company_id, type_, title, description, how_to_apply) VALUES (?, ?, ?, ?, ?)
# 2016-12-10 04:40:21,258 INFO sqlalchemy.engine.base.Engine (2, 1, 'iOS Instructor and Curriculum Engineer', '<p>We&#39;re looking for an iOS Instructor &amp; Curriculum Engineer to develop and teach the iOS curriculum for our Product College.</p>\n\n<p>Make  ... (3933 characters truncated) ... Principles course framework. Swift CSP is currently being used by high school teachers and computer science clubs around the world.</p></li>\n</ul>\n', '<p><a href="https://jobs.lever.co/makeschool/d87353c7-05b1-4afe-95bf-abb4fb1a8aa8/apply">https://jobs.lever.co/makeschool/d87353c7-05b1-4afe-95bf-abb4fb1a8aa8/apply</a></p>\n')
# 2016-12-10 04:40:21,259 INFO sqlalchemy.engine.base.Engine INSERT INTO github_metadata (job_id, github_id, url, created_at) VALUES (?, ?, ?, ?)
# 2016-12-10 04:40:21,260 INFO sqlalchemy.engine.base.Engine (3, '1e8c129c-bd92-11e6-8617-152c7092fed4', 'http://jobs.github.com/positions/1e8c129c-bd92-11e6-8617-152c7092fed4', '2016-12-08 22:03:30.000000')
# 2016-12-10 04:40:21,261 INFO sqlalchemy.engine.base.Engine INSERT INTO location (job_id, description, remote_ok) VALUES (?, ?, ?)
# 2016-12-10 04:40:21,262 INFO sqlalchemy.engine.base.Engine (3, 'San Francisco', 0)
# 2016-12-10 04:40:21,264 INFO sqlalchemy.engine.base.Engine COMMIT
# 2016-12-10 04:40:21,266 INFO sqlalchemy.engine.base.Engine SELECT github_metadata.job_id, github_metadata.github_id, github_metadata.url, github_metadata.created_at
# FROM github_metadata
# WHERE github_metadata.github_id = ?
# 2016-12-10 04:40:21,267 INFO sqlalchemy.engine.base.Engine ('bb1644a2-bce3-11e6-9406-ccfe9cedada7',)
# 2016-12-10 04:40:21,273 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2016-12-10 04:40:21,275 INFO sqlalchemy.engine.base.Engine SELECT company.id, company.name, company.url, company.logo_url
# FROM company
# WHERE company.url = ?
# 2016-12-10 04:40:21,276 INFO sqlalchemy.engine.base.Engine ('https://imo.im',)
# 2016-12-10 04:40:21,278 INFO sqlalchemy.engine.base.Engine INSERT INTO company (name, url, logo_url) VALUES (?, ?, ?)
# 2016-12-10 04:40:21,284 INFO sqlalchemy.engine.base.Engine ('imo messenger', 'https://imo.im', 'http://github-jobs.s3.amazonaws.com/a1d804d0-bce3-11e6-8a7f-9700ffb8862d.png')
# 2016-12-10 04:40:21,285 INFO sqlalchemy.engine.base.Engine INSERT INTO job (company_id, type_, title, description, how_to_apply) VALUES (?, ?, ?, ?, ?)
# 2016-12-10 04:40:21,287 INFO sqlalchemy.engine.base.Engine (3, 1, 'Software Engineer', '<p>imo, based in Palo Alto, is a fast growing mobile messaging app. We’re building products that help hundreds of millions of people around the world ... (1427 characters truncated) ... eimbursement </li>\n<li>Gym membership at Equinox </li>\n<li>Yearly conference stipend </li>\n<li>imo-sponsored team events and outings</li>\n</ul>\n', '<p>Email your resume to <a href="mailto:jobs@imo.im">jobs@imo.im</a></p>\n')
# 2016-12-10 04:40:21,290 INFO sqlalchemy.engine.base.Engine INSERT INTO github_metadata (job_id, github_id, url, created_at) VALUES (?, ?, ?, ?)
# 2016-12-10 04:40:21,292 INFO sqlalchemy.engine.base.Engine (4, 'bb1644a2-bce3-11e6-9406-ccfe9cedada7', 'http://jobs.github.com/positions/bb1644a2-bce3-11e6-9406-ccfe9cedada7', '2016-12-08 01:15:35.000000')
# 2016-12-10 04:40:21,293 INFO sqlalchemy.engine.base.Engine INSERT INTO location (job_id, description, remote_ok) VALUES (?, ?, ?)
# 2016-12-10 04:40:21,294 INFO sqlalchemy.engine.base.Engine (4, 'Palo Alto, CA', 0)
# 2016-12-10 04:40:21,294 INFO sqlalchemy.engine.base.Engine COMMIT
# 2016-12-10 04:40:21,296 INFO sqlalchemy.engine.base.Engine SELECT github_metadata.job_id, github_metadata.github_id, github_metadata.url, github_metadata.created_at
# FROM github_metadata
# WHERE github_metadata.github_id = ?
# 2016-12-10 04:40:21,296 INFO sqlalchemy.engine.base.Engine ('beb74684-bbed-11e6-8197-64e617b51adf',)
# 2016-12-10 04:40:21,298 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2016-12-10 04:40:21,299 INFO sqlalchemy.engine.base.Engine SELECT company.id, company.name, company.url, company.logo_url
# FROM company
# WHERE company.url = ?
# 2016-12-10 04:40:21,300 INFO sqlalchemy.engine.base.Engine ('http://nmi.com',)
# 2016-12-10 04:40:21,302 INFO sqlalchemy.engine.base.Engine INSERT INTO company (name, url, logo_url) VALUES (?, ?, ?)
# 2016-12-10 04:40:21,303 INFO sqlalchemy.engine.base.Engine ('Network Merchants, LLC', 'http://nmi.com', 'http://github-jobs.s3.amazonaws.com/a1b8f9ec-bbed-11e6-960a-b1034c4cd71b.png')
# 2016-12-10 04:40:21,305 INFO sqlalchemy.engine.base.Engine INSERT INTO job (company_id, type_, title, description, how_to_apply) VALUES (?, ?, ?, ?, ?)
# 2016-12-10 04:40:21,305 INFO sqlalchemy.engine.base.Engine (4, 1, 'Linux Systems Engineer', '<p><strong>Summary</strong> </p>\n\n<ul>\n<li>The engineering team at NMI is a small, agile group that works closely together but requires independen ... (2957 characters truncated) ... >\n<li>Jira and Confluence for task and project management</li>\n<li>Computer</li>\n<li>Printer</li>\n<li>Fax Machine</li>\n<li>Scanner</li>\n</ul>\n', '<p>Please E-mail your resume to <a href="mailto:hr@nmi.com">hr@nmi.com</a></p>\n')
# 2016-12-10 04:40:21,307 INFO sqlalchemy.engine.base.Engine INSERT INTO github_metadata (job_id, github_id, url, created_at) VALUES (?, ?, ?, ?)
# 2016-12-10 04:40:21,307 INFO sqlalchemy.engine.base.Engine (5, 'beb74684-bbed-11e6-8197-64e617b51adf', 'http://jobs.github.com/positions/beb74684-bbed-11e6-8197-64e617b51adf', '2016-12-06 19:54:25.000000')
# 2016-12-10 04:40:21,308 INFO sqlalchemy.engine.base.Engine INSERT INTO location (job_id, description, remote_ok) VALUES (?, ?, ?)
# 2016-12-10 04:40:21,309 INFO sqlalchemy.engine.base.Engine (5, 'Roselle, IL', 0)
# 2016-12-10 04:40:21,311 INFO sqlalchemy.engine.base.Engine COMMIT
# 2016-12-10 04:40:21,313 INFO sqlalchemy.engine.base.Engine SELECT github_metadata.job_id, github_metadata.github_id, github_metadata.url, github_metadata.created_at
# FROM github_metadata
# WHERE github_metadata.github_id = ?
# 2016-12-10 04:40:21,314 INFO sqlalchemy.engine.base.Engine ('61433012-baf8-11e6-8d18-1baa36e6dbf5',)
# 2016-12-10 04:40:21,315 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2016-12-10 04:40:21,316 INFO sqlalchemy.engine.base.Engine SELECT company.id, company.name, company.url, company.logo_url
# FROM company
# WHERE company.url = ?
# 2016-12-10 04:40:21,317 INFO sqlalchemy.engine.base.Engine ('http://www.scm-lp.com',)
# 2016-12-10 04:40:21,318 INFO sqlalchemy.engine.base.Engine INSERT INTO company (name, url, logo_url) VALUES (?, ?, ?)
# 2016-12-10 04:40:21,318 INFO sqlalchemy.engine.base.Engine ('Stevens Capital Management LP', 'http://www.scm-lp.com', 'http://github-jobs.s3.amazonaws.com/5df90c6a-baf8-11e6-8a38-492033c01d86.png')
# 2016-12-10 04:40:21,320 INFO sqlalchemy.engine.base.Engine INSERT INTO job (company_id, type_, title, description, how_to_apply) VALUES (?, ?, ?, ?, ?)
# 2016-12-10 04:40:21,321 INFO sqlalchemy.engine.base.Engine (5, 1, 'Implementation Developer', '<p>Stevens Capital Management LP (“SCM”) is a registered investment adviser that manages a multi-billion dollar hedge fund that has been in business  ... (1396 characters truncated) ... Experience with relational databases including Sybase, SQL Server and Oracle is a plus.</li>\n<li>Experience with GUI design is a plus.</li>\n</ul>\n', '<p>Please submit your resume to: <a href="mailto:recruiting@scm-lp.com">recruiting@scm-lp.com</a></p>\n\n<p>Website: <a href="http://www.scm-lp.com">www.scm-lp.com</a></p>\n')
# 2016-12-10 04:40:21,322 INFO sqlalchemy.engine.base.Engine INSERT INTO github_metadata (job_id, github_id, url, created_at) VALUES (?, ?, ?, ?)
# 2016-12-10 04:40:21,323 INFO sqlalchemy.engine.base.Engine (6, '61433012-baf8-11e6-8d18-1baa36e6dbf5', 'http://jobs.github.com/positions/61433012-baf8-11e6-8d18-1baa36e6dbf5', '2016-12-05 14:38:11.000000')
# 2016-12-10 04:40:21,324 INFO sqlalchemy.engine.base.Engine INSERT INTO location (job_id, description, remote_ok) VALUES (?, ?, ?)
# 2016-12-10 04:40:21,325 INFO sqlalchemy.engine.base.Engine (6, 'Radnor, PA. USA', 0)
# 2016-12-10 04:40:21,326 INFO sqlalchemy.engine.base.Engine COMMIT
# 2016-12-10 04:40:21,327 INFO sqlalchemy.engine.base.Engine SELECT github_metadata.job_id, github_metadata.github_id, github_metadata.url, github_metadata.created_at
# FROM github_metadata
# WHERE github_metadata.github_id = ?
# 2016-12-10 04:40:21,328 INFO sqlalchemy.engine.base.Engine ('6d409aaa-b8c6-11e6-8408-7debc09d256f',)
# 2016-12-10 04:40:21,329 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2016-12-10 04:40:21,330 INFO sqlalchemy.engine.base.Engine SELECT company.id, company.name, company.url, company.logo_url
# FROM company
# WHERE company.url = ?
# 2016-12-10 04:40:21,331 INFO sqlalchemy.engine.base.Engine ('http://www.genepeeks.com',)
# 2016-12-10 04:40:21,333 INFO sqlalchemy.engine.base.Engine INSERT INTO company (name, url, logo_url) VALUES (?, ?, ?)
# 2016-12-10 04:40:21,334 INFO sqlalchemy.engine.base.Engine ('GenePeeks, Inc', 'http://www.genepeeks.com', 'http://github-jobs.s3.amazonaws.com/67ea79ea-b8c6-11e6-81ec-ba6eeed777c6.jpg')
# 2016-12-10 04:40:21,335 INFO sqlalchemy.engine.base.Engine INSERT INTO job (company_id, type_, title, description, how_to_apply) VALUES (?, ?, ?, ?, ?)
# 2016-12-10 04:40:21,336 INFO sqlalchemy.engine.base.Engine (6, 1, 'Software Engineer, DevOps', '<p>Job description</p>\n\n<p>GenePeeks is a data-driven genetics start-up pushing the boundaries of reproductive health care and computational geneti ... (2494 characters truncated) ... l>\n\n<p>Location:\nThis position will be located in the Boston or New York area.\n*GenePeeks will not offer visa sponsorship for this position</p>\n', '<p><a href="http://careers.genepeeks.com/o/software-engineer-devops=GitHub">http://careers.genepeeks.com/o/software-engineer-devops=GitHub</a></p>\n')
# 2016-12-10 04:40:21,337 INFO sqlalchemy.engine.base.Engine INSERT INTO github_metadata (job_id, github_id, url, created_at) VALUES (?, ?, ?, ?)
# 2016-12-10 04:40:21,338 INFO sqlalchemy.engine.base.Engine (7, '6d409aaa-b8c6-11e6-8408-7debc09d256f', 'http://jobs.github.com/positions/6d409aaa-b8c6-11e6-8408-7debc09d256f', '2016-12-02 19:36:23.000000')
# 2016-12-10 04:40:21,339 INFO sqlalchemy.engine.base.Engine INSERT INTO location (job_id, description, remote_ok) VALUES (?, ?, ?)
# 2016-12-10 04:40:21,340 INFO sqlalchemy.engine.base.Engine (7, 'Cambridge, MA', 0)
# 2016-12-10 04:40:21,340 INFO sqlalchemy.engine.base.Engine COMMIT
# 2016-12-10 04:40:21,342 INFO sqlalchemy.engine.base.Engine SELECT github_metadata.job_id, github_metadata.github_id, github_metadata.url, github_metadata.created_at
# FROM github_metadata
# WHERE github_metadata.github_id = ?
# 2016-12-10 04:40:21,343 INFO sqlalchemy.engine.base.Engine ('47b78b5e-b7ef-11e6-86f0-a00baabc0c92',)
# 2016-12-10 04:40:21,344 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2016-12-10 04:40:21,346 INFO sqlalchemy.engine.base.Engine SELECT company.id, company.name, company.url, company.logo_url
# FROM company
# WHERE company.url = ?
# 2016-12-10 04:40:21,348 INFO sqlalchemy.engine.base.Engine ('http://jobs.intel.com',)
# 2016-12-10 04:40:21,349 INFO sqlalchemy.engine.base.Engine INSERT INTO company (name, url, logo_url) VALUES (?, ?, ?)
# 2016-12-10 04:40:21,350 INFO sqlalchemy.engine.base.Engine ('Intel Corporation', 'http://jobs.intel.com', 'http://github-jobs.s3.amazonaws.com/0590279e-b7eb-11e6-92e0-095053d3f49d.png')
# 2016-12-10 04:40:21,352 INFO sqlalchemy.engine.base.Engine INSERT INTO job (company_id, type_, title, description, how_to_apply) VALUES (?, ?, ?, ?, ?)
# 2016-12-10 04:40:21,352 INFO sqlalchemy.engine.base.Engine (7, 1, 'Automated Driving SW Development Engineer', '<p>Employees of the Internet of Things Solutions Group (IOTG) have an exciting opportunity before them: To grow Intel&#39;s leadership position in th ... (4089 characters truncated) ... ated to helping Intel drive the next major growth inflection through productivity and new business models that are emerging as a result of IoT.</p>\n', '<p>Apply on company website: <a href="http://career.intel.com/TpLVa">http://career.intel.com/TpLVa</a></p>\n')
# 2016-12-10 04:40:21,354 INFO sqlalchemy.engine.base.Engine INSERT INTO github_metadata (job_id, github_id, url, created_at) VALUES (?, ?, ?, ?)
# 2016-12-10 04:40:21,354 INFO sqlalchemy.engine.base.Engine (8, '47b78b5e-b7ef-11e6-86f0-a00baabc0c92', 'http://jobs.github.com/positions/47b78b5e-b7ef-11e6-86f0-a00baabc0c92', '2016-12-02 11:49:17.000000')
# 2016-12-10 04:40:21,356 INFO sqlalchemy.engine.base.Engine INSERT INTO location (job_id, description, remote_ok) VALUES (?, ?, ?)
# 2016-12-10 04:40:21,356 INFO sqlalchemy.engine.base.Engine (8, 'Karlsruhe, Germany', 0)
# 2016-12-10 04:40:21,357 INFO sqlalchemy.engine.base.Engine COMMIT
# 2016-12-10 04:40:21,359 INFO sqlalchemy.engine.base.Engine SELECT github_metadata.job_id, github_metadata.github_id, github_metadata.url, github_metadata.created_at
# FROM github_metadata
# WHERE github_metadata.github_id = ?
# 2016-12-10 04:40:21,359 INFO sqlalchemy.engine.base.Engine ('88d7a11e-b7ef-11e6-8839-4baedb4f1c00',)
# 2016-12-10 04:40:21,360 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2016-12-10 04:40:21,362 INFO sqlalchemy.engine.base.Engine SELECT company.id, company.name, company.url, company.logo_url
# FROM company
# WHERE company.url = ?
# 2016-12-10 04:40:21,362 INFO sqlalchemy.engine.base.Engine ('http://jobs.intel.com',)
# 2016-12-10 04:40:21,364 INFO sqlalchemy.engine.base.Engine INSERT INTO job (company_id, type_, title, description, how_to_apply) VALUES (?, ?, ?, ?, ?)
# 2016-12-10 04:40:21,364 INFO sqlalchemy.engine.base.Engine (7, 1, 'Software Development Engineer C, C++', '<p>Duties are focused on development open-source LLVM/GCC toolchain for Intel Architecture in Linux and Android target environments.  </p>\n\n<p><str ... (2188 characters truncated) ... global leadership to the software community through its technical expertise, industry enabling activities, and developer products and programs.</p>\n', '<p>Apply on company website: <a href="http://career.intel.com/TpHFE">http://career.intel.com/TpHFE</a></p>\n')
# 2016-12-10 04:40:21,366 INFO sqlalchemy.engine.base.Engine INSERT INTO github_metadata (job_id, github_id, url, created_at) VALUES (?, ?, ?, ?)
# 2016-12-10 04:40:21,366 INFO sqlalchemy.engine.base.Engine (9, '88d7a11e-b7ef-11e6-8839-4baedb4f1c00', 'http://jobs.github.com/positions/88d7a11e-b7ef-11e6-8839-4baedb4f1c00', '2016-12-02 11:49:15.000000')
# 2016-12-10 04:40:21,368 INFO sqlalchemy.engine.base.Engine INSERT INTO location (job_id, description, remote_ok) VALUES (?, ?, ?)
# 2016-12-10 04:40:21,368 INFO sqlalchemy.engine.base.Engine (9, 'Gdansk, Poland ', 0)
# 2016-12-10 04:40:21,369 INFO sqlalchemy.engine.base.Engine COMMIT
# 2016-12-10 04:40:21,371 INFO sqlalchemy.engine.base.Engine SELECT github_metadata.job_id, github_metadata.github_id, github_metadata.url, github_metadata.created_at
# FROM github_metadata
# WHERE github_metadata.github_id = ?
# 2016-12-10 04:40:21,372 INFO sqlalchemy.engine.base.Engine ('24d6d212-b7f8-11e6-9bc0-4c468fa010c5',)
# 2016-12-10 04:40:21,373 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2016-12-10 04:40:21,374 INFO sqlalchemy.engine.base.Engine SELECT company.id, company.name, company.url, company.logo_url
# FROM company
# WHERE company.url = ?
# 2016-12-10 04:40:21,375 INFO sqlalchemy.engine.base.Engine ('http://www.pdtpartners.com',)
# 2016-12-10 04:40:21,376 INFO sqlalchemy.engine.base.Engine INSERT INTO company (name, url, logo_url) VALUES (?, ?, ?)
# 2016-12-10 04:40:21,376 INFO sqlalchemy.engine.base.Engine ('PDT Partners', 'http://www.pdtpartners.com', 'http://github-jobs.s3.amazonaws.com/1dee7540-b7f8-11e6-8780-56e37987ae3b.png')
# 2016-12-10 04:40:21,378 INFO sqlalchemy.engine.base.Engine INSERT INTO job (company_id, type_, title, description, how_to_apply) VALUES (?, ?, ?, ?, ?)
# 2016-12-10 04:40:21,378 INFO sqlalchemy.engine.base.Engine (8, 1, 'C++/Python Developer', '<p><strong>C++/Python Engineers</strong></p>\n\n<p>We’re looking for a select few uniquely excellent C++/Python engineers to join our world-class tea ... (5267 characters truncated) ... ed</li>\n</ul>\n\n<p><strong>Education:</strong></p>\n\n<p>Bachelor’s or master’s degree in computer science from an excellent academic program</p>\n', '<p><a href="http://grnh.se/h8l4dk1">http://grnh.se/h8l4dk1</a></p>\n')
# 2016-12-10 04:40:21,380 INFO sqlalchemy.engine.base.Engine INSERT INTO github_metadata (job_id, github_id, url, created_at) VALUES (?, ?, ?, ?)
# 2016-12-10 04:40:21,381 INFO sqlalchemy.engine.base.Engine (10, '24d6d212-b7f8-11e6-9bc0-4c468fa010c5', 'http://jobs.github.com/positions/24d6d212-b7f8-11e6-9bc0-4c468fa010c5', '2016-12-01 18:59:13.000000')
# 2016-12-10 04:40:21,384 INFO sqlalchemy.engine.base.Engine INSERT INTO location (job_id, description, remote_ok) VALUES (?, ?, ?)
# 2016-12-10 04:40:21,384 INFO sqlalchemy.engine.base.Engine (10, 'New York', 0)
# 2016-12-10 04:40:21,385 INFO sqlalchemy.engine.base.Engine COMMIT
# 2016-12-10 04:40:21,387 INFO sqlalchemy.engine.base.Engine SELECT github_metadata.job_id, github_metadata.github_id, github_metadata.url, github_metadata.created_at
# FROM github_metadata
# WHERE github_metadata.github_id = ?
# 2016-12-10 04:40:21,388 INFO sqlalchemy.engine.base.Engine ('53eb1432-b68b-11e6-805c-42ae75f605e1',)
# 2016-12-10 04:40:21,389 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2016-12-10 04:40:21,390 INFO sqlalchemy.engine.base.Engine SELECT company.id, company.name, company.url, company.logo_url
# FROM company
# WHERE company.url IS NULL
# 2016-12-10 04:40:21,391 INFO sqlalchemy.engine.base.Engine ()
# 2016-12-10 04:40:21,392 INFO sqlalchemy.engine.base.Engine INSERT INTO company (name, url, logo_url) VALUES (?, ?, ?)
# 2016-12-10 04:40:21,393 INFO sqlalchemy.engine.base.Engine ('CrowdFlower', None, None)
# 2016-12-10 04:40:21,394 INFO sqlalchemy.engine.base.Engine INSERT INTO job (company_id, type_, title, description, how_to_apply) VALUES (?, ?, ?, ?, ?)
# 2016-12-10 04:40:21,395 INFO sqlalchemy.engine.base.Engine (9, 1, 'Ruby/Rails BackEnd Developer', '<p><h2><strong>About CrowdFlower...</strong></h2><p>CrowdFlower is the essential human-in-the-loop platform for data science teams. CrowdFlower helps ... (3313 characters truncated) ... ve total compensation package including outstanding benefits and stock options.</p> <img src="https://www.applytracking.com/track.aspx/7IJjT"/></p>\n', '<p><a href="https://www.applytracking.com/track.aspx/7IJjd">https://www.applytracking.com/track.aspx/7IJjd</a></p>\n')
# 2016-12-10 04:40:21,396 INFO sqlalchemy.engine.base.Engine INSERT INTO github_metadata (job_id, github_id, url, created_at) VALUES (?, ?, ?, ?)
# 2016-12-10 04:40:21,397 INFO sqlalchemy.engine.base.Engine (11, '53eb1432-b68b-11e6-805c-42ae75f605e1', 'http://jobs.github.com/positions/53eb1432-b68b-11e6-805c-42ae75f605e1', '2016-11-29 23:27:00.000000')
# 2016-12-10 04:40:21,398 INFO sqlalchemy.engine.base.Engine INSERT INTO location (job_id, description, remote_ok) VALUES (?, ?, ?)
# 2016-12-10 04:40:21,399 INFO sqlalchemy.engine.base.Engine (11, 'San Francisco, CA, US', 0)
# 2016-12-10 04:40:21,400 INFO sqlalchemy.engine.base.Engine COMMIT
# 2016-12-10 04:40:21,402 INFO sqlalchemy.engine.base.Engine SELECT github_metadata.job_id, github_metadata.github_id, github_metadata.url, github_metadata.created_at
# FROM github_metadata
# WHERE github_metadata.github_id = ?
# 2016-12-10 04:40:21,402 INFO sqlalchemy.engine.base.Engine ('f2dff876-b679-11e6-896e-3954f140fe85',)
# 2016-12-10 04:40:21,403 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2016-12-10 04:40:21,404 INFO sqlalchemy.engine.base.Engine SELECT company.id, company.name, company.url, company.logo_url
# FROM company
# WHERE company.url = ?
# 2016-12-10 04:40:21,405 INFO sqlalchemy.engine.base.Engine ('https://www.carbonblack.com/',)
# 2016-12-10 04:40:21,407 INFO sqlalchemy.engine.base.Engine INSERT INTO company (name, url, logo_url) VALUES (?, ?, ?)
# 2016-12-10 04:40:21,407 INFO sqlalchemy.engine.base.Engine ('Carbon Black, Inc.', 'https://www.carbonblack.com/', 'http://github-jobs.s3.amazonaws.com/309b531e-b679-11e6-8bed-4a8a3761e6da.jpg')
# 2016-12-10 04:40:21,408 INFO sqlalchemy.engine.base.Engine INSERT INTO job (company_id, type_, title, description, how_to_apply) VALUES (?, ?, ?, ?, ?)
# 2016-12-10 04:40:21,409 INFO sqlalchemy.engine.base.Engine (10, 1, 'Senior Software Engineer - Cloud', '<p><strong>Why Carbon Black?</strong></p>\n\n<p>At Carbon Black, you’ll have the opportunity to make a huge impact while working alongside a global c ... (4315 characters truncated) ... oint Protection by security professionals in the SANS Institute’s Best of 2015 Awards.</p>\n\n<p>Carbon Black is an Equal Opportunity Employer.</p>\n', '<p><a href="https://lifeatcb.carbonblack.com/job-postings/?p=job/oMPL3fw9&amp;__jvst=JobBoard&amp;__jvsd=Github&amp;nl=1">Click here to apply.</a></p>\n')
# 2016-12-10 04:40:21,412 INFO sqlalchemy.engine.base.Engine INSERT INTO github_metadata (job_id, github_id, url, created_at) VALUES (?, ?, ?, ?)
# 2016-12-10 04:40:21,413 INFO sqlalchemy.engine.base.Engine (12, 'f2dff876-b679-11e6-896e-3954f140fe85', 'http://jobs.github.com/positions/f2dff876-b679-11e6-896e-3954f140fe85', '2016-11-29 21:23:04.000000')
# 2016-12-10 04:40:21,414 INFO sqlalchemy.engine.base.Engine INSERT INTO location (job_id, description, remote_ok) VALUES (?, ?, ?)
# 2016-12-10 04:40:21,415 INFO sqlalchemy.engine.base.Engine (12, 'Waltham, MA or Telecommute', 1)
# 2016-12-10 04:40:21,416 INFO sqlalchemy.engine.base.Engine COMMIT
# 2016-12-10 04:40:21,417 INFO sqlalchemy.engine.base.Engine SELECT github_metadata.job_id, github_metadata.github_id, github_metadata.url, github_metadata.created_at
# FROM github_metadata
# WHERE github_metadata.github_id = ?
# 2016-12-10 04:40:21,418 INFO sqlalchemy.engine.base.Engine ('b3d3c3fe-b65d-11e6-9da9-6e5efb70d328',)
# 2016-12-10 04:40:21,419 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2016-12-10 04:40:21,420 INFO sqlalchemy.engine.base.Engine SELECT company.id, company.name, company.url, company.logo_url
# FROM company
# WHERE company.url = ?
# 2016-12-10 04:40:21,421 INFO sqlalchemy.engine.base.Engine ('http://www.wearesmartertravel.com',)
# 2016-12-10 04:40:21,422 INFO sqlalchemy.engine.base.Engine INSERT INTO company (name, url, logo_url) VALUES (?, ?, ?)
# 2016-12-10 04:40:21,423 INFO sqlalchemy.engine.base.Engine ('SmarterTravel', 'http://www.wearesmartertravel.com', 'http://github-jobs.s3.amazonaws.com/d4a4f27e-b667-11e6-9318-ad870fa045f5.png')
# 2016-12-10 04:40:21,425 INFO sqlalchemy.engine.base.Engine INSERT INTO job (company_id, type_, title, description, how_to_apply) VALUES (?, ?, ?, ?, ?)
# 2016-12-10 04:40:21,426 INFO sqlalchemy.engine.base.Engine (11, 1, 'Software Engineering Manager, Oyster.com', '<p>SmarterTravel, a TripAdvisor Company, offers travelers a portfolio of travel sites to help them find the right trip at the right price.  We are a  ... (3479 characters truncated) ... d, if necessary, the Department of Homeland Security (DHS) with information from each new employee&#39;s I-9 to confirm work authorization. ***</p>\n', '<p>Please apply online at <a href="http://grnh.se/ta5py11">http://grnh.se/ta5py11</a> or email your resume to <a href="mailto:careers@smartertravel.com">careers@smartertravel.com</a></p>\n')
# 2016-12-10 04:40:21,428 INFO sqlalchemy.engine.base.Engine INSERT INTO github_metadata (job_id, github_id, url, created_at) VALUES (?, ?, ?, ?)
# 2016-12-10 04:40:21,429 INFO sqlalchemy.engine.base.Engine (13, 'b3d3c3fe-b65d-11e6-9da9-6e5efb70d328', 'http://jobs.github.com/positions/b3d3c3fe-b65d-11e6-9da9-6e5efb70d328', '2016-11-29 19:14:14.000000')
# 2016-12-10 04:40:21,431 INFO sqlalchemy.engine.base.Engine INSERT INTO location (job_id, description, remote_ok) VALUES (?, ?, ?)
# 2016-12-10 04:40:21,431 INFO sqlalchemy.engine.base.Engine (13, 'New York, NY', 0)
# 2016-12-10 04:40:21,433 INFO sqlalchemy.engine.base.Engine COMMIT
# 2016-12-10 04:40:21,435 INFO sqlalchemy.engine.base.Engine SELECT github_metadata.job_id, github_metadata.github_id, github_metadata.url, github_metadata.created_at
# FROM github_metadata
# WHERE github_metadata.github_id = ?
# 2016-12-10 04:40:21,436 INFO sqlalchemy.engine.base.Engine ('ada0319c-b57d-11e6-9c3c-d13afadb65a8',)
# 2016-12-10 04:40:21,438 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2016-12-10 04:40:21,439 INFO sqlalchemy.engine.base.Engine SELECT company.id, company.name, company.url, company.logo_url
# FROM company
# WHERE company.url = ?
# 2016-12-10 04:40:21,440 INFO sqlalchemy.engine.base.Engine ('http://www.teleopti.com/index.aspx',)
# 2016-12-10 04:40:21,441 INFO sqlalchemy.engine.base.Engine INSERT INTO company (name, url, logo_url) VALUES (?, ?, ?)
# 2016-12-10 04:40:21,442 INFO sqlalchemy.engine.base.Engine ('Teleopti', 'http://www.teleopti.com/index.aspx', 'http://github-jobs.s3.amazonaws.com/9d62e428-b57d-11e6-85ba-b1fdde6cc6ee.jpg')
# 2016-12-10 04:40:21,443 INFO sqlalchemy.engine.base.Engine INSERT INTO job (company_id, type_, title, description, how_to_apply) VALUES (?, ?, ?, ?, ?)
# 2016-12-10 04:40:21,444 INFO sqlalchemy.engine.base.Engine (12, 1, 'Front-End Lead Developer to Teleopti ', '<p>If you are a team player who appreciates freedom with responsibility and working in an international and creative environment, this is the job for ... (5667 characters truncated) ... e third year in a row, Teleopti is ranked by Great Place to Work as one of Sweden´s best workplaces, in the category of medium-sized companies.</p>\n', '<p>Do you meet the requirements? Click on the link below:\n<a href="https://www.academicwork.se/annons/front-end-lead-developer-to-teleopti/14979312? ... (435 characters truncated) ... academicwork.se</a> and we will answer during office hours. Please write the advert title in the subject and paste the advert link in the mail.</p>\n')
# 2016-12-10 04:40:21,446 INFO sqlalchemy.engine.base.Engine INSERT INTO github_metadata (job_id, github_id, url, created_at) VALUES (?, ?, ?, ?)
# 2016-12-10 04:40:21,448 INFO sqlalchemy.engine.base.Engine (14, 'ada0319c-b57d-11e6-9c3c-d13afadb65a8', 'http://jobs.github.com/positions/ada0319c-b57d-11e6-9c3c-d13afadb65a8', '2016-11-28 15:17:34.000000')
# 2016-12-10 04:40:21,450 INFO sqlalchemy.engine.base.Engine INSERT INTO location (job_id, description, remote_ok) VALUES (?, ?, ?)
# 2016-12-10 04:40:21,451 INFO sqlalchemy.engine.base.Engine (14, 'Stockholm', 0)
# 2016-12-10 04:40:21,452 INFO sqlalchemy.engine.base.Engine COMMIT
# 2016-12-10 04:40:21,453 INFO sqlalchemy.engine.base.Engine SELECT github_metadata.job_id, github_metadata.github_id, github_metadata.url, github_metadata.created_at
# FROM github_metadata
# WHERE github_metadata.github_id = ?
# 2016-12-10 04:40:21,454 INFO sqlalchemy.engine.base.Engine ('cf34f21a-b308-11e6-9192-6f14e27e77e8',)
# 2016-12-10 04:40:21,455 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2016-12-10 04:40:21,456 INFO sqlalchemy.engine.base.Engine SELECT company.id, company.name, company.url, company.logo_url
# FROM company
# WHERE company.url = ?
# 2016-12-10 04:40:21,457 INFO sqlalchemy.engine.base.Engine ('http://www.workingatbooking.com',)
# 2016-12-10 04:40:21,458 INFO sqlalchemy.engine.base.Engine INSERT INTO company (name, url, logo_url) VALUES (?, ?, ?)
# 2016-12-10 04:40:21,459 INFO sqlalchemy.engine.base.Engine ('Booking.com', 'http://www.workingatbooking.com', 'http://github-jobs.s3.amazonaws.com/c9146712-b308-11e6-875e-1fa7ba6a7f42.jpeg')
# 2016-12-10 04:40:21,460 INFO sqlalchemy.engine.base.Engine INSERT INTO job (company_id, type_, title, description, how_to_apply) VALUES (?, ?, ?, ?, ?)
# 2016-12-10 04:40:21,461 INFO sqlalchemy.engine.base.Engine (13, 1, 'Data Scientist – Machine Learning', '<p>Would you like to translate terabytes of data into unforgettable holidays for millions of people around the globe? Booking.com, the world’s larges ... (3049 characters truncated) ... is looking for a Data Scientist - Machine Learning in Amsterdam, the Netherlands. All references to “Booking.com&quot; refer to Booking.com BV.</p>\n', '<p>Apply: <a href="http://grnh.se/62yip51">http://grnh.se/62yip51</a></p>\n')
# 2016-12-10 04:40:21,464 INFO sqlalchemy.engine.base.Engine INSERT INTO github_metadata (job_id, github_id, url, created_at) VALUES (?, ?, ?, ?)
# 2016-12-10 04:40:21,465 INFO sqlalchemy.engine.base.Engine (15, 'cf34f21a-b308-11e6-9192-6f14e27e77e8', 'http://jobs.github.com/positions/cf34f21a-b308-11e6-9192-6f14e27e77e8', '2016-11-25 12:15:59.000000')
# 2016-12-10 04:40:21,467 INFO sqlalchemy.engine.base.Engine INSERT INTO location (job_id, description, remote_ok) VALUES (?, ?, ?)
# 2016-12-10 04:40:21,468 INFO sqlalchemy.engine.base.Engine (15, 'Amsterdam', 0)
# 2016-12-10 04:40:21,469 INFO sqlalchemy.engine.base.Engine COMMIT
# 2016-12-10 04:40:21,471 INFO sqlalchemy.engine.base.Engine SELECT github_metadata.job_id, github_metadata.github_id, github_metadata.url, github_metadata.created_at
# FROM github_metadata
# WHERE github_metadata.github_id = ?
# 2016-12-10 04:40:21,472 INFO sqlalchemy.engine.base.Engine ('4e2c3674-b308-11e6-9dbe-b0fc9cbe45b2',)
# 2016-12-10 04:40:21,473 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2016-12-10 04:40:21,475 INFO sqlalchemy.engine.base.Engine SELECT company.id, company.name, company.url, company.logo_url
# FROM company
# WHERE company.url = ?
# 2016-12-10 04:40:21,475 INFO sqlalchemy.engine.base.Engine ('http://www.workingatbooking.com',)
# 2016-12-10 04:40:21,477 INFO sqlalchemy.engine.base.Engine INSERT INTO job (company_id, type_, title, description, how_to_apply) VALUES (?, ?, ?, ?, ?)
# 2016-12-10 04:40:21,477 INFO sqlalchemy.engine.base.Engine (13, 1, 'Data Scientist – Analytics', '<p>Booking.com is looking for data savvy professionals to join our team of data scientists. You will be working with stakeholders throughout the comp ... (2719 characters truncated) ... com BV is looking for a Data Scientist - Analytics in Amsterdam, the Netherlands. All references to “Booking.com&quot; refer to Booking.com BV.</p>\n', '<p>Apply:  <a href="http://grnh.se/62yip51">http://grnh.se/62yip51</a></p>\n')
# 2016-12-10 04:40:21,479 INFO sqlalchemy.engine.base.Engine INSERT INTO github_metadata (job_id, github_id, url, created_at) VALUES (?, ?, ?, ?)
# 2016-12-10 04:40:21,480 INFO sqlalchemy.engine.base.Engine (16, '4e2c3674-b308-11e6-9dbe-b0fc9cbe45b2', 'http://jobs.github.com/positions/4e2c3674-b308-11e6-9dbe-b0fc9cbe45b2', '2016-11-25 12:12:50.000000')
# 2016-12-10 04:40:21,481 INFO sqlalchemy.engine.base.Engine INSERT INTO location (job_id, description, remote_ok) VALUES (?, ?, ?)
# 2016-12-10 04:40:21,483 INFO sqlalchemy.engine.base.Engine (16, 'Amsterdam', 0)
# 2016-12-10 04:40:21,485 INFO sqlalchemy.engine.base.Engine COMMIT
# 2016-12-10 04:40:21,487 INFO sqlalchemy.engine.base.Engine SELECT github_metadata.job_id, github_metadata.github_id, github_metadata.url, github_metadata.created_at
# FROM github_metadata
# WHERE github_metadata.github_id = ?
# 2016-12-10 04:40:21,488 INFO sqlalchemy.engine.base.Engine ('f2648464-b10d-11e6-9bd0-5ecee6c9ffa7',)
# 2016-12-10 04:40:21,490 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2016-12-10 04:40:21,491 INFO sqlalchemy.engine.base.Engine SELECT company.id, company.name, company.url, company.logo_url
# FROM company
# WHERE company.url = ?
# 2016-12-10 04:40:21,492 INFO sqlalchemy.engine.base.Engine ('http://www.livestories.com',)
# 2016-12-10 04:40:21,494 INFO sqlalchemy.engine.base.Engine INSERT INTO company (name, url, logo_url) VALUES (?, ?, ?)
# 2016-12-10 04:40:21,495 INFO sqlalchemy.engine.base.Engine ('LiveStories', 'http://www.livestories.com', 'http://github-jobs.s3.amazonaws.com/a74585a0-b10d-11e6-80d4-bae80c66bb59.png')
# 2016-12-10 04:40:21,498 INFO sqlalchemy.engine.base.Engine INSERT INTO job (company_id, type_, title, description, how_to_apply) VALUES (?, ?, ?, ?, ?)
# 2016-12-10 04:40:21,499 INFO sqlalchemy.engine.base.Engine (14, 1, '(Sr.) Front End Engineer', '<h1>Why LiveStories?</h1>\n\n<p>LiveStories is a venture-backed company building modern tools to help the world’s largest sector be more data-driven, ... (2026 characters truncated) ... ental, and vision benefits </li>\n<li>Flexible vacation policy </li>\n<li>An incredible team of smart, dedicated, and supportive people</li>\n</ul>\n', '<p>Send your resume to <a href="mailto:careers@livestories.com">careers@livestories.com</a></p>\n')
# 2016-12-10 04:40:21,501 INFO sqlalchemy.engine.base.Engine INSERT INTO github_metadata (job_id, github_id, url, created_at) VALUES (?, ?, ?, ?)
# 2016-12-10 04:40:21,502 INFO sqlalchemy.engine.base.Engine (17, 'f2648464-b10d-11e6-9bd0-5ecee6c9ffa7', 'http://jobs.github.com/positions/f2648464-b10d-11e6-9bd0-5ecee6c9ffa7', '2016-11-22 23:48:04.000000')
# 2016-12-10 04:40:21,503 INFO sqlalchemy.engine.base.Engine INSERT INTO location (job_id, description, remote_ok) VALUES (?, ?, ?)
# 2016-12-10 04:40:21,504 INFO sqlalchemy.engine.base.Engine (17, 'Seattle', 0)
# 2016-12-10 04:40:21,505 INFO sqlalchemy.engine.base.Engine COMMIT
# 2016-12-10 04:40:21,506 INFO sqlalchemy.engine.base.Engine SELECT github_metadata.job_id, github_metadata.github_id, github_metadata.url, github_metadata.created_at
# FROM github_metadata
# WHERE github_metadata.github_id = ?
# 2016-12-10 04:40:21,507 INFO sqlalchemy.engine.base.Engine ('048cd71c-adae-11e6-9327-2b710fbf6e21',)
# 2016-12-10 04:40:21,508 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2016-12-10 04:40:21,509 INFO sqlalchemy.engine.base.Engine SELECT company.id, company.name, company.url, company.logo_url
# FROM company
# WHERE company.url = ?
# 2016-12-10 04:40:21,511 INFO sqlalchemy.engine.base.Engine ('http://www.mayfieldrobotics.com/',)
# 2016-12-10 04:40:21,512 INFO sqlalchemy.engine.base.Engine INSERT INTO company (name, url, logo_url) VALUES (?, ?, ?)
# 2016-12-10 04:40:21,513 INFO sqlalchemy.engine.base.Engine ('Mayfield Robotics', 'http://www.mayfieldrobotics.com/', 'http://github-jobs.s3.amazonaws.com/85454f34-adad-11e6-938c-da7ff962d92f.png')
# 2016-12-10 04:40:21,515 INFO sqlalchemy.engine.base.Engine INSERT INTO job (company_id, type_, title, description, how_to_apply) VALUES (?, ?, ?, ?, ?)
# 2016-12-10 04:40:21,516 INFO sqlalchemy.engine.base.Engine (15, 1, 'Software Test Engineer (Python)', '<p>About the Company:</p>\n\n<p>At Mayfield Robotics, we make home robots that are joyful, useful, and inspiring. We move fast, we like and respect e ... (3997 characters truncated) ... es </li>\n<li>Tuition reimbursement </li>\n<li>401K </li>\n<li>Laundry/dry cleaning service </li>\n<li>Happy hours &amp; company events</li>\n</ul>\n', '<p>To apply, send your resume to <a href="mailto:jobs+qa@mayfieldrobotics.com">jobs+qa@mayfieldrobotics.com</a>.</p>\n')
# 2016-12-10 04:40:21,518 INFO sqlalchemy.engine.base.Engine INSERT INTO github_metadata (job_id, github_id, url, created_at) VALUES (?, ?, ?, ?)
# 2016-12-10 04:40:21,518 INFO sqlalchemy.engine.base.Engine (18, '048cd71c-adae-11e6-9327-2b710fbf6e21', 'http://jobs.github.com/positions/048cd71c-adae-11e6-9327-2b710fbf6e21', '2016-11-18 16:43:44.000000')
# 2016-12-10 04:40:21,519 INFO sqlalchemy.engine.base.Engine INSERT INTO location (job_id, description, remote_ok) VALUES (?, ?, ?)
# 2016-12-10 04:40:21,522 INFO sqlalchemy.engine.base.Engine (18, 'Redwood City, CA', 0)
# 2016-12-10 04:40:21,524 INFO sqlalchemy.engine.base.Engine COMMIT
# 2016-12-10 04:40:21,525 INFO sqlalchemy.engine.base.Engine SELECT github_metadata.job_id, github_metadata.github_id, github_metadata.url, github_metadata.created_at
# FROM github_metadata
# WHERE github_metadata.github_id = ?
# 2016-12-10 04:40:21,526 INFO sqlalchemy.engine.base.Engine ('b92c77de-ab62-11e6-9d5d-0f03dd750bd7',)
# 2016-12-10 04:40:21,527 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2016-12-10 04:40:21,528 INFO sqlalchemy.engine.base.Engine SELECT company.id, company.name, company.url, company.logo_url
# FROM company
# WHERE company.url = ?
# 2016-12-10 04:40:21,529 INFO sqlalchemy.engine.base.Engine ('http://www.spreemo.com',)
# 2016-12-10 04:40:21,530 INFO sqlalchemy.engine.base.Engine INSERT INTO company (name, url, logo_url) VALUES (?, ?, ?)
# 2016-12-10 04:40:21,531 INFO sqlalchemy.engine.base.Engine ('Spreemo', 'http://www.spreemo.com', 'http://github-jobs.s3.amazonaws.com/8530b198-ab62-11e6-9227-10b58f5dcfab.png')
# 2016-12-10 04:40:21,533 INFO sqlalchemy.engine.base.Engine INSERT INTO job (company_id, type_, title, description, how_to_apply) VALUES (?, ?, ?, ?, ?)
# 2016-12-10 04:40:21,534 INFO sqlalchemy.engine.base.Engine (16, 1, 'Software Engineer', '<h2><strong>Who are we?</strong></h2>\n\n<p>At Spreemo we believe that advanced data science can prevent serious misdiagnoses and poor outcomes. Usin ... (2839 characters truncated) ... t benefits. Benefits include: medical + dental insurance, FSA, pre-tax commuter benefits, lots of paid time off, and Macbook Pro + XL monitors.</p>\n', '<p>Visit <a href="https://jobs.lever.co/spreemo.com/76c7822a-481a-4629-9a6e-ac6fe811885f">https://jobs.lever.co/spreemo.com/76c7822a-481a-4629-9a6e-ac6fe811885f</a></p>\n')
# 2016-12-10 04:40:21,535 INFO sqlalchemy.engine.base.Engine INSERT INTO github_metadata (job_id, github_id, url, created_at) VALUES (?, ?, ?, ?)
# 2016-12-10 04:40:21,536 INFO sqlalchemy.engine.base.Engine (19, 'b92c77de-ab62-11e6-9d5d-0f03dd750bd7', 'http://jobs.github.com/positions/b92c77de-ab62-11e6-9d5d-0f03dd750bd7', '2016-11-15 18:39:28.000000')
# 2016-12-10 04:40:21,538 INFO sqlalchemy.engine.base.Engine INSERT INTO location (job_id, description, remote_ok) VALUES (?, ?, ?)
# 2016-12-10 04:40:21,539 INFO sqlalchemy.engine.base.Engine (19, 'New York, NY', 0)
# 2016-12-10 04:40:21,540 INFO sqlalchemy.engine.base.Engine COMMIT
# 2016-12-10 04:40:21,541 INFO sqlalchemy.engine.base.Engine SELECT github_metadata.job_id, github_metadata.github_id, github_metadata.url, github_metadata.created_at
# FROM github_metadata
# WHERE github_metadata.github_id = ?
# 2016-12-10 04:40:21,542 INFO sqlalchemy.engine.base.Engine ('d409edb0-ab4a-11e6-8eed-c01232d09e01',)
# 2016-12-10 04:40:21,544 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2016-12-10 04:40:21,545 INFO sqlalchemy.engine.base.Engine SELECT company.id, company.name, company.url, company.logo_url
# FROM company
# WHERE company.url IS NULL
# 2016-12-10 04:40:21,546 INFO sqlalchemy.engine.base.Engine ()
# 2016-12-10 04:40:21,548 INFO sqlalchemy.engine.base.Engine INSERT INTO job (company_id, type_, title, description, how_to_apply) VALUES (?, ?, ?, ?, ?)
# 2016-12-10 04:40:21,549 INFO sqlalchemy.engine.base.Engine (9, 1, 'Software Project Manager', '<p>Summary:</p>\n\n<p>eHealth Africa is focused on improving healthcare by creating effective ways to implement reliable health information managemen ... (3184 characters truncated) ... -paced environment</p>\n\n<p>Ability to work on multiple projects simultaneously and deliver within tight timelines</p>\n\n<p>Fluent in English</p>\n', '<p><a href="https://eHealthAfrica.bamboohr.com/jobs/view.php?id=40">https://eHealthAfrica.bamboohr.com/jobs/view.php?id=40</a></p>\n')
# 2016-12-10 04:40:21,551 INFO sqlalchemy.engine.base.Engine INSERT INTO github_metadata (job_id, github_id, url, created_at) VALUES (?, ?, ?, ?)
# 2016-12-10 04:40:21,552 INFO sqlalchemy.engine.base.Engine (20, 'd409edb0-ab4a-11e6-8eed-c01232d09e01', 'http://jobs.github.com/positions/d409edb0-ab4a-11e6-8eed-c01232d09e01', '2016-11-15 15:49:15.000000')
# 2016-12-10 04:40:21,553 INFO sqlalchemy.engine.base.Engine INSERT INTO location (job_id, description, remote_ok) VALUES (?, ?, ?)
# 2016-12-10 04:40:21,554 INFO sqlalchemy.engine.base.Engine (20, 'Sierra Leone', 0)
# 2016-12-10 04:40:21,556 INFO sqlalchemy.engine.base.Engine COMMIT
# 2016-12-10 04:40:21,557 INFO sqlalchemy.engine.base.Engine SELECT github_metadata.job_id, github_metadata.github_id, github_metadata.url, github_metadata.created_at
# FROM github_metadata
# WHERE github_metadata.github_id = ?
# 2016-12-10 04:40:21,558 INFO sqlalchemy.engine.base.Engine ('2e1b4148-ab49-11e6-8b5d-230703ad0bc9',)
# 2016-12-10 04:40:21,560 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2016-12-10 04:40:21,561 INFO sqlalchemy.engine.base.Engine SELECT company.id, company.name, company.url, company.logo_url
# FROM company
# WHERE company.url IS NULL
# 2016-12-10 04:40:21,562 INFO sqlalchemy.engine.base.Engine ()
# 2016-12-10 04:40:21,563 INFO sqlalchemy.engine.base.Engine INSERT INTO job (company_id, type_, title, description, how_to_apply) VALUES (?, ?, ?, ?, ?)
# 2016-12-10 04:40:21,563 INFO sqlalchemy.engine.base.Engine (9, 1, 'Senior Andriod Developer(Freelance for 6 months)', '<p>Summary:</p>\n\n<p>eHealth Africa is focused on improving healthcare by creating effective ways to implement reliable health information managemen ... (3582 characters truncated) ... our priority as well as rewarding them for their hard work.</p>\n\n<p>Note: The successful candidate will work either from Freetown or  Berlin.</p>\n', '<p><a href="https://eHealthAfrica.bamboohr.com/jobs/view.php?id=38">https://eHealthAfrica.bamboohr.com/jobs/view.php?id=38</a></p>\n')
# 2016-12-10 04:40:21,565 INFO sqlalchemy.engine.base.Engine INSERT INTO github_metadata (job_id, github_id, url, created_at) VALUES (?, ?, ?, ?)
# 2016-12-10 04:40:21,566 INFO sqlalchemy.engine.base.Engine (21, '2e1b4148-ab49-11e6-8b5d-230703ad0bc9', 'http://jobs.github.com/positions/2e1b4148-ab49-11e6-8b5d-230703ad0bc9', '2016-11-15 15:39:44.000000')
# 2016-12-10 04:40:21,567 INFO sqlalchemy.engine.base.Engine INSERT INTO location (job_id, description, remote_ok) VALUES (?, ?, ?)
# 2016-12-10 04:40:21,568 INFO sqlalchemy.engine.base.Engine (21, 'Sierra Leone', 0)
# 2016-12-10 04:40:21,569 INFO sqlalchemy.engine.base.Engine COMMIT
# 2016-12-10 04:40:21,570 INFO sqlalchemy.engine.base.Engine SELECT github_metadata.job_id, github_metadata.github_id, github_metadata.url, github_metadata.created_at
# FROM github_metadata
# WHERE github_metadata.github_id = ?
# 2016-12-10 04:40:21,571 INFO sqlalchemy.engine.base.Engine ('a0e32852-aa9b-11e6-93e6-4146165b3b6f',)
# 2016-12-10 04:40:21,572 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2016-12-10 04:40:21,573 INFO sqlalchemy.engine.base.Engine SELECT company.id, company.name, company.url, company.logo_url
# FROM company
# WHERE company.url = ?
# 2016-12-10 04:40:21,574 INFO sqlalchemy.engine.base.Engine ('http://www.tyco.com/',)
# 2016-12-10 04:40:21,575 INFO sqlalchemy.engine.base.Engine INSERT INTO company (name, url, logo_url) VALUES (?, ?, ?)
# 2016-12-10 04:40:21,576 INFO sqlalchemy.engine.base.Engine ('Johnson Controls', 'http://www.tyco.com/', 'http://github-jobs.s3.amazonaws.com/9c77a9be-aa9b-11e6-9186-3e169096f20b.png')
# 2016-12-10 04:40:21,577 INFO sqlalchemy.engine.base.Engine INSERT INTO job (company_id, type_, title, description, how_to_apply) VALUES (?, ?, ?, ?, ?)
# 2016-12-10 04:40:21,578 INFO sqlalchemy.engine.base.Engine (17, 1, 'Senior Android Engineer', '<p>ANDROID JOB DESCRIPTION\niOS and/or wearable is nice to have. Bluetooth and Embedded Experience also nice to have.</p>\n\n<p>As a Senior Mobile En ... (4111 characters truncated) ... t importantly, (Have a Personality  ) we are a fun crowd and like to work with other fun talented people.</li>\n</ul>\n\n<p>Job Type: Full-Time</p>\n', '<p>Visit:\n<a href="https://jobs.johnsoncontrols.com/job-details/software-engineer-iii-mobile/649849012/">https://jobs.johnsoncontrols.com/job-detail ... (25 characters truncated) ... obile/649849012/</a></p>\n\n<p>or</p>\n\n<p>send resume directly to <a href="mailto:JoPedroza@tycoint.com">JoPedroza@tycoint.com</a> for review</p>\n')
# 2016-12-10 04:40:21,580 INFO sqlalchemy.engine.base.Engine INSERT INTO github_metadata (job_id, github_id, url, created_at) VALUES (?, ?, ?, ?)
# 2016-12-10 04:40:21,581 INFO sqlalchemy.engine.base.Engine (22, 'a0e32852-aa9b-11e6-93e6-4146165b3b6f', 'http://jobs.github.com/positions/a0e32852-aa9b-11e6-93e6-4146165b3b6f', '2016-11-14 18:54:05.000000')
# 2016-12-10 04:40:21,582 INFO sqlalchemy.engine.base.Engine INSERT INTO location (job_id, description, remote_ok) VALUES (?, ?, ?)
# 2016-12-10 04:40:21,583 INFO sqlalchemy.engine.base.Engine (22, 'Irvine, CA', 0)
# 2016-12-10 04:40:21,584 INFO sqlalchemy.engine.base.Engine COMMIT
# 2016-12-10 04:40:21,585 INFO sqlalchemy.engine.base.Engine SELECT github_metadata.job_id, github_metadata.github_id, github_metadata.url, github_metadata.created_at
# FROM github_metadata
# WHERE github_metadata.github_id = ?
# 2016-12-10 04:40:21,587 INFO sqlalchemy.engine.base.Engine ('0e70b42e-aa98-11e6-9dc7-99d5c3a10bc9',)
# 2016-12-10 04:40:21,588 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2016-12-10 04:40:21,590 INFO sqlalchemy.engine.base.Engine SELECT company.id, company.name, company.url, company.logo_url
# FROM company
# WHERE company.url = ?
# 2016-12-10 04:40:21,590 INFO sqlalchemy.engine.base.Engine ('https://jobs.sap.com/search/?q=SAPmachinelearningcareers&locationsearch=&utm_source=github&utm_campaign=sap_machinelearning',)
# 2016-12-10 04:40:21,592 INFO sqlalchemy.engine.base.Engine INSERT INTO company (name, url, logo_url) VALUES (?, ?, ?)
# 2016-12-10 04:40:21,592 INFO sqlalchemy.engine.base.Engine ('SAP', 'https://jobs.sap.com/search/?q=SAPmachinelearningcareers&locationsearch=&utm_source=github&utm_campaign=sap_machinelearning', 'http://github-jobs.s3.amazonaws.com/05fe7560-aa98-11e6-9e8a-0e66c883b7dd.png')
# 2016-12-10 04:40:21,594 INFO sqlalchemy.engine.base.Engine INSERT INTO job (company_id, type_, title, description, how_to_apply) VALUES (?, ?, ?, ?, ?)
# 2016-12-10 04:40:21,595 INFO sqlalchemy.engine.base.Engine (18, 1, 'Developer with ML background for Machine Learning development Job', '<p><a href="https://jobs.sap.com/job/Palo-Alto-Developer-with-ML-background-for-Machine-Learning-development-Job-CA-94301/327259801/?feedId=203001&ut ... (1486 characters truncated) ... arning-development-Job-CA-94301/327259801/?feedId=203001&utm_source=github&utm_campaign=sap_machinelearning">Apply on our career site here.</a></p>\n', '<p><a href="https://jobs.sap.com/job/Palo-Alto-Developer-with-ML-background-for-Machine-Learning-development-Job-CA-94301/327259801/?feedId=203001&utm_source=github&utm_campaign=sap_machinelearning">Apply on our career site here.</a></p>\n')
# 2016-12-10 04:40:21,596 INFO sqlalchemy.engine.base.Engine INSERT INTO github_metadata (job_id, github_id, url, created_at) VALUES (?, ?, ?, ?)
# 2016-12-10 04:40:21,596 INFO sqlalchemy.engine.base.Engine (23, '0e70b42e-aa98-11e6-9dc7-99d5c3a10bc9', 'http://jobs.github.com/positions/0e70b42e-aa98-11e6-9dc7-99d5c3a10bc9', '2016-11-14 18:29:10.000000')
# 2016-12-10 04:40:21,598 INFO sqlalchemy.engine.base.Engine INSERT INTO location (job_id, description, remote_ok) VALUES (?, ?, ?)
# 2016-12-10 04:40:21,598 INFO sqlalchemy.engine.base.Engine (23, 'Palo Alto', 0)
# 2016-12-10 04:40:21,599 INFO sqlalchemy.engine.base.Engine COMMIT
# 2016-12-10 04:40:21,601 INFO sqlalchemy.engine.base.Engine SELECT github_metadata.job_id, github_metadata.github_id, github_metadata.url, github_metadata.created_at
# FROM github_metadata
# WHERE github_metadata.github_id = ?
# 2016-12-10 04:40:21,602 INFO sqlalchemy.engine.base.Engine ('43b8b066-a83e-11e6-9dcf-84f334f5295b',)
# 2016-12-10 04:40:21,603 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2016-12-10 04:40:21,604 INFO sqlalchemy.engine.base.Engine SELECT company.id, company.name, company.url, company.logo_url
# FROM company
# WHERE company.url = ?
# 2016-12-10 04:40:21,605 INFO sqlalchemy.engine.base.Engine ('http://www.leadpages.net/',)
# 2016-12-10 04:40:21,606 INFO sqlalchemy.engine.base.Engine INSERT INTO company (name, url, logo_url) VALUES (?, ?, ?)
# 2016-12-10 04:40:21,607 INFO sqlalchemy.engine.base.Engine ('Leadpages', 'http://www.leadpages.net/', 'http://github-jobs.s3.amazonaws.com/314925f0-a83e-11e6-8350-38442bc0d153.png')
# 2016-12-10 04:40:21,608 INFO sqlalchemy.engine.base.Engine INSERT INTO job (company_id, type_, title, description, how_to_apply) VALUES (?, ?, ?, ?, ?)
# 2016-12-10 04:40:21,609 INFO sqlalchemy.engine.base.Engine (19, 1, 'Site Reliability Engineer', '<p>We promise you haven’t worked with anyone <a href="http://www.leadpages.net/careers">like us</a> before.  We’re a Minneapolis / St. Paul, MN based ... (6317 characters truncated) ... leadpages.net/apply/YN38C7/Site-Reliability-Engineer?source=Github">HERE</a>. Thanks for checking us out - we look forward to hearing from you!</p>\n', '<p><strong>Sound like you?</strong></p>\n\n<p>To apply, please submit your tailored resume, a link to your LinkedIn profile, and a cover letter expla ... (95 characters truncated) ... leadpages.net/apply/YN38C7/Site-Reliability-Engineer?source=Github">HERE</a>. Thanks for checking us out - we look forward to hearing from you!</p>\n')
# 2016-12-10 04:40:21,611 INFO sqlalchemy.engine.base.Engine INSERT INTO github_metadata (job_id, github_id, url, created_at) VALUES (?, ?, ?, ?)
# 2016-12-10 04:40:21,612 INFO sqlalchemy.engine.base.Engine (24, '43b8b066-a83e-11e6-9dcf-84f334f5295b', 'http://jobs.github.com/positions/43b8b066-a83e-11e6-9dcf-84f334f5295b', '2016-11-11 18:41:52.000000')
# 2016-12-10 04:40:21,614 INFO sqlalchemy.engine.base.Engine INSERT INTO location (job_id, description, remote_ok) VALUES (?, ?, ?)
# 2016-12-10 04:40:21,614 INFO sqlalchemy.engine.base.Engine (24, 'Minneapolis, MN', 0)
# 2016-12-10 04:40:21,616 INFO sqlalchemy.engine.base.Engine COMMIT
# 2016-12-10 04:40:21,618 INFO sqlalchemy.engine.base.Engine SELECT github_metadata.job_id, github_metadata.github_id, github_metadata.url, github_metadata.created_at
# FROM github_metadata
# WHERE github_metadata.github_id = ?
# 2016-12-10 04:40:21,619 INFO sqlalchemy.engine.base.Engine ('7978e922-a781-11e6-9907-af5d98bf0bd7',)
# 2016-12-10 04:40:21,620 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2016-12-10 04:40:21,621 INFO sqlalchemy.engine.base.Engine SELECT company.id, company.name, company.url, company.logo_url
# FROM company
# WHERE company.url = ?
# 2016-12-10 04:40:21,622 INFO sqlalchemy.engine.base.Engine ('http://www.fiftythree.com',)
# 2016-12-10 04:40:21,624 INFO sqlalchemy.engine.base.Engine INSERT INTO company (name, url, logo_url) VALUES (?, ?, ?)
# 2016-12-10 04:40:21,625 INFO sqlalchemy.engine.base.Engine ('FiftyThree, Inc.', 'http://www.fiftythree.com', None)
# 2016-12-10 04:40:21,627 INFO sqlalchemy.engine.base.Engine INSERT INTO job (company_id, type_, title, description, how_to_apply) VALUES (?, ?, ?, ?, ?)
# 2016-12-10 04:40:21,628 INFO sqlalchemy.engine.base.Engine (20, 1, 'Software Engineer, Front-End Web', '<p>Job Profile:</p>\n\n<p>Build rich, dynamic, magical web applications. Work hand-in-hand with the design and product teams to implement interfaces  ... (2360 characters truncated) ... >Catered in-office lunches twice weekly and fully stocked pantry </li>\n<li>Flexible Time Off Policy </li>\n<li>Employee Equity Program</li>\n</ul>\n', '<p><a href="http://grnh.se/bdfpi81">http://grnh.se/bdfpi81</a></p>\n')
# 2016-12-10 04:40:21,630 INFO sqlalchemy.engine.base.Engine INSERT INTO github_metadata (job_id, github_id, url, created_at) VALUES (?, ?, ?, ?)
# 2016-12-10 04:40:21,631 INFO sqlalchemy.engine.base.Engine (25, '7978e922-a781-11e6-9907-af5d98bf0bd7', 'http://jobs.github.com/positions/7978e922-a781-11e6-9907-af5d98bf0bd7', '2016-11-10 20:23:11.000000')
# 2016-12-10 04:40:21,634 INFO sqlalchemy.engine.base.Engine INSERT INTO location (job_id, description, remote_ok) VALUES (?, ?, ?)
# 2016-12-10 04:40:21,636 INFO sqlalchemy.engine.base.Engine (25, 'New York, NY', 0)
# 2016-12-10 04:40:21,637 INFO sqlalchemy.engine.base.Engine COMMIT

# %%
from sqlalchemy.sql import text

s = text('SELECT * FROM company')
result = conn.execute(s)

for row in result:
    print('\n {}'.format(row))
# Out:
# 2016-12-10 04:41:13,477 INFO sqlalchemy.engine.base.Engine SELECT * FROM company
# 2016-12-10 04:41:13,478 INFO sqlalchemy.engine.base.Engine ()
#
#  (1, 'The Nordam Group', 'http://nordam.com/', 'http://github-jobs.s3.amazonaws.com/f53d44ee-be25-11e6-957a-f616239dc5c8.png')
#
#  (2, 'Make School', 'http://www.makeschool.com', 'http://github-jobs.s3.amazonaws.com/1a750858-bd92-11e6-86c4-3164e610a489.png')
#
#  (3, 'imo messenger', 'https://imo.im', 'http://github-jobs.s3.amazonaws.com/a1d804d0-bce3-11e6-8a7f-9700ffb8862d.png')
#
#  (4, 'Network Merchants, LLC', 'http://nmi.com', 'http://github-jobs.s3.amazonaws.com/a1b8f9ec-bbed-11e6-960a-b1034c4cd71b.png')
#
#  (5, 'Stevens Capital Management LP', 'http://www.scm-lp.com', 'http://github-jobs.s3.amazonaws.com/5df90c6a-baf8-11e6-8a38-492033c01d86.png')
#
#  (6, 'GenePeeks, Inc', 'http://www.genepeeks.com', 'http://github-jobs.s3.amazonaws.com/67ea79ea-b8c6-11e6-81ec-ba6eeed777c6.jpg')
#
#  (7, 'Intel Corporation', 'http://jobs.intel.com', 'http://github-jobs.s3.amazonaws.com/0590279e-b7eb-11e6-92e0-095053d3f49d.png')
#
#  (8, 'PDT Partners', 'http://www.pdtpartners.com', 'http://github-jobs.s3.amazonaws.com/1dee7540-b7f8-11e6-8780-56e37987ae3b.png')
#
#  (9, 'CrowdFlower', None, None)
#
#  (10, 'Carbon Black, Inc.', 'https://www.carbonblack.com/', 'http://github-jobs.s3.amazonaws.com/309b531e-b679-11e6-8bed-4a8a3761e6da.jpg')
#
#  (11, 'SmarterTravel', 'http://www.wearesmartertravel.com', 'http://github-jobs.s3.amazonaws.com/d4a4f27e-b667-11e6-9318-ad870fa045f5.png')
#
#  (12, 'Teleopti', 'http://www.teleopti.com/index.aspx', 'http://github-jobs.s3.amazonaws.com/9d62e428-b57d-11e6-85ba-b1fdde6cc6ee.jpg')
#
#  (13, 'Booking.com', 'http://www.workingatbooking.com', 'http://github-jobs.s3.amazonaws.com/c9146712-b308-11e6-875e-1fa7ba6a7f42.jpeg')
#
#  (14, 'LiveStories', 'http://www.livestories.com', 'http://github-jobs.s3.amazonaws.com/a74585a0-b10d-11e6-80d4-bae80c66bb59.png')
#
#  (15, 'Mayfield Robotics', 'http://www.mayfieldrobotics.com/', 'http://github-jobs.s3.amazonaws.com/85454f34-adad-11e6-938c-da7ff962d92f.png')
#
#  (16, 'Spreemo', 'http://www.spreemo.com', 'http://github-jobs.s3.amazonaws.com/8530b198-ab62-11e6-9227-10b58f5dcfab.png')
#
#  (17, 'Johnson Controls', 'http://www.tyco.com/', 'http://github-jobs.s3.amazonaws.com/9c77a9be-aa9b-11e6-9186-3e169096f20b.png')
#
#  (18, 'SAP', 'https://jobs.sap.com/search/?q=SAPmachinelearningcareers&locationsearch=&utm_source=github&utm_campaign=sap_machinelearning', 'http://github-jobs.s3.amazonaws.com/05fe7560-aa98-11e6-9e8a-0e66c883b7dd.png')
#
#  (19, 'Leadpages', 'http://www.leadpages.net/', 'http://github-jobs.s3.amazonaws.com/314925f0-a83e-11e6-8350-38442bc0d153.png')
#
#  (20, 'FiftyThree, Inc.', 'http://www.fiftythree.com', None)

# %%
s = text('SELECT * FROM job')
result = conn.execute(s)

for row in result:
    print('\n {}'.format(row))
# Out:
# 2016-12-10 04:41:19,501 INFO sqlalchemy.engine.base.Engine SELECT * FROM job
# 2016-12-10 04:41:19,502 INFO sqlalchemy.engine.base.Engine ()
#
#  (1, 1, 1, 'Team Lead, Fullstack Software Developer', '<p>Onsite, Relocation available.</p>\n\n<p>We’re an independent development team inside The NORDAM Group building a brand new public web service. The ... (2489 characters truncated) ... ssibility and can build products that are accessible to users with disabilities.</li>\n<li>Experience developing “responsive” websites.</li>\n</ul>\n', '<p>Email your resume and a link to your Github profile to <a href="mailto:simon.grondin@outlook.com">simon.grondin@outlook.com</a></p>\n')
#
#  (2, 1, 1, 'Fullstack Developer', '<p>We’re an independent development team inside The NORDAM Group building a brand new public web service. The aerospace industry we’re modernizing ha ... (2254 characters truncated) ... ilities.</li>\n<li>Experience with front end development technologies like HTML5 and CSS3, and experience building responsive websites.</li>\n</ul>\n', '<p>Email your resume and a link to your Github profile to <a href="mailto:simon.grondin@outlook.com">simon.grondin@outlook.com</a></p>\n')
#
#  (3, 2, 1, 'iOS Instructor and Curriculum Engineer', '<p>We&#39;re looking for an iOS Instructor &amp; Curriculum Engineer to develop and teach the iOS curriculum for our Product College.</p>\n\n<p>Make  ... (3933 characters truncated) ... Principles course framework. Swift CSP is currently being used by high school teachers and computer science clubs around the world.</p></li>\n</ul>\n', '<p><a href="https://jobs.lever.co/makeschool/d87353c7-05b1-4afe-95bf-abb4fb1a8aa8/apply">https://jobs.lever.co/makeschool/d87353c7-05b1-4afe-95bf-abb4fb1a8aa8/apply</a></p>\n')
#
#  (4, 3, 1, 'Software Engineer', '<p>imo, based in Palo Alto, is a fast growing mobile messaging app. We’re building products that help hundreds of millions of people around the world ... (1427 characters truncated) ... eimbursement </li>\n<li>Gym membership at Equinox </li>\n<li>Yearly conference stipend </li>\n<li>imo-sponsored team events and outings</li>\n</ul>\n', '<p>Email your resume to <a href="mailto:jobs@imo.im">jobs@imo.im</a></p>\n')
#
#  (5, 4, 1, 'Linux Systems Engineer', '<p><strong>Summary</strong> </p>\n\n<ul>\n<li>The engineering team at NMI is a small, agile group that works closely together but requires independen ... (2957 characters truncated) ... >\n<li>Jira and Confluence for task and project management</li>\n<li>Computer</li>\n<li>Printer</li>\n<li>Fax Machine</li>\n<li>Scanner</li>\n</ul>\n', '<p>Please E-mail your resume to <a href="mailto:hr@nmi.com">hr@nmi.com</a></p>\n')
#
#  (6, 5, 1, 'Implementation Developer', '<p>Stevens Capital Management LP (“SCM”) is a registered investment adviser that manages a multi-billion dollar hedge fund that has been in business  ... (1396 characters truncated) ... Experience with relational databases including Sybase, SQL Server and Oracle is a plus.</li>\n<li>Experience with GUI design is a plus.</li>\n</ul>\n', '<p>Please submit your resume to: <a href="mailto:recruiting@scm-lp.com">recruiting@scm-lp.com</a></p>\n\n<p>Website: <a href="http://www.scm-lp.com">www.scm-lp.com</a></p>\n')
#
#  (7, 6, 1, 'Software Engineer, DevOps', '<p>Job description</p>\n\n<p>GenePeeks is a data-driven genetics start-up pushing the boundaries of reproductive health care and computational geneti ... (2494 characters truncated) ... l>\n\n<p>Location:\nThis position will be located in the Boston or New York area.\n*GenePeeks will not offer visa sponsorship for this position</p>\n', '<p><a href="http://careers.genepeeks.com/o/software-engineer-devops=GitHub">http://careers.genepeeks.com/o/software-engineer-devops=GitHub</a></p>\n')
#
#  (8, 7, 1, 'Automated Driving SW Development Engineer', '<p>Employees of the Internet of Things Solutions Group (IOTG) have an exciting opportunity before them: To grow Intel&#39;s leadership position in th ... (4089 characters truncated) ... ated to helping Intel drive the next major growth inflection through productivity and new business models that are emerging as a result of IoT.</p>\n', '<p>Apply on company website: <a href="http://career.intel.com/TpLVa">http://career.intel.com/TpLVa</a></p>\n')
#
#  (9, 7, 1, 'Software Development Engineer C, C++', '<p>Duties are focused on development open-source LLVM/GCC toolchain for Intel Architecture in Linux and Android target environments.  </p>\n\n<p><str ... (2188 characters truncated) ... global leadership to the software community through its technical expertise, industry enabling activities, and developer products and programs.</p>\n', '<p>Apply on company website: <a href="http://career.intel.com/TpHFE">http://career.intel.com/TpHFE</a></p>\n')
#
#  (10, 8, 1, 'C++/Python Developer', '<p><strong>C++/Python Engineers</strong></p>\n\n<p>We’re looking for a select few uniquely excellent C++/Python engineers to join our world-class tea ... (5267 characters truncated) ... ed</li>\n</ul>\n\n<p><strong>Education:</strong></p>\n\n<p>Bachelor’s or master’s degree in computer science from an excellent academic program</p>\n', '<p><a href="http://grnh.se/h8l4dk1">http://grnh.se/h8l4dk1</a></p>\n')
#
#  (11, 9, 1, 'Ruby/Rails BackEnd Developer', '<p><h2><strong>About CrowdFlower...</strong></h2><p>CrowdFlower is the essential human-in-the-loop platform for data science teams. CrowdFlower helps ... (3313 characters truncated) ... ve total compensation package including outstanding benefits and stock options.</p> <img src="https://www.applytracking.com/track.aspx/7IJjT"/></p>\n', '<p><a href="https://www.applytracking.com/track.aspx/7IJjd">https://www.applytracking.com/track.aspx/7IJjd</a></p>\n')
#
#  (12, 10, 1, 'Senior Software Engineer - Cloud', '<p><strong>Why Carbon Black?</strong></p>\n\n<p>At Carbon Black, you’ll have the opportunity to make a huge impact while working alongside a global c ... (4315 characters truncated) ... oint Protection by security professionals in the SANS Institute’s Best of 2015 Awards.</p>\n\n<p>Carbon Black is an Equal Opportunity Employer.</p>\n', '<p><a href="https://lifeatcb.carbonblack.com/job-postings/?p=job/oMPL3fw9&amp;__jvst=JobBoard&amp;__jvsd=Github&amp;nl=1">Click here to apply.</a></p>\n')
#
#  (13, 11, 1, 'Software Engineering Manager, Oyster.com', '<p>SmarterTravel, a TripAdvisor Company, offers travelers a portfolio of travel sites to help them find the right trip at the right price.  We are a  ... (3479 characters truncated) ... d, if necessary, the Department of Homeland Security (DHS) with information from each new employee&#39;s I-9 to confirm work authorization. ***</p>\n', '<p>Please apply online at <a href="http://grnh.se/ta5py11">http://grnh.se/ta5py11</a> or email your resume to <a href="mailto:careers@smartertravel.com">careers@smartertravel.com</a></p>\n')
#
#  (14, 12, 1, 'Front-End Lead Developer to Teleopti ', '<p>If you are a team player who appreciates freedom with responsibility and working in an international and creative environment, this is the job for ... (5667 characters truncated) ... e third year in a row, Teleopti is ranked by Great Place to Work as one of Sweden´s best workplaces, in the category of medium-sized companies.</p>\n', '<p>Do you meet the requirements? Click on the link below:\n<a href="https://www.academicwork.se/annons/front-end-lead-developer-to-teleopti/14979312? ... (435 characters truncated) ... academicwork.se</a> and we will answer during office hours. Please write the advert title in the subject and paste the advert link in the mail.</p>\n')
#
#  (15, 13, 1, 'Data Scientist – Machine Learning', '<p>Would you like to translate terabytes of data into unforgettable holidays for millions of people around the globe? Booking.com, the world’s larges ... (3049 characters truncated) ... is looking for a Data Scientist - Machine Learning in Amsterdam, the Netherlands. All references to “Booking.com&quot; refer to Booking.com BV.</p>\n', '<p>Apply: <a href="http://grnh.se/62yip51">http://grnh.se/62yip51</a></p>\n')
#
#  (16, 13, 1, 'Data Scientist – Analytics', '<p>Booking.com is looking for data savvy professionals to join our team of data scientists. You will be working with stakeholders throughout the comp ... (2719 characters truncated) ... com BV is looking for a Data Scientist - Analytics in Amsterdam, the Netherlands. All references to “Booking.com&quot; refer to Booking.com BV.</p>\n', '<p>Apply:  <a href="http://grnh.se/62yip51">http://grnh.se/62yip51</a></p>\n')
#
#  (17, 14, 1, '(Sr.) Front End Engineer', '<h1>Why LiveStories?</h1>\n\n<p>LiveStories is a venture-backed company building modern tools to help the world’s largest sector be more data-driven, ... (2026 characters truncated) ... ental, and vision benefits </li>\n<li>Flexible vacation policy </li>\n<li>An incredible team of smart, dedicated, and supportive people</li>\n</ul>\n', '<p>Send your resume to <a href="mailto:careers@livestories.com">careers@livestories.com</a></p>\n')
#
#  (18, 15, 1, 'Software Test Engineer (Python)', '<p>About the Company:</p>\n\n<p>At Mayfield Robotics, we make home robots that are joyful, useful, and inspiring. We move fast, we like and respect e ... (3997 characters truncated) ... es </li>\n<li>Tuition reimbursement </li>\n<li>401K </li>\n<li>Laundry/dry cleaning service </li>\n<li>Happy hours &amp; company events</li>\n</ul>\n', '<p>To apply, send your resume to <a href="mailto:jobs+qa@mayfieldrobotics.com">jobs+qa@mayfieldrobotics.com</a>.</p>\n')
#
#  (19, 16, 1, 'Software Engineer', '<h2><strong>Who are we?</strong></h2>\n\n<p>At Spreemo we believe that advanced data science can prevent serious misdiagnoses and poor outcomes. Usin ... (2839 characters truncated) ... t benefits. Benefits include: medical + dental insurance, FSA, pre-tax commuter benefits, lots of paid time off, and Macbook Pro + XL monitors.</p>\n', '<p>Visit <a href="https://jobs.lever.co/spreemo.com/76c7822a-481a-4629-9a6e-ac6fe811885f">https://jobs.lever.co/spreemo.com/76c7822a-481a-4629-9a6e-ac6fe811885f</a></p>\n')
#
#  (20, 9, 1, 'Software Project Manager', '<p>Summary:</p>\n\n<p>eHealth Africa is focused on improving healthcare by creating effective ways to implement reliable health information managemen ... (3184 characters truncated) ... -paced environment</p>\n\n<p>Ability to work on multiple projects simultaneously and deliver within tight timelines</p>\n\n<p>Fluent in English</p>\n', '<p><a href="https://eHealthAfrica.bamboohr.com/jobs/view.php?id=40">https://eHealthAfrica.bamboohr.com/jobs/view.php?id=40</a></p>\n')
#
#  (21, 9, 1, 'Senior Andriod Developer(Freelance for 6 months)', '<p>Summary:</p>\n\n<p>eHealth Africa is focused on improving healthcare by creating effective ways to implement reliable health information managemen ... (3582 characters truncated) ... our priority as well as rewarding them for their hard work.</p>\n\n<p>Note: The successful candidate will work either from Freetown or  Berlin.</p>\n', '<p><a href="https://eHealthAfrica.bamboohr.com/jobs/view.php?id=38">https://eHealthAfrica.bamboohr.com/jobs/view.php?id=38</a></p>\n')
#
#  (22, 17, 1, 'Senior Android Engineer', '<p>ANDROID JOB DESCRIPTION\niOS and/or wearable is nice to have. Bluetooth and Embedded Experience also nice to have.</p>\n\n<p>As a Senior Mobile En ... (4111 characters truncated) ... t importantly, (Have a Personality  ) we are a fun crowd and like to work with other fun talented people.</li>\n</ul>\n\n<p>Job Type: Full-Time</p>\n', '<p>Visit:\n<a href="https://jobs.johnsoncontrols.com/job-details/software-engineer-iii-mobile/649849012/">https://jobs.johnsoncontrols.com/job-detail ... (25 characters truncated) ... obile/649849012/</a></p>\n\n<p>or</p>\n\n<p>send resume directly to <a href="mailto:JoPedroza@tycoint.com">JoPedroza@tycoint.com</a> for review</p>\n')
#
#  (23, 18, 1, 'Developer with ML background for Machine Learning development Job', '<p><a href="https://jobs.sap.com/job/Palo-Alto-Developer-with-ML-background-for-Machine-Learning-development-Job-CA-94301/327259801/?feedId=203001&ut ... (1486 characters truncated) ... arning-development-Job-CA-94301/327259801/?feedId=203001&utm_source=github&utm_campaign=sap_machinelearning">Apply on our career site here.</a></p>\n', '<p><a href="https://jobs.sap.com/job/Palo-Alto-Developer-with-ML-background-for-Machine-Learning-development-Job-CA-94301/327259801/?feedId=203001&utm_source=github&utm_campaign=sap_machinelearning">Apply on our career site here.</a></p>\n')
#
#  (24, 19, 1, 'Site Reliability Engineer', '<p>We promise you haven’t worked with anyone <a href="http://www.leadpages.net/careers">like us</a> before.  We’re a Minneapolis / St. Paul, MN based ... (6317 characters truncated) ... leadpages.net/apply/YN38C7/Site-Reliability-Engineer?source=Github">HERE</a>. Thanks for checking us out - we look forward to hearing from you!</p>\n', '<p><strong>Sound like you?</strong></p>\n\n<p>To apply, please submit your tailored resume, a link to your LinkedIn profile, and a cover letter expla ... (95 characters truncated) ... leadpages.net/apply/YN38C7/Site-Reliability-Engineer?source=Github">HERE</a>. Thanks for checking us out - we look forward to hearing from you!</p>\n')
#
#  (25, 20, 1, 'Software Engineer, Front-End Web', '<p>Job Profile:</p>\n\n<p>Build rich, dynamic, magical web applications. Work hand-in-hand with the design and product teams to implement interfaces  ... (2360 characters truncated) ... >Catered in-office lunches twice weekly and fully stocked pantry </li>\n<li>Flexible Time Off Policy </li>\n<li>Employee Equity Program</li>\n</ul>\n', '<p><a href="http://grnh.se/bdfpi81">http://grnh.se/bdfpi81</a></p>\n')

# %%
s = text('SELECT * FROM location')
result = conn.execute(s)

for row in result:
    print('\n {}'.format(row))
# Out:
# 2016-12-10 04:41:22,438 INFO sqlalchemy.engine.base.Engine SELECT * FROM location
# 2016-12-10 04:41:22,439 INFO sqlalchemy.engine.base.Engine ()
#
#  (1, 'Tulsa, OK, USA', 0)
#
#  (2, 'Tulsa, OK, USA', 0)
#
#  (3, 'San Francisco', 0)
#
#  (4, 'Palo Alto, CA', 0)
#
#  (5, 'Roselle, IL', 0)
#
#  (6, 'Radnor, PA. USA', 0)
#
#  (7, 'Cambridge, MA', 0)
#
#  (8, 'Karlsruhe, Germany', 0)
#
#  (9, 'Gdansk, Poland ', 0)
#
#  (10, 'New York', 0)
#
#  (11, 'San Francisco, CA, US', 0)
#
#  (12, 'Waltham, MA or Telecommute', 1)
#
#  (13, 'New York, NY', 0)
#
#  (14, 'Stockholm', 0)
#
#  (15, 'Amsterdam', 0)
#
#  (16, 'Amsterdam', 0)
#
#  (17, 'Seattle', 0)
#
#  (18, 'Redwood City, CA', 0)
#
#  (19, 'New York, NY', 0)
#
#  (20, 'Sierra Leone', 0)
#
#  (21, 'Sierra Leone', 0)
#
#  (22, 'Irvine, CA', 0)
#
#  (23, 'Palo Alto', 0)
#
#  (24, 'Minneapolis, MN', 0)
#
#  (25, 'New York, NY', 0)

# %%
s = text('SELECT * FROM github_metadata')
result = conn.execute(s)

for row in result:
    print('\n {}'.format(row))
# Out:
# 2016-12-10 04:41:26,167 INFO sqlalchemy.engine.base.Engine SELECT * FROM github_metadata
# 2016-12-10 04:41:26,168 INFO sqlalchemy.engine.base.Engine ()
#
#  (1, 'f9891adc-be25-11e6-9511-e40bbeeef49d', 'http://jobs.github.com/positions/f9891adc-be25-11e6-9511-e40bbeeef49d', '2016-12-09 15:42:07.000000')
#
#  (2, '8ae1f6bc-be25-11e6-89a1-99b30fbe0cd6', 'http://jobs.github.com/positions/8ae1f6bc-be25-11e6-89a1-99b30fbe0cd6', '2016-12-09 15:39:49.000000')
#
#  (3, '1e8c129c-bd92-11e6-8617-152c7092fed4', 'http://jobs.github.com/positions/1e8c129c-bd92-11e6-8617-152c7092fed4', '2016-12-08 22:03:30.000000')
#
#  (4, 'bb1644a2-bce3-11e6-9406-ccfe9cedada7', 'http://jobs.github.com/positions/bb1644a2-bce3-11e6-9406-ccfe9cedada7', '2016-12-08 01:15:35.000000')
#
#  (5, 'beb74684-bbed-11e6-8197-64e617b51adf', 'http://jobs.github.com/positions/beb74684-bbed-11e6-8197-64e617b51adf', '2016-12-06 19:54:25.000000')
#
#  (6, '61433012-baf8-11e6-8d18-1baa36e6dbf5', 'http://jobs.github.com/positions/61433012-baf8-11e6-8d18-1baa36e6dbf5', '2016-12-05 14:38:11.000000')
#
#  (7, '6d409aaa-b8c6-11e6-8408-7debc09d256f', 'http://jobs.github.com/positions/6d409aaa-b8c6-11e6-8408-7debc09d256f', '2016-12-02 19:36:23.000000')
#
#  (8, '47b78b5e-b7ef-11e6-86f0-a00baabc0c92', 'http://jobs.github.com/positions/47b78b5e-b7ef-11e6-86f0-a00baabc0c92', '2016-12-02 11:49:17.000000')
#
#  (9, '88d7a11e-b7ef-11e6-8839-4baedb4f1c00', 'http://jobs.github.com/positions/88d7a11e-b7ef-11e6-8839-4baedb4f1c00', '2016-12-02 11:49:15.000000')
#
#  (10, '24d6d212-b7f8-11e6-9bc0-4c468fa010c5', 'http://jobs.github.com/positions/24d6d212-b7f8-11e6-9bc0-4c468fa010c5', '2016-12-01 18:59:13.000000')
#
#  (11, '53eb1432-b68b-11e6-805c-42ae75f605e1', 'http://jobs.github.com/positions/53eb1432-b68b-11e6-805c-42ae75f605e1', '2016-11-29 23:27:00.000000')
#
#  (12, 'f2dff876-b679-11e6-896e-3954f140fe85', 'http://jobs.github.com/positions/f2dff876-b679-11e6-896e-3954f140fe85', '2016-11-29 21:23:04.000000')
#
#  (13, 'b3d3c3fe-b65d-11e6-9da9-6e5efb70d328', 'http://jobs.github.com/positions/b3d3c3fe-b65d-11e6-9da9-6e5efb70d328', '2016-11-29 19:14:14.000000')
#
#  (14, 'ada0319c-b57d-11e6-9c3c-d13afadb65a8', 'http://jobs.github.com/positions/ada0319c-b57d-11e6-9c3c-d13afadb65a8', '2016-11-28 15:17:34.000000')
#
#  (15, 'cf34f21a-b308-11e6-9192-6f14e27e77e8', 'http://jobs.github.com/positions/cf34f21a-b308-11e6-9192-6f14e27e77e8', '2016-11-25 12:15:59.000000')
#
#  (16, '4e2c3674-b308-11e6-9dbe-b0fc9cbe45b2', 'http://jobs.github.com/positions/4e2c3674-b308-11e6-9dbe-b0fc9cbe45b2', '2016-11-25 12:12:50.000000')
#
#  (17, 'f2648464-b10d-11e6-9bd0-5ecee6c9ffa7', 'http://jobs.github.com/positions/f2648464-b10d-11e6-9bd0-5ecee6c9ffa7', '2016-11-22 23:48:04.000000')
#
#  (18, '048cd71c-adae-11e6-9327-2b710fbf6e21', 'http://jobs.github.com/positions/048cd71c-adae-11e6-9327-2b710fbf6e21', '2016-11-18 16:43:44.000000')
#
#  (19, 'b92c77de-ab62-11e6-9d5d-0f03dd750bd7', 'http://jobs.github.com/positions/b92c77de-ab62-11e6-9d5d-0f03dd750bd7', '2016-11-15 18:39:28.000000')
#
#  (20, 'd409edb0-ab4a-11e6-8eed-c01232d09e01', 'http://jobs.github.com/positions/d409edb0-ab4a-11e6-8eed-c01232d09e01', '2016-11-15 15:49:15.000000')
#
#  (21, '2e1b4148-ab49-11e6-8b5d-230703ad0bc9', 'http://jobs.github.com/positions/2e1b4148-ab49-11e6-8b5d-230703ad0bc9', '2016-11-15 15:39:44.000000')
#
#  (22, 'a0e32852-aa9b-11e6-93e6-4146165b3b6f', 'http://jobs.github.com/positions/a0e32852-aa9b-11e6-93e6-4146165b3b6f', '2016-11-14 18:54:05.000000')
#
#  (23, '0e70b42e-aa98-11e6-9dc7-99d5c3a10bc9', 'http://jobs.github.com/positions/0e70b42e-aa98-11e6-9dc7-99d5c3a10bc9', '2016-11-14 18:29:10.000000')
#
#  (24, '43b8b066-a83e-11e6-9dcf-84f334f5295b', 'http://jobs.github.com/positions/43b8b066-a83e-11e6-9dcf-84f334f5295b', '2016-11-11 18:41:52.000000')
#
#  (25, '7978e922-a781-11e6-9907-af5d98bf0bd7', 'http://jobs.github.com/positions/7978e922-a781-11e6-9907-af5d98bf0bd7', '2016-11-10 20:23:11.000000')

# %% [markdown]
# # The output from our queries should be similar to this:
#
# There are 27 jobs with the 'Data Science' term, and 40% of them have 'Python' in the description.
#
# 22% of them have been created in the past 7 days.
#
# 2 of those are remote ok. The companies with remote jobs are: ['Carbon Black, Inc.', 'Kaggle']

# %%
s = text("SELECT COUNT() "
         "FROM job")
total, = conn.execute(s).fetchone()

s = text("SELECT COUNT() "
         "FROM job "
         "WHERE description LIKE '%python%'")
python, = conn.execute(s).fetchone()

print("\nThere are {} jobs with the 'Data Science' term, and {}% of them have 'Python' in the description."
      .format(total, 100 * python // total))
# Out:
# 2016-12-10 04:42:00,679 INFO sqlalchemy.engine.base.Engine SELECT COUNT() FROM job
# 2016-12-10 04:42:00,680 INFO sqlalchemy.engine.base.Engine ()
# 2016-12-10 04:42:00,682 INFO sqlalchemy.engine.base.Engine SELECT COUNT() FROM job WHERE description LIKE '%python%'
# 2016-12-10 04:42:00,682 INFO sqlalchemy.engine.base.Engine ()
#
# There are 25 jobs with the 'Data Science' term, and 40% of them have 'Python' in the description.

# %%
from datetime import datetime, timedelta

s = text("SELECT COUNT() "
         "FROM github_metadata "
         "WHERE created_at >= :week_ago")
last_week, = conn.execute(s, week_ago=datetime.today() - timedelta(days=7)
                         ).fetchone()

print("\n{}% of them have been created in the past 7 days."
      .format(100 * last_week // total))
# Out:
# 2016-12-10 04:42:11,135 INFO sqlalchemy.engine.base.Engine SELECT COUNT() FROM github_metadata WHERE created_at >= ?
# 2016-12-10 04:42:11,137 INFO sqlalchemy.engine.base.Engine (datetime.datetime(2016, 12, 3, 4, 42, 11, 135697),)
#
# 24% of them have been created in the past 7 days.

# %%
s = text("SELECT COUNT() "
         "FROM job "
         "JOIN location ON job.id = location.job_id "
         "WHERE remote_ok = :true")
remote_jobs, = conn.execute(s, true=int(True)).fetchone()

if remote_jobs > 0:
    s = text("SELECT name "
             "FROM company "
             "JOIN job ON company.id = job.company_id "
             "JOIN location ON job.id = location.job_id "
             "WHERE location.remote_ok = :true")
    remote_companies = conn.execute(s, true=int(True)).fetchall()
    
    if len(remote_companies) == 1:
        message = '\n{} of those is remote ok. The company with the remote job is: {}'
    else:
        message = '\n{} of those are remote ok. The companies with remote jobs are: {}'
        
    print(message.format(remote_jobs, " ;".join(str(company) for company, in remote_companies)))
# Out:
# 2016-12-10 04:42:17,323 INFO sqlalchemy.engine.base.Engine SELECT COUNT() FROM job JOIN location ON job.id = location.job_id WHERE remote_ok = ?
# 2016-12-10 04:42:17,324 INFO sqlalchemy.engine.base.Engine (1,)
# 2016-12-10 04:42:17,326 INFO sqlalchemy.engine.base.Engine SELECT name FROM company JOIN job ON company.id = job.company_id JOIN location ON job.id = location.job_id WHERE location.remote_ok = ?
# 2016-12-10 04:42:17,326 INFO sqlalchemy.engine.base.Engine (1,)
#
# 1 of those is remote ok. The company with the remote job is: Carbon Black, Inc.

# %%
conn.close()
